# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback


model = TQC.load("data/tqc1/tqc_model_873000_steps")
env = roboverse.make("Widow250PickPlace-v2",
                         gui=True,
                         observation_mode="pixels",
                         transpose_image=False)
model.set_env(env)
env = model.get_env()

obs = env.reset()
print("start render")
for i in range(int(1e4)):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(rewards)
    env.render("human")
env.close()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
import time
import numpy as np
from roboverse.policies import policies
from stable_baselines3.common.utils import set_random_seed


def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = roboverse.make(env_id,
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
        #env = TimeFeatureWrapper(env)
        #env.reset(seed=seed + rank)
        env.reset()
        return env
    set_random_seed(seed)
    return _init


def collect_data(env, model, policy, target, num_trajectories=100, num_timesteps=30):
    policy_class = policies[policy]
    policy = policy_class(env)
    num_success = 0
    num_saved = 0
    accept_trajectory_key = target
    noise = 0.1
    EPSILON = 0.1

    while num_saved < num_trajectories:
        num_saved += 1
        num_steps = 1e6
        rewards = []
        env.reset()
        policy.reset()
        time.sleep(0.1)
        success = False
        for j in range(num_timesteps):
            action, agent_info = policy.get_action()

            # In case we need to pad actions by 1 for easier realNVP modelling 
            env_action_dim = env.action_space.shape[0]
            #if env_action_dim - action.shape[0] == 1:
            #    action = np.append(action, 0)
            action += np.random.normal(scale=noise, size=(env_action_dim,))
            action = np.clip(action, -1 + EPSILON, 1 - EPSILON)
            observation = env.get_observation()
            observation["image"] = np.transpose(observation["image"], (2, 0, 1))
            next_observation, reward, done, info = env.step(action)
            next_observation["image"] = np.transpose(next_observation["image"], (2, 0, 1))
            rewards.append(reward)
            success = sum(rewards) > 70
            model.replay_buffer.add(observation, next_observation, action, reward, np.array([done]), [{}])

            if success and num_steps > 1e3: #info[accept_trajectory_key]
                num_steps = j

            if success and j > 23: #info[accept_trajectory_key]
                break
            if done or agent_info['done']:
                break

        if success: #info[accept_trajectory_key]
            PRINT = False
            if PRINT:
                print("num_timesteps: ", num_steps, rewards)
                #print(observation["image"].shape)
                #print(next_observation["image"].shape)
            num_success += 1
        if num_saved%100 == 0:
            print(f"num_trajectories: {num_saved} success rate: {num_success/num_saved} Reward: {sum(rewards)}")

    print("success rate: {}".format(num_success / (num_saved)))
# Out:
# pybullet build time: May 20 2022 19:44:17

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlaceMultiObject-v0",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 2
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

# model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
#              policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
#              replay_buffer_class=HerReplayBuffer,
#              replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
#              tau=0.05, learning_starts=200, verbose=1)

model = TQC.load("data/seed_1/tqc_pick_place", env=env)
model.set_env(env)

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start learning")
model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")
print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# load_replay_buffer
# start learning
# Output()
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:219:
# DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is
# recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:225:
# DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:165: UserWarning:
# WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 9900     |
# |    fps             | 10       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 980198   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.00557  |
# |    ent_coef_loss   | 250      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999997   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 9905     |
# |    fps             | 10       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 980693   |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 85.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1000492  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 9910     |
# |    fps             | 10       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 981188   |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | 48.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1000987  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 9915     |
# |    fps             | 10       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 981683   |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0212   |
# |    ent_coef_loss   | 16.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1001482  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 10       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 982178   |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1001977  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 9925     |
# |    fps             | 10       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 982673   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 13.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1002472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 9930     |
# |    fps             | 10       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 983168   |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0369   |
# |    ent_coef_loss   | 11.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1002967  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 90.6     |
# | time/              |          |
# |    episodes        | 9935     |
# |    fps             | 10       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 983663   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | 7.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1003462  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 74.5     |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 10       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 984158   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 9.34     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 4.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1003957  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 58.4     |
# | time/              |          |
# |    episodes        | 9945     |
# |    fps             | 10       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 984653   |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0604   |
# |    ent_coef_loss   | 6.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1004452  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 42.2     |
# | time/              |          |
# |    episodes        | 9950     |
# |    fps             | 10       |
# |    time_elapsed    | 508      |
# |    total_timesteps | 985148   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | 4.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1004947  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 26.4     |
# | time/              |          |
# |    episodes        | 9955     |
# |    fps             | 10       |
# |    time_elapsed    | 558      |
# |    total_timesteps | 985643   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 3.72     |
# |    ent_coef        | 0.0883   |
# |    ent_coef_loss   | 2.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1005442  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 10       |
# |    time_elapsed    | 609      |
# |    total_timesteps | 986138   |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.0884   |
# |    ent_coef_loss   | -2.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1005937  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -2.17    |
# | time/              |          |
# |    episodes        | 9965     |
# |    fps             | 10       |
# |    time_elapsed    | 659      |
# |    total_timesteps | 986633   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | -0.752   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1006432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -15.8    |
# | time/              |          |
# |    episodes        | 9970     |
# |    fps             | 10       |
# |    time_elapsed    | 708      |
# |    total_timesteps | 987128   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.0654   |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1006927  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -28.7    |
# | time/              |          |
# |    episodes        | 9975     |
# |    fps             | 10       |
# |    time_elapsed    | 761      |
# |    total_timesteps | 987623   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 5.95     |
# |    ent_coef        | 0.0598   |
# |    ent_coef_loss   | -0.0678  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1007422  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42      |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 10       |
# |    time_elapsed    | 810      |
# |    total_timesteps | 988118   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.17     |
# |    ent_coef        | 0.0473   |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1007917  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -58      |
# | time/              |          |
# |    episodes        | 9985     |
# |    fps             | 9        |
# |    time_elapsed    | 862      |
# |    total_timesteps | 988613   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 7.29     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | 0.701    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1008412  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -70.6    |
# | time/              |          |
# |    episodes        | 9990     |
# |    fps             | 9        |
# |    time_elapsed    | 911      |
# |    total_timesteps | 989108   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 6.02     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | 0.203    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1008907  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.5    |
# | time/              |          |
# |    episodes        | 9995     |
# |    fps             | 10       |
# |    time_elapsed    | 960      |
# |    total_timesteps | 989603   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.0558   |
# |    ent_coef_loss   | -0.595   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1009402  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 10       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 990098   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1009897  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10005    |
# |    fps             | 10       |
# |    time_elapsed    | 1056     |
# |    total_timesteps | 990593   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 3.58     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | -0.731   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1010392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10010    |
# |    fps             | 10       |
# |    time_elapsed    | 1105     |
# |    total_timesteps | 991088   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 3.05     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1010887  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10015    |
# |    fps             | 10       |
# |    time_elapsed    | 1154     |
# |    total_timesteps | 991583   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0538   |
# |    ent_coef_loss   | 0.0106   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1011382  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10020    |
# |    fps             | 10       |
# |    time_elapsed    | 1201     |
# |    total_timesteps | 992078   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 2.05     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1011877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -90.7    |
# | time/              |          |
# |    episodes        | 10025    |
# |    fps             | 10       |
# |    time_elapsed    | 1251     |
# |    total_timesteps | 992573   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.0512   |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1012372  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -88.2    |
# | time/              |          |
# |    episodes        | 10030    |
# |    fps             | 10       |
# |    time_elapsed    | 1302     |
# |    total_timesteps | 993068   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0572   |
# |    ent_coef_loss   | -0.687   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1012867  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.3    |
# | time/              |          |
# |    episodes        | 10035    |
# |    fps             | 10       |
# |    time_elapsed    | 1351     |
# |    total_timesteps | 993563   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.0582   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1013362  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10040    |
# |    fps             | 10       |
# |    time_elapsed    | 1400     |
# |    total_timesteps | 994058   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.762    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1013857  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10045    |
# |    fps             | 10       |
# |    time_elapsed    | 1447     |
# |    total_timesteps | 994553   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | 0.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1014352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10050    |
# |    fps             | 10       |
# |    time_elapsed    | 1497     |
# |    total_timesteps | 995048   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 3.05     |
# |    ent_coef        | 0.0515   |
# |    ent_coef_loss   | -0.333   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1014847  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10055    |
# |    fps             | 10       |
# |    time_elapsed    | 1546     |
# |    total_timesteps | 995543   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1015342  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10060    |
# |    fps             | 10       |
# |    time_elapsed    | 1595     |
# |    total_timesteps | 996038   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | -0.406   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1015837  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10065    |
# |    fps             | 10       |
# |    time_elapsed    | 1645     |
# |    total_timesteps | 996533   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0425   |
# |    ent_coef_loss   | 0.0373   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016332  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10070    |
# |    fps             | 10       |
# |    time_elapsed    | 1694     |
# |    total_timesteps | 997028   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | -0.393   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016827  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10075    |
# |    fps             | 10       |
# |    time_elapsed    | 1743     |
# |    total_timesteps | 997523   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -0.873   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1017322  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10080    |
# |    fps             | 10       |
# |    time_elapsed    | 1792     |
# |    total_timesteps | 998018   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.929   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1017817  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10085    |
# |    fps             | 10       |
# |    time_elapsed    | 1841     |
# |    total_timesteps | 998513   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1018312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10090    |
# |    fps             | 10       |
# |    time_elapsed    | 1888     |
# |    total_timesteps | 999008   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.2      |
# |    ent_coef        | 0.0351   |
# |    ent_coef_loss   | 0.636    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1018807  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10095    |
# |    fps             | 10       |
# |    time_elapsed    | 1939     |
# |    total_timesteps | 999503   |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.11     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.686    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1019302  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10100    |
# |    fps             | 10       |
# |    time_elapsed    | 1987     |
# |    total_timesteps | 999998   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | -0.515   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1019797  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10105    |
# |    fps             | 10       |
# |    time_elapsed    | 2038     |
# |    total_timesteps | 1000493  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.34     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1020292  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10110    |
# |    fps             | 10       |
# |    time_elapsed    | 2084     |
# |    total_timesteps | 1000988  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0339   |
# |    ent_coef_loss   | 0.861    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1020787  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10115    |
# |    fps             | 10       |
# |    time_elapsed    | 2134     |
# |    total_timesteps | 1001483  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.6      |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1021282  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.4    |
# | time/              |          |
# |    episodes        | 10120    |
# |    fps             | 10       |
# |    time_elapsed    | 2183     |
# |    total_timesteps | 1001978  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -1.46    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1021777  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.4    |
# | time/              |          |
# |    episodes        | 10125    |
# |    fps             | 10       |
# |    time_elapsed    | 2231     |
# |    total_timesteps | 1002473  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.038    |
# |    ent_coef_loss   | 0.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1022272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.9    |
# | time/              |          |
# |    episodes        | 10130    |
# |    fps             | 10       |
# |    time_elapsed    | 2279     |
# |    total_timesteps | 1002968  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.44     |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | 0.391    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1022767  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -88.8    |
# | time/              |          |
# |    episodes        | 10135    |
# |    fps             | 10       |
# |    time_elapsed    | 2328     |
# |    total_timesteps | 1003463  |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1023262  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10140    |
# |    fps             | 10       |
# |    time_elapsed    | 2376     |
# |    total_timesteps | 1003958  |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.0378   |
# |    ent_coef_loss   | 0.159    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1023757  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10145    |
# |    fps             | 10       |
# |    time_elapsed    | 2425     |
# |    total_timesteps | 1004453  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 2.69     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1024252  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10150    |
# |    fps             | 10       |
# |    time_elapsed    | 2476     |
# |    total_timesteps | 1004948  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | 0.0695   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1024747  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10155    |
# |    fps             | 10       |
# |    time_elapsed    | 2524     |
# |    total_timesteps | 1005443  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | -0.377   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1025242  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10160    |
# |    fps             | 10       |
# |    time_elapsed    | 2573     |
# |    total_timesteps | 1005938  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.0453   |
# |    ent_coef_loss   | 0.485    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1025737  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10165    |
# |    fps             | 10       |
# |    time_elapsed    | 2623     |
# |    total_timesteps | 1006433  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | -0.382   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1026232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10170    |
# |    fps             | 10       |
# |    time_elapsed    | 2673     |
# |    total_timesteps | 1006928  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 0.756    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1026727  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.3    |
# | time/              |          |
# |    episodes        | 10175    |
# |    fps             | 10       |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 1007423  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.46     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1027222  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 10180    |
# |    fps             | 10       |
# |    time_elapsed    | 2770     |
# |    total_timesteps | 1007918  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.89     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1027717  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79.3    |
# | time/              |          |
# |    episodes        | 10185    |
# |    fps             | 10       |
# |    time_elapsed    | 2818     |
# |    total_timesteps | 1008413  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1028212  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.7    |
# | time/              |          |
# |    episodes        | 10190    |
# |    fps             | 10       |
# |    time_elapsed    | 2866     |
# |    total_timesteps | 1008908  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | 0.162    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1028707  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79      |
# | time/              |          |
# |    episodes        | 10195    |
# |    fps             | 10       |
# |    time_elapsed    | 2916     |
# |    total_timesteps | 1009403  |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -0.997   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1029202  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79      |
# | time/              |          |
# |    episodes        | 10200    |
# |    fps             | 10       |
# |    time_elapsed    | 2963     |
# |    total_timesteps | 1009898  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1029697  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10205    |
# |    fps             | 10       |
# |    time_elapsed    | 3011     |
# |    total_timesteps | 1010393  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1030192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10210    |
# |    fps             | 10       |
# |    time_elapsed    | 3059     |
# |    total_timesteps | 1010888  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | -0.0321  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1030687  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10215    |
# |    fps             | 10       |
# |    time_elapsed    | 3105     |
# |    total_timesteps | 1011383  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | -0.789   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1031182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 10220    |
# |    fps             | 10       |
# |    time_elapsed    | 3153     |
# |    total_timesteps | 1011878  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.0348   |
# |    ent_coef_loss   | -0.377   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1031677  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10225    |
# |    fps             | 10       |
# |    time_elapsed    | 3201     |
# |    total_timesteps | 1012373  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -0.969   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1032172  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10230    |
# |    fps             | 10       |
# |    time_elapsed    | 3250     |
# |    total_timesteps | 1012868  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.0334   |
# |    ent_coef_loss   | 0.161    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1032667  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10235    |
# |    fps             | 10       |
# |    time_elapsed    | 3300     |
# |    total_timesteps | 1013363  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0357   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1033162  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10240    |
# |    fps             | 10       |
# |    time_elapsed    | 3347     |
# |    total_timesteps | 1013858  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0326   |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1033657  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10245    |
# |    fps             | 10       |
# |    time_elapsed    | 3397     |
# |    total_timesteps | 1014353  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0304   |
# |    ent_coef_loss   | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1034152  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10250    |
# |    fps             | 10       |
# |    time_elapsed    | 3445     |
# |    total_timesteps | 1014848  |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | -0.251   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1034647  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.2    |
# | time/              |          |
# |    episodes        | 10255    |
# |    fps             | 10       |
# |    time_elapsed    | 3496     |
# |    total_timesteps | 1015343  |
# | train/             |          |
# |    actor_loss      | -96.2    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0322   |
# |    ent_coef_loss   | 1.41     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1035142  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10260    |
# |    fps             | 10       |
# |    time_elapsed    | 3544     |
# |    total_timesteps | 1015838  |
# | train/             |          |
# |    actor_loss      | -95      |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0301   |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1035637  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10265    |
# |    fps             | 10       |
# |    time_elapsed    | 3593     |
# |    total_timesteps | 1016333  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0329   |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1036132  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10270    |
# |    fps             | 10       |
# |    time_elapsed    | 3641     |
# |    total_timesteps | 1016828  |
# | train/             |          |
# |    actor_loss      | -93.3    |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | 0.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1036627  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82      |
# | time/              |          |
# |    episodes        | 10275    |
# |    fps             | 10       |
# |    time_elapsed    | 3689     |
# |    total_timesteps | 1017323  |
# | train/             |          |
# |    actor_loss      | -91.9    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | -0.898   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1037122  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.5    |
# | time/              |          |
# |    episodes        | 10280    |
# |    fps             | 10       |
# |    time_elapsed    | 3738     |
# |    total_timesteps | 1017818  |
# | train/             |          |
# |    actor_loss      | -93.8    |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1037617  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 10285    |
# |    fps             | 10       |
# |    time_elapsed    | 3786     |
# |    total_timesteps | 1018313  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | 0.484    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1038112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79.6    |
# | time/              |          |
# |    episodes        | 10290    |
# |    fps             | 10       |
# |    time_elapsed    | 3834     |
# |    total_timesteps | 1018808  |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.0315   |
# |    ent_coef_loss   | 0.0425   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1038607  |
# ---------------------------------
# ---------------------------------
# ...
# |    n_updates       | 1966237  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -0.06    |
# | time/              |          |
# |    episodes        | 19665    |
# |    fps             | 10       |
# |    time_elapsed    | 47604    |
# |    total_timesteps | 1946933  |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.00776  |
# |    ent_coef_loss   | 0.781    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1966732  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 0.15     |
# | time/              |          |
# |    episodes        | 19670    |
# |    fps             | 10       |
# |    time_elapsed    | 47645    |
# |    total_timesteps | 1947428  |
# | train/             |          |
# |    actor_loss      | -33.9    |
# |    critic_loss     | 4.04     |
# |    ent_coef        | 0.00787  |
# |    ent_coef_loss   | -1.97    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1967227  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -9.06    |
# | time/              |          |
# |    episodes        | 19675    |
# |    fps             | 10       |
# |    time_elapsed    | 47685    |
# |    total_timesteps | 1947923  |
# | train/             |          |
# |    actor_loss      | -37.2    |
# |    critic_loss     | 4.24     |
# |    ent_coef        | 0.0084   |
# |    ent_coef_loss   | 0.392    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1967722  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 0.99     |
# | time/              |          |
# |    episodes        | 19680    |
# |    fps             | 10       |
# |    time_elapsed    | 47723    |
# |    total_timesteps | 1948418  |
# | train/             |          |
# |    actor_loss      | -34.8    |
# |    critic_loss     | 4.13     |
# |    ent_coef        | 0.00759  |
# |    ent_coef_loss   | -0.596   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1968217  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -1.55    |
# | time/              |          |
# |    episodes        | 19685    |
# |    fps             | 10       |
# |    time_elapsed    | 47760    |
# |    total_timesteps | 1948913  |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.00803  |
# |    ent_coef_loss   | 0.383    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1968712  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 2.11     |
# | time/              |          |
# |    episodes        | 19690    |
# |    fps             | 10       |
# |    time_elapsed    | 47795    |
# |    total_timesteps | 1949408  |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.0078   |
# |    ent_coef_loss   | -0.427   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1969207  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -1.4     |
# | time/              |          |
# |    episodes        | 19695    |
# |    fps             | 10       |
# |    time_elapsed    | 47829    |
# |    total_timesteps | 1949903  |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.0079   |
# |    ent_coef_loss   | 0.848    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1969702  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 4.91     |
# | time/              |          |
# |    episodes        | 19700    |
# |    fps             | 10       |
# |    time_elapsed    | 47865    |
# |    total_timesteps | 1950398  |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.00853  |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1970197  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 19.5     |
# | time/              |          |
# |    episodes        | 19705    |
# |    fps             | 10       |
# |    time_elapsed    | 47898    |
# |    total_timesteps | 1950893  |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.00781  |
# |    ent_coef_loss   | -0.698   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1970692  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 25.7     |
# | time/              |          |
# |    episodes        | 19710    |
# |    fps             | 10       |
# |    time_elapsed    | 47935    |
# |    total_timesteps | 1951388  |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.00834  |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1971187  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 32       |
# | time/              |          |
# |    episodes        | 19715    |
# |    fps             | 10       |
# |    time_elapsed    | 47968    |
# |    total_timesteps | 1951883  |
# | train/             |          |
# |    actor_loss      | -34.4    |
# |    critic_loss     | 3.97     |
# |    ent_coef        | 0.00749  |
# |    ent_coef_loss   | -2.05    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1971682  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 32.5     |
# | time/              |          |
# |    episodes        | 19720    |
# |    fps             | 10       |
# |    time_elapsed    | 48004    |
# |    total_timesteps | 1952378  |
# | train/             |          |
# |    actor_loss      | -36.1    |
# |    critic_loss     | 4.07     |
# |    ent_coef        | 0.00825  |
# |    ent_coef_loss   | 0.0912   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1972177  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 32.5     |
# | time/              |          |
# |    episodes        | 19725    |
# |    fps             | 10       |
# |    time_elapsed    | 48038    |
# |    total_timesteps | 1952873  |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 4.02     |
# |    ent_coef        | 0.00718  |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1972672  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 26.9     |
# | time/              |          |
# |    episodes        | 19730    |
# |    fps             | 10       |
# |    time_elapsed    | 48075    |
# |    total_timesteps | 1953368  |
# | train/             |          |
# |    actor_loss      | -33.9    |
# |    critic_loss     | 4.1      |
# |    ent_coef        | 0.00765  |
# |    ent_coef_loss   | -0.962   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1973167  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 29.1     |
# | time/              |          |
# |    episodes        | 19735    |
# |    fps             | 10       |
# |    time_elapsed    | 48110    |
# |    total_timesteps | 1953863  |
# | train/             |          |
# |    actor_loss      | -35.5    |
# |    critic_loss     | 4.17     |
# |    ent_coef        | 0.00797  |
# |    ent_coef_loss   | -0.988   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1973662  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 25.6     |
# | time/              |          |
# |    episodes        | 19740    |
# |    fps             | 10       |
# |    time_elapsed    | 48147    |
# |    total_timesteps | 1954358  |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 4.12     |
# |    ent_coef        | 0.00724  |
# |    ent_coef_loss   | 1.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1974157  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 28.8     |
# | time/              |          |
# |    episodes        | 19745    |
# |    fps             | 10       |
# |    time_elapsed    | 48180    |
# |    total_timesteps | 1954853  |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 4.14     |
# |    ent_coef        | 0.00748  |
# |    ent_coef_loss   | 0.431    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1974652  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 25.7     |
# | time/              |          |
# |    episodes        | 19750    |
# |    fps             | 10       |
# |    time_elapsed    | 48216    |
# |    total_timesteps | 1955348  |
# | train/             |          |
# |    actor_loss      | -36      |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.00687  |
# |    ent_coef_loss   | -0.961   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1975147  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 28.9     |
# | time/              |          |
# |    episodes        | 19755    |
# |    fps             | 10       |
# |    time_elapsed    | 48253    |
# |    total_timesteps | 1955843  |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 4.15     |
# |    ent_coef        | 0.00742  |
# |    ent_coef_loss   | 0.396    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1975642  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 38.3     |
# | time/              |          |
# |    episodes        | 19760    |
# |    fps             | 10       |
# |    time_elapsed    | 48287    |
# |    total_timesteps | 1956338  |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 4.2      |
# |    ent_coef        | 0.0071   |
# |    ent_coef_loss   | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1976137  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 32.1     |
# | time/              |          |
# |    episodes        | 19765    |
# |    fps             | 10       |
# |    time_elapsed    | 48321    |
# |    total_timesteps | 1956833  |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.00721  |
# |    ent_coef_loss   | 0.842    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1976632  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 31.9     |
# | time/              |          |
# |    episodes        | 19770    |
# |    fps             | 10       |
# |    time_elapsed    | 48357    |
# |    total_timesteps | 1957328  |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 4.11     |
# |    ent_coef        | 0.00753  |
# |    ent_coef_loss   | 0.995    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1977127  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 40.8     |
# | time/              |          |
# |    episodes        | 19775    |
# |    fps             | 10       |
# |    time_elapsed    | 48392    |
# |    total_timesteps | 1957823  |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 4.05     |
# |    ent_coef        | 0.00745  |
# |    ent_coef_loss   | -0.851   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1977622  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 30.7     |
# | time/              |          |
# |    episodes        | 19780    |
# |    fps             | 10       |
# |    time_elapsed    | 48427    |
# |    total_timesteps | 1958318  |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 3.96     |
# |    ent_coef        | 0.00726  |
# |    ent_coef_loss   | -0.898   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1978117  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 34       |
# | time/              |          |
# |    episodes        | 19785    |
# |    fps             | 10       |
# |    time_elapsed    | 48461    |
# |    total_timesteps | 1958813  |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.00738  |
# |    ent_coef_loss   | 1.98     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1978612  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 28.4     |
# | time/              |          |
# |    episodes        | 19790    |
# |    fps             | 10       |
# |    time_elapsed    | 48494    |
# |    total_timesteps | 1959308  |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 4.16     |
# |    ent_coef        | 0.00716  |
# |    ent_coef_loss   | 1.83     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1979107  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 37.2     |
# | time/              |          |
# |    episodes        | 19795    |
# |    fps             | 10       |
# |    time_elapsed    | 48529    |
# |    total_timesteps | 1959803  |
# | train/             |          |
# |    actor_loss      | -36.7    |
# |    critic_loss     | 4.11     |
# |    ent_coef        | 0.00696  |
# |    ent_coef_loss   | 0.863    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1979602  |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# finish learning

# %%
print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start learning")
model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")
print("finish learning")
# Out:
# load_replay_buffer
# Output()
# start learning
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 34.5     |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 13       |
# |    time_elapsed    | 21       |
# |    total_timesteps | 1960298  |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 5.23     |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | 15.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1980097  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 19       |
# | time/              |          |
# |    episodes        | 19805    |
# |    fps             | 14       |
# |    time_elapsed    | 56       |
# |    total_timesteps | 1960793  |
# | train/             |          |
# |    actor_loss      | -97.4    |
# |    critic_loss     | 4.24     |
# |    ent_coef        | 0.0285   |
# |    ent_coef_loss   | 6.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1980592  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 12.7     |
# | time/              |          |
# |    episodes        | 19810    |
# |    fps             | 14       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 1961288  |
# | train/             |          |
# |    actor_loss      | -96      |
# |    critic_loss     | 4.41     |
# |    ent_coef        | 0.0348   |
# |    ent_coef_loss   | 1.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1981087  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 6.38     |
# | time/              |          |
# |    episodes        | 19815    |
# |    fps             | 13       |
# |    time_elapsed    | 130      |
# |    total_timesteps | 1961783  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 3.94     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | 1.86     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1981582  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 5.3      |
# | time/              |          |
# |    episodes        | 19820    |
# |    fps             | 13       |
# |    time_elapsed    | 166      |
# |    total_timesteps | 1962278  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.59     |
# |    ent_coef        | 0.0385   |
# |    ent_coef_loss   | 0.949    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1982077  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -4.22    |
# | time/              |          |
# |    episodes        | 19825    |
# |    fps             | 13       |
# |    time_elapsed    | 201      |
# |    total_timesteps | 1962773  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 3.61     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | 0.111    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1982572  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -7.43    |
# | time/              |          |
# |    episodes        | 19830    |
# |    fps             | 13       |
# |    time_elapsed    | 236      |
# |    total_timesteps | 1963268  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 3.63     |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | -1.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1983067  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -13.9    |
# | time/              |          |
# |    episodes        | 19835    |
# |    fps             | 13       |
# |    time_elapsed    | 276      |
# |    total_timesteps | 1963763  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 3.52     |
# |    ent_coef        | 0.0366   |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1983562  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -14.7    |
# | time/              |          |
# |    episodes        | 19840    |
# |    fps             | 13       |
# |    time_elapsed    | 313      |
# |    total_timesteps | 1964258  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 3.22     |
# |    ent_coef        | 0.0337   |
# |    ent_coef_loss   | -0.495   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1984057  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -18.1    |
# | time/              |          |
# |    episodes        | 19845    |
# |    fps             | 13       |
# |    time_elapsed    | 349      |
# |    total_timesteps | 1964753  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.76     |
# |    ent_coef        | 0.0303   |
# |    ent_coef_loss   | -0.0108  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1984552  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -21      |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 13       |
# |    time_elapsed    | 386      |
# |    total_timesteps | 1965248  |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0292   |
# |    ent_coef_loss   | -0.811   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1985047  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -23.6    |
# | time/              |          |
# |    episodes        | 19855    |
# |    fps             | 13       |
# |    time_elapsed    | 422      |
# |    total_timesteps | 1965743  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.0286   |
# |    ent_coef_loss   | -0.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1985542  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -35.7    |
# | time/              |          |
# |    episodes        | 19860    |
# |    fps             | 13       |
# |    time_elapsed    | 457      |
# |    total_timesteps | 1966238  |
# | train/             |          |
# |    actor_loss      | -99.1    |
# |    critic_loss     | 3.83     |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | -0.256   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1986037  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -37.4    |
# | time/              |          |
# |    episodes        | 19865    |
# |    fps             | 13       |
# |    time_elapsed    | 495      |
# |    total_timesteps | 1966733  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 3.3      |
# |    ent_coef        | 0.0336   |
# |    ent_coef_loss   | -0.0228  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1986532  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -40      |
# | time/              |          |
# |    episodes        | 19870    |
# |    fps             | 13       |
# |    time_elapsed    | 529      |
# |    total_timesteps | 1967228  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 5.15     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | 0.142    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1987027  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -49.5    |
# | time/              |          |
# |    episodes        | 19875    |
# |    fps             | 13       |
# |    time_elapsed    | 563      |
# |    total_timesteps | 1967723  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 3.81     |
# |    ent_coef        | 0.032    |
# |    ent_coef_loss   | -1.23    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1987522  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -49.9    |
# | time/              |          |
# |    episodes        | 19880    |
# |    fps             | 13       |
# |    time_elapsed    | 600      |
# |    total_timesteps | 1968218  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 3.14     |
# |    ent_coef        | 0.031    |
# |    ent_coef_loss   | -0.371   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1988017  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -55.8    |
# | time/              |          |
# |    episodes        | 19885    |
# |    fps             | 13       |
# |    time_elapsed    | 634      |
# |    total_timesteps | 1968713  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 3.91     |
# |    ent_coef        | 0.0287   |
# |    ent_coef_loss   | 0.435    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1988512  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -57      |
# | time/              |          |
# |    episodes        | 19890    |
# |    fps             | 13       |
# |    time_elapsed    | 669      |
# |    total_timesteps | 1969208  |
# | train/             |          |
# |    actor_loss      | -98.7    |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | 0.494    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1989007  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 19895    |
# |    fps             | 13       |
# |    time_elapsed    | 704      |
# |    total_timesteps | 1969703  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.0287   |
# |    ent_coef_loss   | 0.853    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1989502  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72.2    |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 13       |
# |    time_elapsed    | 739      |
# |    total_timesteps | 1970198  |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 3.67     |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | -0.482   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1989997  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -69.6    |
# | time/              |          |
# |    episodes        | 19905    |
# |    fps             | 13       |
# |    time_elapsed    | 774      |
# |    total_timesteps | 1970693  |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 3.58     |
# |    ent_coef        | 0.0276   |
# |    ent_coef_loss   | -0.379   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1990492  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 19910    |
# |    fps             | 13       |
# |    time_elapsed    | 811      |
# |    total_timesteps | 1971188  |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.0267   |
# |    ent_coef_loss   | -1.53    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1990987  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 19915    |
# |    fps             | 13       |
# |    time_elapsed    | 846      |
# |    total_timesteps | 1971683  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.12     |
# |    ent_coef        | 0.027    |
# |    ent_coef_loss   | 0.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1991482  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.4    |
# | time/              |          |
# |    episodes        | 19920    |
# |    fps             | 13       |
# |    time_elapsed    | 884      |
# |    total_timesteps | 1972178  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.22     |
# |    ent_coef        | 0.0269   |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1991977  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.8    |
# | time/              |          |
# |    episodes        | 19925    |
# |    fps             | 13       |
# |    time_elapsed    | 920      |
# |    total_timesteps | 1972673  |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 3.24     |
# |    ent_coef        | 0.0266   |
# |    ent_coef_loss   | -0.35    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1992472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.3    |
# | time/              |          |
# |    episodes        | 19930    |
# |    fps             | 13       |
# |    time_elapsed    | 956      |
# |    total_timesteps | 1973168  |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 3.5      |
# |    ent_coef        | 0.0261   |
# |    ent_coef_loss   | 0.447    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1992967  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -68.3    |
# | time/              |          |
# |    episodes        | 19935    |
# |    fps             | 13       |
# |    time_elapsed    | 992      |
# |    total_timesteps | 1973663  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 3.33     |
# |    ent_coef        | 0.0265   |
# |    ent_coef_loss   | 0.413    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1993462  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -70.7    |
# | time/              |          |
# |    episodes        | 19940    |
# |    fps             | 13       |
# |    time_elapsed    | 1029     |
# |    total_timesteps | 1974158  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 2.88     |
# |    ent_coef        | 0.0243   |
# |    ent_coef_loss   | 0.172    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1993957  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -71.4    |
# | time/              |          |
# |    episodes        | 19945    |
# |    fps             | 13       |
# |    time_elapsed    | 1066     |
# |    total_timesteps | 1974653  |
# | train/             |          |
# |    actor_loss      | -99.2    |
# |    critic_loss     | 2.7      |
# |    ent_coef        | 0.0252   |
# |    ent_coef_loss   | -1.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1994452  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 13       |
# |    time_elapsed    | 1101     |
# |    total_timesteps | 1975148  |
# | train/             |          |
# |    actor_loss      | -96.8    |
# |    critic_loss     | 3.07     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | 0.508    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1994947  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 19955    |
# |    fps             | 13       |
# |    time_elapsed    | 1140     |
# |    total_timesteps | 1975643  |
# | train/             |          |
# |    actor_loss      | -99.6    |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.0247   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1995442  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 19960    |
# |    fps             | 13       |
# |    time_elapsed    | 1175     |
# |    total_timesteps | 1976138  |
# | train/             |          |
# |    actor_loss      | -99.8    |
# |    critic_loss     | 2.76     |
# |    ent_coef        | 0.0241   |
# |    ent_coef_loss   | -1.68    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1995937  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.8    |
# | time/              |          |
# |    episodes        | 19965    |
# |    fps             | 13       |
# |    time_elapsed    | 1211     |
# |    total_timesteps | 1976633  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0221   |
# |    ent_coef_loss   | -0.694   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1996432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 19970    |
# |    fps             | 13       |
# |    time_elapsed    | 1248     |
# |    total_timesteps | 1977128  |
# | train/             |          |
# |    actor_loss      | -97.4    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0243   |
# |    ent_coef_loss   | -0.311   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1996927  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -60.2    |
# | time/              |          |
# |    episodes        | 19975    |
# |    fps             | 13       |
# |    time_elapsed    | 1285     |
# |    total_timesteps | 1977623  |
# | train/             |          |
# |    actor_loss      | -98.2    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.0245   |
# |    ent_coef_loss   | -0.223   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1997422  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.9    |
# | time/              |          |
# |    episodes        | 19980    |
# |    fps             | 13       |
# |    time_elapsed    | 1321     |
# |    total_timesteps | 1978118  |
# | train/             |          |
# |    actor_loss      | -96.9    |
# |    critic_loss     | 2.89     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | -0.664   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1997917  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.9    |
# | time/              |          |
# |    episodes        | 19985    |
# |    fps             | 13       |
# |    time_elapsed    | 1354     |
# |    total_timesteps | 1978613  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.83     |
# |    ent_coef        | 0.0231   |
# |    ent_coef_loss   | -0.706   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1998412  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.1    |
# | time/              |          |
# |    episodes        | 19990    |
# |    fps             | 13       |
# |    time_elapsed    | 1391     |
# |    total_timesteps | 1979108  |
# | train/             |          |
# |    actor_loss      | -95.8    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0251   |
# |    ent_coef_loss   | -0.199   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1998907  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.8    |
# | time/              |          |
# |    episodes        | 19995    |
# |    fps             | 13       |
# |    time_elapsed    | 1427     |
# |    total_timesteps | 1979603  |
# | train/             |          |
# |    actor_loss      | -97.3    |
# |    critic_loss     | 2.69     |
# |    ent_coef        | 0.0228   |
# |    ent_coef_loss   | -0.606   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1999402  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 13       |
# |    time_elapsed    | 1463     |
# |    total_timesteps | 1980098  |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 2.58     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | -0.391   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1999897  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 20005    |
# |    fps             | 13       |
# |    time_elapsed    | 1501     |
# |    total_timesteps | 1980593  |
# | train/             |          |
# |    actor_loss      | -97.4    |
# |    critic_loss     | 2.55     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | -0.829   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2000392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 20010    |
# |    fps             | 13       |
# |    time_elapsed    | 1536     |
# |    total_timesteps | 1981088  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0213   |
# |    ent_coef_loss   | 0.448    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2000887  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 20015    |
# |    fps             | 13       |
# |    time_elapsed    | 1570     |
# |    total_timesteps | 1981583  |
# | train/             |          |
# |    actor_loss      | -95.1    |
# |    critic_loss     | 2.46     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | -0.796   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2001382  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 20020    |
# |    fps             | 13       |
# |    time_elapsed    | 1605     |
# |    total_timesteps | 1982078  |
# | train/             |          |
# |    actor_loss      | -96.9    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.458   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2001877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -68.3    |
# | time/              |          |
# |    episodes        | 20025    |
# |    fps             | 13       |
# |    time_elapsed    | 1641     |
# |    total_timesteps | 1982573  |
# | train/             |          |
# |    actor_loss      | -96.4    |
# |    critic_loss     | 2.61     |
# |    ent_coef        | 0.0216   |
# |    ent_coef_loss   | -0.104   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2002372  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 20030    |
# |    fps             | 13       |
# |    time_elapsed    | 1675     |
# |    total_timesteps | 1983068  |
# | train/             |          |
# |    actor_loss      | -95.4    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 1.09     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2002867  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.8    |
# | time/              |          |
# |    episodes        | 20035    |
# |    fps             | 13       |
# |    time_elapsed    | 1710     |
# |    total_timesteps | 1983563  |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | -1.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2003362  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -60.2    |
# | time/              |          |
# |    episodes        | 20040    |
# |    fps             | 13       |
# |    time_elapsed    | 1747     |
# |    total_timesteps | 1984058  |
# | train/             |          |
# |    actor_loss      | -93.7    |
# |    critic_loss     | 2.93     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | -1.28    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2003857  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.5    |
# | time/              |          |
# |    episodes        | 20045    |
# |    fps             | 13       |
# |    time_elapsed    | 1782     |
# |    total_timesteps | 1984553  |
# | train/             |          |
# |    actor_loss      | -93.7    |
# |    critic_loss     | 2.88     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 1.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2004352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 20050    |
# |    fps             | 13       |
# |    time_elapsed    | 1819     |
# |    total_timesteps | 1985048  |
# | train/             |          |
# |    actor_loss      | -95.9    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0191   |
# |    ent_coef_loss   | -1.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2004847  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 20055    |
# |    fps             | 13       |
# |    time_elapsed    | 1853     |
# |    total_timesteps | 1985543  |
# | train/             |          |
# |    actor_loss      | -93.3    |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0184   |
# |    ent_coef_loss   | -0.734   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2005342  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62.2    |
# | time/              |          |
# |    episodes        | 20060    |
# |    fps             | 13       |
# |    time_elapsed    | 1889     |
# |    total_timesteps | 1986038  |
# | train/             |          |
# |    actor_loss      | -96.7    |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2005837  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -60.6    |
# | time/              |          |
# |    episodes        | 20065    |
# |    fps             | 13       |
# |    time_elapsed    | 1925     |
# |    total_timesteps | 1986533  |
# | train/             |          |
# |    actor_loss      | -96.6    |
# |    critic_loss     | 2.36     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | -0.295   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2006332  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -60.6    |
# | time/              |          |
# |    episodes        | 20070    |
# |    fps             | 13       |
# |    time_elapsed    | 1962     |
# |    total_timesteps | 1987028  |
# | train/             |          |
# |    actor_loss      | -94      |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 0.351    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2006827  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 20075    |
# |    fps             | 13       |
# |    time_elapsed    | 1998     |
# |    total_timesteps | 1987523  |
# | train/             |          |
# |    actor_loss      | -95.3    |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | -1.59    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2007322  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.6    |
# | time/              |          |
# |    episodes        | 20080    |
# |    fps             | 13       |
# |    time_elapsed    | 2036     |
# |    total_timesteps | 1988018  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -0.351   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2007817  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 20085    |
# |    fps             | 13       |
# |    time_elapsed    | 2071     |
# |    total_timesteps | 1988513  |
# | train/             |          |
# |    actor_loss      | -94.4    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 0.517    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2008312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -69.4    |
# | time/              |          |
# |    episodes        | 20090    |
# |    fps             | 13       |
# |    time_elapsed    | 2108     |
# |    total_timesteps | 1989008  |
# | train/             |          |
# |    actor_loss      | -95.4    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.0163   |
# |    ent_coef_loss   | 1.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2008807  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.7    |
# | time/              |          |
# |    episodes        | 20095    |
# |    fps             | 13       |
# |    time_elapsed    | 2144     |
# |    total_timesteps | 1989503  |
# | train/             |          |
# |    actor_loss      | -93.3    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -0.663   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2009302  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.2    |
# | time/              |          |
# |    episodes        | 20100    |
# |    fps             | 13       |
# |    time_elapsed    | 2182     |
# |    total_timesteps | 1989998  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | 1.94     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2009797  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.3    |
# | time/              |          |
# |    episodes        | 20105    |
# |    fps             | 13       |
# |    time_elapsed    | 2216     |
# |    total_timesteps | 1990493  |
# | train/             |          |
# |    actor_loss      | -90.6    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0182   |
# |    ent_coef_loss   | 0.0306   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2010292  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.3    |
# | time/              |          |
# |    episodes        | 20110    |
# |    fps             | 13       |
# |    time_elapsed    | 2252     |
# |    total_timesteps | 1990988  |
# | train/             |          |
# |    actor_loss      | -90.8    |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -2.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2010787  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -61.3    |
# | time/              |          |
# |    episodes        | 20115    |
# |    fps             | 13       |
# |    time_elapsed    | 2289     |
# |    total_timesteps | 1991483  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.02     |
# |    ent_coef_loss   | 0.388    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2011282  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -61.3    |
# | time/              |          |
# |    episodes        | 20120    |
# |    fps             | 13       |
# |    time_elapsed    | 2326     |
# |    total_timesteps | 1991978  |
# | train/             |          |
# |    actor_loss      | -94.7    |
# |    critic_loss     | 2.36     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | 1.01     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2011777  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -58.9    |
# | time/              |          |
# |    episodes        | 20125    |
# |    fps             | 13       |
# |    time_elapsed    | 2362     |
# |    total_timesteps | 1992473  |
# | train/             |          |
# |    actor_loss      | -94.2    |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.0196   |
# |    ent_coef_loss   | 0.0356   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2012272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -61.4    |
# | time/              |          |
# |    episodes        | 20130    |
# |    fps             | 13       |
# |    time_elapsed    | 2397     |
# |    total_timesteps | 1992968  |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | 0.237    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2012767  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -61.4    |
# | time/              |          |
# |    episodes        | 20135    |
# |    fps             | 13       |
# |    time_elapsed    | 2433     |
# |    total_timesteps | 1993463  |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 2.58     |
# |    ent_coef        | 0.0184   |
# |    ent_coef_loss   | 0.233    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2013262  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 20140    |
# |    fps             | 13       |
# |    time_elapsed    | 2471     |
# |    total_timesteps | 1993958  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0187   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2013757  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.4    |
# | time/              |          |
# |    episodes        | 20145    |
# |    fps             | 13       |
# |    time_elapsed    | 2506     |
# |    total_timesteps | 1994453  |
# | train/             |          |
# |    actor_loss      | -92.7    |
# |    critic_loss     | 2.29     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | 0.245    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2014252  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -61.4    |
# | time/              |          |
# |    episodes        | 20150    |
# |    fps             | 13       |
# |    time_elapsed    | 2543     |
# |    total_timesteps | 1994948  |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 2.44     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2014747  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -60.9    |
# | time/              |          |
# |    episodes        | 20155    |
# |    fps             | 13       |
# |    time_elapsed    | 2578     |
# |    total_timesteps | 1995443  |
# | train/             |          |
# |    actor_loss      | -90.8    |
# |    critic_loss     | 2.56     |
# |    ent_coef        | 0.0177   |
# |    ent_coef_loss   | 0.0494   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2015242  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.5    |
# | time/              |          |
# |    episodes        | 20160    |
# |    fps             | 13       |
# |    time_elapsed    | 2614     |
# |    total_timesteps | 1995938  |
# | train/             |          |
# |    actor_loss      | -91.8    |
# |    critic_loss     | 2.62     |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | -0.506   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2015737  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67      |
# | time/              |          |
# |    episodes        | 20165    |
# |    fps             | 13       |
# |    time_elapsed    | 2648     |
# |    total_timesteps | 1996433  |
# | train/             |          |
# |    actor_loss      | -91.1    |
# |    critic_loss     | 2.55     |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | 0.446    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2016232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -69.6    |
# | time/              |          |
# |    episodes        | 20170    |
# |    fps             | 13       |
# |    time_elapsed    | 2686     |
# |    total_timesteps | 1996928  |
# | train/             |          |
# |    actor_loss      | -93.5    |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | 0.49     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2016727  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -69.1    |
# | time/              |          |
# |    episodes        | 20175    |
# |    fps             | 13       |
# |    time_elapsed    | 2722     |
# |    total_timesteps | 1997423  |
# | train/             |          |
# |    actor_loss      | -92.5    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | 0.188    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2017222  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.2    |
# | time/              |          |
# |    episodes        | 20180    |
# |    fps             | 13       |
# |    time_elapsed    | 2757     |
# |    total_timesteps | 1997918  |
# | train/             |          |
# |    actor_loss      | -93      |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -0.66    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2017717  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.2    |
# | time/              |          |
# |    episodes        | 20185    |
# |    fps             | 13       |
# |    time_elapsed    | 2794     |
# |    total_timesteps | 1998413  |
# | train/             |          |
# |    actor_loss      | -92.1    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 0.162    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2018212  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -63.3    |
# | time/              |          |
# |    episodes        | 20190    |
# |    fps             | 13       |
# |    time_elapsed    | 2829     |
# |    total_timesteps | 1998908  |
# | train/             |          |
# |    actor_loss      | -92.3    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0209   |
# |    ent_coef_loss   | -0.078   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2018707  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.8    |
# | time/              |          |
# |    episodes        | 20195    |
# |    fps             | 13       |
# |    time_elapsed    | 2866     |
# |    total_timesteps | 1999403  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 0.0775   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2019202  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -68.3    |
# | time/              |          |
# |    episodes        | 20200    |
# |    fps             | 13       |
# |    time_elapsed    | 2902     |
# |    total_timesteps | 1999898  |
# | train/             |          |
# |    actor_loss      | -90.4    |
# |    critic_loss     | 2.94     |
# |    ent_coef        | 0.0205   |
# |    ent_coef_loss   | 0.267    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2019697  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -65.7    |
# | time/              |          |
# |    episodes        | 20205    |
# |    fps             | 13       |
# |    time_elapsed    | 2940     |
# |    total_timesteps | 2000393  |
# | train/             |          |
# |    actor_loss      | -92.2    |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -0.862   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2020192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -68.2    |
# | time/              |          |
# |    episodes        | 20210    |
# |    fps             | 13       |
# |    time_elapsed    | 2974     |
# |    total_timesteps | 2000888  |
# | train/             |          |
# |    actor_loss      | -90      |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.0175   |
# |    ent_coef_loss   | 0.0387   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2020687  |
# ...
# |    fps             | 12       |
# |    time_elapsed    | 1294     |
# |    total_timesteps | 2475593  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.028    |
# |    ent_coef_loss   | -0.905   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2495392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72.3    |
# | time/              |          |
# |    episodes        | 25010    |
# |    fps             | 11       |
# |    time_elapsed    | 1343     |
# |    total_timesteps | 2476088  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.05     |
# |    ent_coef        | 0.0282   |
# |    ent_coef_loss   | -2.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2495887  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -74.9    |
# | time/              |          |
# |    episodes        | 25015    |
# |    fps             | 11       |
# |    time_elapsed    | 1390     |
# |    total_timesteps | 2476583  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.0273   |
# |    ent_coef_loss   | -0.582   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2496382  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.5    |
# | time/              |          |
# |    episodes        | 25020    |
# |    fps             | 11       |
# |    time_elapsed    | 1440     |
# |    total_timesteps | 2477078  |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 2.19     |
# |    ent_coef        | 0.0262   |
# |    ent_coef_loss   | 0.574    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2496877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -66.5    |
# | time/              |          |
# |    episodes        | 25025    |
# |    fps             | 11       |
# |    time_elapsed    | 1490     |
# |    total_timesteps | 2477573  |
# | train/             |          |
# |    actor_loss      | -108     |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0253   |
# |    ent_coef_loss   | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2497372  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -63.6    |
# | time/              |          |
# |    episodes        | 25030    |
# |    fps             | 11       |
# |    time_elapsed    | 1539     |
# |    total_timesteps | 2478068  |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0253   |
# |    ent_coef_loss   | 0.319    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2497867  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -62      |
# | time/              |          |
# |    episodes        | 25035    |
# |    fps             | 11       |
# |    time_elapsed    | 1591     |
# |    total_timesteps | 2478563  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.04     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -0.209   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2498362  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -58.6    |
# | time/              |          |
# |    episodes        | 25040    |
# |    fps             | 11       |
# |    time_elapsed    | 1640     |
# |    total_timesteps | 2479058  |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | -0.806   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2498857  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -51.9    |
# | time/              |          |
# |    episodes        | 25045    |
# |    fps             | 11       |
# |    time_elapsed    | 1690     |
# |    total_timesteps | 2479553  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0234   |
# |    ent_coef_loss   | -0.0809  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2499352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -39.8    |
# | time/              |          |
# |    episodes        | 25425    |
# |    fps             | 10       |
# |    time_elapsed    | 5465     |
# |    total_timesteps | 2517173  |
# | train/             |          |
# |    actor_loss      | -92      |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 0.684    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2536972  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -45.3    |
# | time/              |          |
# |    episodes        | 25430    |
# |    fps             | 10       |
# |    time_elapsed    | 5514     |
# |    total_timesteps | 2517668  |
# | train/             |          |
# |    actor_loss      | -91.5    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -0.523   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2537467  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 25435    |
# |    fps             | 10       |
# |    time_elapsed    | 5561     |
# |    total_timesteps | 2518163  |
# | train/             |          |
# |    actor_loss      | -91.2    |
# |    critic_loss     | 2.88     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | -0.292   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2537962  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -45.2    |
# | time/              |          |
# |    episodes        | 25440    |
# |    fps             | 10       |
# |    time_elapsed    | 5609     |
# |    total_timesteps | 2518658  |
# | train/             |          |
# |    actor_loss      | -91.6    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0166   |
# |    ent_coef_loss   | 0.685    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2538457  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -47.7    |
# | time/              |          |
# |    episodes        | 25445    |
# |    fps             | 10       |
# |    time_elapsed    | 5661     |
# |    total_timesteps | 2519153  |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.0182   |
# |    ent_coef_loss   | -2.49    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2538952  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -46.4    |
# | time/              |          |
# |    episodes        | 25450    |
# |    fps             | 10       |
# |    time_elapsed    | 5709     |
# |    total_timesteps | 2519648  |
# | train/             |          |
# |    actor_loss      | -91      |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | 2.93     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2539447  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -48.9    |
# | time/              |          |
# |    episodes        | 25455    |
# |    fps             | 10       |
# |    time_elapsed    | 5761     |
# |    total_timesteps | 2520143  |
# | train/             |          |
# |    actor_loss      | -91.3    |
# |    critic_loss     | 2.85     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -0.498   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2539942  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -43.4    |
# | time/              |          |
# |    episodes        | 25460    |
# |    fps             | 10       |
# |    time_elapsed    | 5809     |
# |    total_timesteps | 2520638  |
# | train/             |          |
# |    actor_loss      | -91.8    |
# |    critic_loss     | 2.83     |
# |    ent_coef        | 0.0201   |
# |    ent_coef_loss   | -0.47    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2540437  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -39.9    |
# | time/              |          |
# |    episodes        | 25465    |
# |    fps             | 10       |
# |    time_elapsed    | 5861     |
# |    total_timesteps | 2521133  |
# | train/             |          |
# |    actor_loss      | -89.3    |
# |    critic_loss     | 2.38     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | 0.106    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2540932  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.7    |
# | time/              |          |
# |    episodes        | 25470    |
# |    fps             | 10       |
# |    time_elapsed    | 5910     |
# |    total_timesteps | 2521628  |
# | train/             |          |
# |    actor_loss      | -87.7    |
# |    critic_loss     | 3        |
# |    ent_coef        | 0.0204   |
# |    ent_coef_loss   | 0.948    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2541427  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -43.2    |
# | time/              |          |
# |    episodes        | 25475    |
# |    fps             | 10       |
# |    time_elapsed    | 5959     |
# |    total_timesteps | 2522123  |
# | train/             |          |
# |    actor_loss      | -88.9    |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -0.566   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2541922  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.6    |
# | time/              |          |
# |    episodes        | 25480    |
# |    fps             | 10       |
# |    time_elapsed    | 6009     |
# |    total_timesteps | 2522618  |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 2.83     |
# |    ent_coef        | 0.0207   |
# |    ent_coef_loss   | 0.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2542417  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -43.3    |
# | time/              |          |
# |    episodes        | 25485    |
# |    fps             | 10       |
# |    time_elapsed    | 6059     |
# |    total_timesteps | 2523113  |
# | train/             |          |
# |    actor_loss      | -90.2    |
# |    critic_loss     | 2.65     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -0.305   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2542912  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -38.7    |
# | time/              |          |
# |    episodes        | 25490    |
# |    fps             | 10       |
# |    time_elapsed    | 6109     |
# |    total_timesteps | 2523608  |
# | train/             |          |
# |    actor_loss      | -87.5    |
# |    critic_loss     | 3.5      |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2543407  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -29.9    |
# | time/              |          |
# |    episodes        | 25495    |
# |    fps             | 10       |
# |    time_elapsed    | 6156     |
# |    total_timesteps | 2524103  |
# | train/             |          |
# |    actor_loss      | -90.4    |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -0.448   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2543902  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -35.7    |
# | time/              |          |
# |    episodes        | 25500    |
# |    fps             | 10       |
# |    time_elapsed    | 6207     |
# |    total_timesteps | 2524598  |
# | train/             |          |
# |    actor_loss      | -88.5    |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.0197   |
# |    ent_coef_loss   | 2.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2544397  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.1    |
# | time/              |          |
# |    episodes        | 25505    |
# |    fps             | 10       |
# |    time_elapsed    | 6256     |
# |    total_timesteps | 2525093  |
# | train/             |          |
# |    actor_loss      | -89.5    |
# |    critic_loss     | 2.61     |
# |    ent_coef        | 0.0182   |
# |    ent_coef_loss   | 0.0494   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2544892  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.7    |
# | time/              |          |
# |    episodes        | 25510    |
# |    fps             | 10       |
# |    time_elapsed    | 6306     |
# |    total_timesteps | 2525588  |
# | train/             |          |
# |    actor_loss      | -87      |
# |    critic_loss     | 3.06     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | -1.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2545387  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -45.5    |
# | time/              |          |
# |    episodes        | 25515    |
# |    fps             | 10       |
# |    time_elapsed    | 6357     |
# |    total_timesteps | 2526083  |
# | train/             |          |
# |    actor_loss      | -89.6    |
# |    critic_loss     | 2.8      |
# |    ent_coef        | 0.0212   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2545882  |
# ---------------------------------

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlaceMultiObject-v0",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 2
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

# model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
#              policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
#              replay_buffer_class=HerReplayBuffer,
#              replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
#              tau=0.05, learning_starts=200, verbose=1)

model = TQC.load(f"data/seed_{seed}/tqc_model_1957000_steps", env=env)
model.set_env(env)

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start learning")
model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")
print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# load_replay_buffer
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/her/her_replay_buffer.py:394: UserWarning: The last trajectory in the replay buffer will be truncated.
# If you are in the same episode as when the replay buffer was saved,
# you should use `truncate_last_trajectory=False` to avoid that issue.
#   warnings.warn(
# start learning
# Output()
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:219:
# DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is
# recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:225:
# DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:165: UserWarning:
# WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gymnasium/core.py:311: UserWarning: WARN:
# env.compute_reward to get variables from other wrappers is deprecated and will be removed in v1.0, to get this
# variable you can do `env.unwrapped.compute_reward` for environment variables or
# `env.get_wrapper_attr('compute_reward')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 28.7     |
# | time/              |          |
# |    episodes        | 19770    |
# |    fps             | 9        |
# |    time_elapsed    | 42       |
# |    total_timesteps | 1957396  |
# | train/             |          |
# |    actor_loss      | -28.9    |
# |    critic_loss     | 4.47     |
# |    ent_coef        | 0.0183   |
# |    ent_coef_loss   | 4.04     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1977194  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 28.2     |
# | time/              |          |
# |    episodes        | 19775    |
# |    fps             | 9        |
# |    time_elapsed    | 96       |
# |    total_timesteps | 1957891  |
# | train/             |          |
# |    actor_loss      | -32.1    |
# |    critic_loss     | 4.39     |
# |    ent_coef        | 0.0219   |
# |    ent_coef_loss   | 4.99     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1977689  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 14.9     |
# | time/              |          |
# |    episodes        | 19780    |
# |    fps             | 9        |
# |    time_elapsed    | 151      |
# |    total_timesteps | 1958386  |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 3.86     |
# |    ent_coef        | 0.0232   |
# |    ent_coef_loss   | 0.368    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1978184  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 11.8     |
# | time/              |          |
# |    episodes        | 19785    |
# |    fps             | 9        |
# |    time_elapsed    | 205      |
# |    total_timesteps | 1958881  |
# | train/             |          |
# |    actor_loss      | -40.5    |
# |    critic_loss     | 4.21     |
# |    ent_coef        | 0.0237   |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1978679  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 2.6      |
# | time/              |          |
# |    episodes        | 19790    |
# |    fps             | 9        |
# |    time_elapsed    | 258      |
# |    total_timesteps | 1959376  |
# | train/             |          |
# |    actor_loss      | -42.8    |
# |    critic_loss     | 4.94     |
# |    ent_coef        | 0.0244   |
# |    ent_coef_loss   | 4.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1979174  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -0.55    |
# | time/              |          |
# |    episodes        | 19795    |
# |    fps             | 9        |
# |    time_elapsed    | 312      |
# |    total_timesteps | 1959871  |
# | train/             |          |
# |    actor_loss      | -60.1    |
# |    critic_loss     | 6.58     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | 18.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1979669  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -10      |
# | time/              |          |
# |    episodes        | 19800    |
# |    fps             | 9        |
# |    time_elapsed    | 365      |
# |    total_timesteps | 1960366  |
# | train/             |          |
# |    actor_loss      | -65.4    |
# |    critic_loss     | 10.5     |
# |    ent_coef        | 0.0564   |
# |    ent_coef_loss   | 15.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1980164  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -25.6    |
# | time/              |          |
# |    episodes        | 19805    |
# |    fps             | 9        |
# |    time_elapsed    | 416      |
# |    total_timesteps | 1960861  |
# | train/             |          |
# |    actor_loss      | -49      |
# |    critic_loss     | 14.4     |
# |    ent_coef        | 0.0803   |
# |    ent_coef_loss   | 3.67     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1980659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -31.8    |
# | time/              |          |
# |    episodes        | 19810    |
# |    fps             | 9        |
# |    time_elapsed    | 469      |
# |    total_timesteps | 1961356  |
# | train/             |          |
# |    actor_loss      | -25.5    |
# |    critic_loss     | 13.3     |
# |    ent_coef        | 0.0694   |
# |    ent_coef_loss   | -7.53    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1981154  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -38.2    |
# | time/              |          |
# |    episodes        | 19815    |
# |    fps             | 9        |
# |    time_elapsed    | 522      |
# |    total_timesteps | 1961851  |
# | train/             |          |
# |    actor_loss      | -32.4    |
# |    critic_loss     | 4.13     |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | -14.7    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1981649  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -41.8    |
# | time/              |          |
# |    episodes        | 19820    |
# |    fps             | 9        |
# |    time_elapsed    | 576      |
# |    total_timesteps | 1962346  |
# | train/             |          |
# |    actor_loss      | -38.7    |
# |    critic_loss     | 3.53     |
# |    ent_coef        | 0.0248   |
# |    ent_coef_loss   | -11      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1982144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -51.3    |
# | time/              |          |
# |    episodes        | 19825    |
# |    fps             | 9        |
# |    time_elapsed    | 631      |
# |    total_timesteps | 1962841  |
# | train/             |          |
# |    actor_loss      | -40      |
# |    critic_loss     | 3.49     |
# |    ent_coef        | 0.0181   |
# |    ent_coef_loss   | -5.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1982639  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -55.1    |
# | time/              |          |
# |    episodes        | 19830    |
# |    fps             | 9        |
# |    time_elapsed    | 684      |
# |    total_timesteps | 1963336  |
# | train/             |          |
# |    actor_loss      | -40.9    |
# |    critic_loss     | 3.88     |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | 2.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1983134  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -64.6    |
# | time/              |          |
# |    episodes        | 19835    |
# |    fps             | 9        |
# |    time_elapsed    | 737      |
# |    total_timesteps | 1963831  |
# | train/             |          |
# |    actor_loss      | -39.3    |
# |    critic_loss     | 3.92     |
# |    ent_coef        | 0.0214   |
# |    ent_coef_loss   | -0.605   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1983629  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -67.8    |
# | time/              |          |
# |    episodes        | 19840    |
# |    fps             | 9        |
# |    time_elapsed    | 790      |
# |    total_timesteps | 1964326  |
# | train/             |          |
# |    actor_loss      | -46.3    |
# |    critic_loss     | 5.45     |
# |    ent_coef        | 0.033    |
# |    ent_coef_loss   | 8.65     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1984124  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -74.1    |
# | time/              |          |
# |    episodes        | 19845    |
# |    fps             | 9        |
# |    time_elapsed    | 843      |
# |    total_timesteps | 1964821  |
# | train/             |          |
# |    actor_loss      | -47.9    |
# |    critic_loss     | 9.1      |
# |    ent_coef        | 0.0466   |
# |    ent_coef_loss   | -1.63    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1984619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -77      |
# | time/              |          |
# |    episodes        | 19850    |
# |    fps             | 9        |
# |    time_elapsed    | 898      |
# |    total_timesteps | 1965316  |
# | train/             |          |
# |    actor_loss      | -32      |
# |    critic_loss     | 7.13     |
# |    ent_coef        | 0.0254   |
# |    ent_coef_loss   | -18.4    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1985114  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.2    |
# | time/              |          |
# |    episodes        | 19855    |
# |    fps             | 9        |
# |    time_elapsed    | 952      |
# |    total_timesteps | 1965811  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 4.03     |
# |    ent_coef        | 0.0136   |
# |    ent_coef_loss   | -10.6    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1985609  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -92.8    |
# | time/              |          |
# |    episodes        | 19860    |
# |    fps             | 9        |
# |    time_elapsed    | 1006     |
# |    total_timesteps | 1966306  |
# | train/             |          |
# |    actor_loss      | -38.4    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0101   |
# |    ent_coef_loss   | -3.84    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1986104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19865    |
# |    fps             | 9        |
# |    time_elapsed    | 1060     |
# |    total_timesteps | 1966801  |
# | train/             |          |
# |    actor_loss      | -37.1    |
# |    critic_loss     | 2.75     |
# |    ent_coef        | 0.00963  |
# |    ent_coef_loss   | 0.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1986599  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19870    |
# |    fps             | 9        |
# |    time_elapsed    | 1113     |
# |    total_timesteps | 1967296  |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.0107   |
# |    ent_coef_loss   | 3.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1987094  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19875    |
# |    fps             | 9        |
# |    time_elapsed    | 1166     |
# |    total_timesteps | 1967791  |
# | train/             |          |
# |    actor_loss      | -37.3    |
# |    critic_loss     | 2.65     |
# |    ent_coef        | 0.00874  |
# |    ent_coef_loss   | -2.87    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1987589  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19880    |
# |    fps             | 9        |
# |    time_elapsed    | 1219     |
# |    total_timesteps | 1968286  |
# | train/             |          |
# |    actor_loss      | -36.4    |
# |    critic_loss     | 2.72     |
# |    ent_coef        | 0.00715  |
# |    ent_coef_loss   | -3.34    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1988084  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19885    |
# |    fps             | 9        |
# |    time_elapsed    | 1272     |
# |    total_timesteps | 1968781  |
# | train/             |          |
# |    actor_loss      | -37      |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.00698  |
# |    ent_coef_loss   | 3.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1988579  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 19890    |
# |    fps             | 9        |
# |    time_elapsed    | 1324     |
# |    total_timesteps | 1969276  |
# | train/             |          |
# |    actor_loss      | -36.9    |
# |    critic_loss     | 2.89     |
# |    ent_coef        | 0.00782  |
# |    ent_coef_loss   | -0.219   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1989074  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.1    |
# | time/              |          |
# |    episodes        | 19895    |
# |    fps             | 9        |
# |    time_elapsed    | 1378     |
# |    total_timesteps | 1969771  |
# | train/             |          |
# |    actor_loss      | -36.4    |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.0069   |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1989569  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.1    |
# | time/              |          |
# |    episodes        | 19900    |
# |    fps             | 9        |
# |    time_elapsed    | 1431     |
# |    total_timesteps | 1970266  |
# | train/             |          |
# |    actor_loss      | -37      |
# |    critic_loss     | 3.02     |
# |    ent_coef        | 0.00603  |
# |    ent_coef_loss   | -2.98    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1990064  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.1    |
# | time/              |          |
# |    episodes        | 19905    |
# |    fps             | 9        |
# |    time_elapsed    | 1484     |
# |    total_timesteps | 1970761  |
# | train/             |          |
# |    actor_loss      | -36.8    |
# |    critic_loss     | 2.89     |
# |    ent_coef        | 0.00611  |
# |    ent_coef_loss   | -0.655   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1990559  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -95.6    |
# | time/              |          |
# |    episodes        | 19910    |
# |    fps             | 9        |
# |    time_elapsed    | 1535     |
# |    total_timesteps | 1971256  |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 2.85     |
# |    ent_coef        | 0.00667  |
# |    ent_coef_loss   | -0.569   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1991054  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -95.6    |
# | time/              |          |
# |    episodes        | 19915    |
# |    fps             | 9        |
# |    time_elapsed    | 1587     |
# |    total_timesteps | 1971751  |
# | train/             |          |
# |    actor_loss      | -36.1    |
# |    critic_loss     | 3.03     |
# |    ent_coef        | 0.00628  |
# |    ent_coef_loss   | 2.1      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1991549  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    episodes        | 19920    |
# |    fps             | 9        |
# |    time_elapsed    | 1640     |
# |    total_timesteps | 1972246  |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 2.79     |
# |    ent_coef        | 0.00598  |
# |    ent_coef_loss   | -0.268   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1992044  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.5    |
# | time/              |          |
# |    episodes        | 19925    |
# |    fps             | 9        |
# |    time_elapsed    | 1693     |
# |    total_timesteps | 1972741  |
# | train/             |          |
# |    actor_loss      | -35      |
# |    critic_loss     | 2.91     |
# |    ent_coef        | 0.00592  |
# |    ent_coef_loss   | -2.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1992539  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.5    |
# | time/              |          |
# |    episodes        | 19930    |
# |    fps             | 9        |
# |    time_elapsed    | 1747     |
# |    total_timesteps | 1973236  |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.00557  |
# |    ent_coef_loss   | -1.11    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1993034  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 19935    |
# |    fps             | 9        |
# |    time_elapsed    | 1791     |
# |    total_timesteps | 1973731  |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.00495  |
# |    ent_coef_loss   | -1.54    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1993529  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 19940    |
# |    fps             | 9        |
# |    time_elapsed    | 1834     |
# |    total_timesteps | 1974226  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 2.62     |
# |    ent_coef        | 0.0041   |
# |    ent_coef_loss   | -3.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1994024  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 19945    |
# |    fps             | 9        |
# |    time_elapsed    | 1877     |
# |    total_timesteps | 1974721  |
# | train/             |          |
# |    actor_loss      | -35.4    |
# |    critic_loss     | 2.74     |
# |    ent_coef        | 0.00398  |
# |    ent_coef_loss   | -2.19    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1994519  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.8    |
# | time/              |          |
# |    episodes        | 19950    |
# |    fps             | 9        |
# |    time_elapsed    | 1920     |
# |    total_timesteps | 1975216  |
# | train/             |          |
# |    actor_loss      | -33.4    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.005    |
# |    ent_coef_loss   | -0.768   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1995014  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.3    |
# | time/              |          |
# |    episodes        | 19955    |
# |    fps             | 9        |
# |    time_elapsed    | 1962     |
# |    total_timesteps | 1975711  |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.00511  |
# |    ent_coef_loss   | -2.93    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1995509  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.5    |
# | time/              |          |
# |    episodes        | 19960    |
# |    fps             | 9        |
# |    time_elapsed    | 2004     |
# |    total_timesteps | 1976206  |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 2.84     |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | 1.28     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1996004  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    episodes        | 19965    |
# |    fps             | 9        |
# |    time_elapsed    | 2047     |
# |    total_timesteps | 1976701  |
# | train/             |          |
# |    actor_loss      | -34.6    |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.00501  |
# |    ent_coef_loss   | -1.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1996499  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86      |
# | time/              |          |
# |    episodes        | 19970    |
# |    fps             | 9        |
# |    time_elapsed    | 2090     |
# |    total_timesteps | 1977196  |
# | train/             |          |
# |    actor_loss      | -35      |
# |    critic_loss     | 2.78     |
# |    ent_coef        | 0.00428  |
# |    ent_coef_loss   | 0.142    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1996994  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86      |
# | time/              |          |
# |    episodes        | 19975    |
# |    fps             | 9        |
# |    time_elapsed    | 2140     |
# |    total_timesteps | 1977691  |
# | train/             |          |
# |    actor_loss      | -34.4    |
# |    critic_loss     | 2.56     |
# |    ent_coef        | 0.00439  |
# |    ent_coef_loss   | -0.614   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1997489  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86      |
# | time/              |          |
# |    episodes        | 19980    |
# |    fps             | 9        |
# |    time_elapsed    | 2193     |
# |    total_timesteps | 1978186  |
# | train/             |          |
# |    actor_loss      | -34.2    |
# |    critic_loss     | 2.54     |
# |    ent_coef        | 0.00448  |
# |    ent_coef_loss   | 0.242    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1997984  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.5    |
# | time/              |          |
# |    episodes        | 19985    |
# |    fps             | 9        |
# |    time_elapsed    | 2240     |
# |    total_timesteps | 1978681  |
# | train/             |          |
# |    actor_loss      | -33.3    |
# |    critic_loss     | 2.61     |
# |    ent_coef        | 0.00544  |
# |    ent_coef_loss   | -5.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1998479  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.9    |
# | time/              |          |
# |    episodes        | 19990    |
# |    fps             | 9        |
# |    time_elapsed    | 2284     |
# |    total_timesteps | 1979176  |
# | train/             |          |
# |    actor_loss      | -33.5    |
# |    critic_loss     | 2.76     |
# |    ent_coef        | 0.00746  |
# |    ent_coef_loss   | 3.06     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1998974  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.3    |
# | time/              |          |
# |    episodes        | 19995    |
# |    fps             | 9        |
# |    time_elapsed    | 2325     |
# |    total_timesteps | 1979671  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.00574  |
# |    ent_coef_loss   | -3.78    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1999469  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.3    |
# | time/              |          |
# |    episodes        | 20000    |
# |    fps             | 9        |
# |    time_elapsed    | 2380     |
# |    total_timesteps | 1980166  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | -0.984   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1999964  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.3    |
# | time/              |          |
# |    episodes        | 20005    |
# |    fps             | 9        |
# |    time_elapsed    | 2432     |
# |    total_timesteps | 1980661  |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.00486  |
# |    ent_coef_loss   | -0.358   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2000459  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.8    |
# | time/              |          |
# |    episodes        | 20010    |
# |    fps             | 9        |
# |    time_elapsed    | 2486     |
# |    total_timesteps | 1981156  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 2.77     |
# |    ent_coef        | 0.00468  |
# |    ent_coef_loss   | 0.715    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2000954  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.9    |
# | time/              |          |
# |    episodes        | 20015    |
# |    fps             | 9        |
# |    time_elapsed    | 2539     |
# |    total_timesteps | 1981651  |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 2.58     |
# |    ent_coef        | 0.00438  |
# |    ent_coef_loss   | 3.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2001449  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.5    |
# | time/              |          |
# |    episodes        | 20020    |
# |    fps             | 9        |
# |    time_elapsed    | 2593     |
# |    total_timesteps | 1982146  |
# | train/             |          |
# |    actor_loss      | -34.4    |
# |    critic_loss     | 2.56     |
# |    ent_coef        | 0.00462  |
# |    ent_coef_loss   | -1.99    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2001944  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85      |
# | time/              |          |
# |    episodes        | 20025    |
# |    fps             | 9        |
# |    time_elapsed    | 2651     |
# |    total_timesteps | 1982641  |
# | train/             |          |
# |    actor_loss      | -34.1    |
# |    critic_loss     | 2.73     |
# |    ent_coef        | 0.00462  |
# |    ent_coef_loss   | -1.22    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2002439  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.5    |
# | time/              |          |
# |    episodes        | 20030    |
# |    fps             | 9        |
# |    time_elapsed    | 2705     |
# |    total_timesteps | 1983136  |
# | train/             |          |
# |    actor_loss      | -33.3    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.00669  |
# |    ent_coef_loss   | 0.488    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2002934  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.7    |
# | time/              |          |
# |    episodes        | 20035    |
# |    fps             | 9        |
# |    time_elapsed    | 2760     |
# |    total_timesteps | 1983631  |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 2.57     |
# |    ent_coef        | 0.00456  |
# |    ent_coef_loss   | -6.11    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2003429  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.7    |
# | time/              |          |
# |    episodes        | 20040    |
# |    fps             | 9        |
# |    time_elapsed    | 2814     |
# |    total_timesteps | 1984126  |
# | train/             |          |
# |    actor_loss      | -35.9    |
# |    critic_loss     | 2.6      |
# |    ent_coef        | 0.0037   |
# |    ent_coef_loss   | 2.39     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2003924  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.7    |
# | time/              |          |
# |    episodes        | 20045    |
# |    fps             | 9        |
# |    time_elapsed    | 2867     |
# |    total_timesteps | 1984621  |
# | train/             |          |
# |    actor_loss      | -35.1    |
# |    critic_loss     | 2.72     |
# |    ent_coef        | 0.00397  |
# |    ent_coef_loss   | 3.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2004419  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.2    |
# | time/              |          |
# |    episodes        | 20050    |
# |    fps             | 9        |
# |    time_elapsed    | 2921     |
# |    total_timesteps | 1985116  |
# | train/             |          |
# |    actor_loss      | -34.8    |
# |    critic_loss     | 2.61     |
# |    ent_coef        | 0.00405  |
# |    ent_coef_loss   | 2.96     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2004914  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 20055    |
# |    fps             | 9        |
# |    time_elapsed    | 2974     |
# |    total_timesteps | 1985611  |
# | train/             |          |
# |    actor_loss      | -34      |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.00444  |
# |    ent_coef_loss   | -1.94    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2005409  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.2    |
# | time/              |          |
# |    episodes        | 20060    |
# |    fps             | 9        |
# |    time_elapsed    | 3027     |
# |    total_timesteps | 1986106  |
# | train/             |          |
# |    actor_loss      | -34.2    |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.00455  |
# |    ent_coef_loss   | -4.06    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2005904  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.3    |
# | time/              |          |
# |    episodes        | 20065    |
# |    fps             | 9        |
# |    time_elapsed    | 3071     |
# |    total_timesteps | 1986601  |
# | train/             |          |
# |    actor_loss      | -34.3    |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.00429  |
# |    ent_coef_loss   | 2.4      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2006399  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -78.4    |
# | time/              |          |
# |    episodes        | 20070    |
# |    fps             | 9        |
# |    time_elapsed    | 3117     |
# |    total_timesteps | 1987096  |
# | train/             |          |
# |    actor_loss      | -33.7    |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.00372  |
# |    ent_coef_loss   | -2.65    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2006894  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -76      |
# | time/              |          |
# |    episodes        | 20075    |
# |    fps             | 9        |
# |    time_elapsed    | 3171     |
# |    total_timesteps | 1987591  |
# | train/             |          |
# |    actor_loss      | -33.1    |
# |    critic_loss     | 2.24     |
# |    ent_coef        | 0.00407  |
# |    ent_coef_loss   | -1.02    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2007389  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -76      |
# | time/              |          |
# |    episodes        | 20080    |
# |    fps             | 9        |
# |    time_elapsed    | 3214     |
# |    total_timesteps | 1988086  |
# | train/             |          |
# |    actor_loss      | -35.8    |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.00388  |
# |    ent_coef_loss   | 0.0996   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2007884  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -71.5    |
# | time/              |          |
# |    episodes        | 20085    |
# |    fps             | 9        |
# |    time_elapsed    | 3254     |
# |    total_timesteps | 1988581  |
# | train/             |          |
# |    actor_loss      | -35.3    |
# |    critic_loss     | 2.35     |
# |    ent_coef        | 0.00381  |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2008379  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    episodes        | 20090    |
# |    fps             | 9        |
# |    time_elapsed    | 3293     |
# |    total_timesteps | 1989076  |
# | train/             |          |
# |    actor_loss      | -33.6    |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.00509  |
# |    ent_coef_loss   | -1.42    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2008874  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    episodes        | 20095    |
# |    fps             | 9        |
# |    time_elapsed    | 3334     |
# |    total_timesteps | 1989571  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.00423  |
# |    ent_coef_loss   | 2.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2009369  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72      |
# | time/              |          |
# |    episodes        | 20100    |
# |    fps             | 9        |
# |    time_elapsed    | 3374     |
# |    total_timesteps | 1990066  |
# | train/             |          |
# |    actor_loss      | -32.6    |
# |    critic_loss     | 2.05     |
# |    ent_coef        | 0.00412  |
# |    ent_coef_loss   | -1.01    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2009864  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -69.5    |
# | time/              |          |
# |    episodes        | 20105    |
# |    fps             | 9        |
# |    time_elapsed    | 3414     |
# |    total_timesteps | 1990561  |
# | train/             |          |
# |    actor_loss      | -33.6    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.00473  |
# |    ent_coef_loss   | -3.04    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2010359  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -70      |
# | time/              |          |
# |    episodes        | 20110    |
# |    fps             | 9        |
# |    time_elapsed    | 3455     |
# |    total_timesteps | 1991056  |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 1.83     |
# |    ent_coef        | 0.00648  |
# |    ent_coef_loss   | 1.58     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2010854  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72.9    |
# | time/              |          |
# |    episodes        | 20115    |
# |    fps             | 9        |
# |    time_elapsed    | 3503     |
# |    total_timesteps | 1991551  |
# | train/             |          |
# |    actor_loss      | -33.9    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.00741  |
# |    ent_coef_loss   | 1.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2011349  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -72.9    |
# | time/              |          |
# |    episodes        | 20120    |
# |    fps             | 9        |
# |    time_elapsed    | 3551     |
# |    total_timesteps | 1992046  |
# | train/             |          |
# |    actor_loss      | -33.9    |
# |    critic_loss     | 1.8      |
# |    ent_coef        | 0.00674  |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2011844  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -73.4    |
# | time/              |          |
# |    episodes        | 20125    |
# |    fps             | 9        |
# |    time_elapsed    | 3591     |
# |    total_timesteps | 1992541  |
# | train/             |          |
# |    actor_loss      | -34.5    |
# |    critic_loss     | 1.95     |
# |    ent_coef        | 0.00651  |
# |    ent_coef_loss   | -2.32    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2012339  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -73.4    |
# | time/              |          |
# |    episodes        | 20130    |
# |    fps             | 9        |
# |    time_elapsed    | 3634     |
# |    total_timesteps | 1993036  |
# | train/             |          |
# |    actor_loss      | -36      |
# |    critic_loss     | 1.96     |
# |    ent_coef        | 0.0065   |
# |    ent_coef_loss   | 1.56     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2012834  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 20135    |
# |    fps             | 9        |
# |    time_elapsed    | 3681     |
# |    total_timesteps | 1993531  |
# | train/             |          |
# |    actor_loss      | -35.2    |
# |    critic_loss     | 2.01     |
# |    ent_coef        | 0.00946  |
# |    ent_coef_loss   | -3.26    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2013329  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 20140    |
# |    fps             | 9        |
# |    time_elapsed    | 3730     |
# |    total_timesteps | 1994026  |
# | train/             |          |
# |    actor_loss      | -35.6    |
# |    critic_loss     | 1.94     |
# |    ent_coef        | 0.00783  |
# |    ent_coef_loss   | -1.16    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2013824  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -75.9    |
# | time/              |          |
# |    episodes        | 20145    |
# |    fps             | 9        |
# |    time_elapsed    | 3770     |
# |    total_timesteps | 1994521  |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 1.86     |
# |    ent_coef        | 0.00754  |
# |    ent_coef_loss   | -3.75    |
# ...
# |    n_updates       | 2963234  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    episodes        | 29735    |
# |    fps             | 8        |
# |    time_elapsed    | 54922    |
# |    total_timesteps | 2943931  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.093    |
# |    ent_coef        | 7.97e-05 |
# |    ent_coef_loss   | -22.3    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2963729  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    episodes        | 29740    |
# |    fps             | 8        |
# |    time_elapsed    | 54999    |
# |    total_timesteps | 2944426  |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.129    |
# |    ent_coef        | 4.93e-05 |
# |    ent_coef_loss   | -18      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2964224  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94.5    |
# | time/              |          |
# |    episodes        | 29745    |
# |    fps             | 8        |
# |    time_elapsed    | 55079    |
# |    total_timesteps | 2944921  |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.105    |
# |    ent_coef        | 4.74e-05 |
# |    ent_coef_loss   | 8.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2964719  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -95.5    |
# | time/              |          |
# |    episodes        | 29750    |
# |    fps             | 8        |
# |    time_elapsed    | 55157    |
# |    total_timesteps | 2945416  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.0992   |
# |    ent_coef        | 7.43e-05 |
# |    ent_coef_loss   | 14       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2965214  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -95.5    |
# | time/              |          |
# |    episodes        | 29755    |
# |    fps             | 8        |
# |    time_elapsed    | 55233    |
# |    total_timesteps | 2945911  |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 7.41e-05 |
# |    ent_coef_loss   | -5.85    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2965709  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.2    |
# | time/              |          |
# |    episodes        | 29760    |
# |    fps             | 8        |
# |    time_elapsed    | 55308    |
# |    total_timesteps | 2946406  |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.114    |
# |    ent_coef        | 6.2e-05  |
# |    ent_coef_loss   | 19.3     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2966204  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29765    |
# |    fps             | 8        |
# |    time_elapsed    | 55386    |
# |    total_timesteps | 2946901  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.148    |
# |    ent_coef        | 7.37e-05 |
# |    ent_coef_loss   | 28.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2966699  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29770    |
# |    fps             | 8        |
# |    time_elapsed    | 55465    |
# |    total_timesteps | 2947396  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.121    |
# |    ent_coef        | 0.00011  |
# |    ent_coef_loss   | 9.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2967194  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29775    |
# |    fps             | 8        |
# |    time_elapsed    | 55543    |
# |    total_timesteps | 2947891  |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.0997   |
# |    ent_coef        | 6.82e-05 |
# |    ent_coef_loss   | -6       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2967689  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29780    |
# |    fps             | 8        |
# |    time_elapsed    | 55623    |
# |    total_timesteps | 2948386  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.146    |
# |    ent_coef        | 6.08e-05 |
# |    ent_coef_loss   | 0.418    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2968184  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29785    |
# |    fps             | 8        |
# |    time_elapsed    | 55702    |
# |    total_timesteps | 2948881  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.152    |
# |    ent_coef        | 6.01e-05 |
# |    ent_coef_loss   | 12.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2968679  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29790    |
# |    fps             | 8        |
# |    time_elapsed    | 55781    |
# |    total_timesteps | 2949376  |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.0952   |
# |    ent_coef        | 5.52e-05 |
# |    ent_coef_loss   | -29      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2969174  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29795    |
# |    fps             | 8        |
# |    time_elapsed    | 55858    |
# |    total_timesteps | 2949871  |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.11     |
# |    ent_coef        | 5.6e-05  |
# |    ent_coef_loss   | 0.385    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2969669  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29800    |
# |    fps             | 8        |
# |    time_elapsed    | 55938    |
# |    total_timesteps | 2950366  |
# | train/             |          |
# |    actor_loss      | -11.3    |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 7.96e-05 |
# |    ent_coef_loss   | -2.86    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2970164  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29805    |
# |    fps             | 8        |
# |    time_elapsed    | 56017    |
# |    total_timesteps | 2950861  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.109    |
# |    ent_coef        | 5.43e-05 |
# |    ent_coef_loss   | 4.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2970659  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29810    |
# |    fps             | 8        |
# |    time_elapsed    | 56093    |
# |    total_timesteps | 2951356  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.126    |
# |    ent_coef        | 7.77e-05 |
# |    ent_coef_loss   | 20.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2971154  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29815    |
# |    fps             | 8        |
# |    time_elapsed    | 56172    |
# |    total_timesteps | 2951851  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.108    |
# |    ent_coef        | 8.7e-05  |
# |    ent_coef_loss   | -13.2    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2971649  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29820    |
# |    fps             | 8        |
# |    time_elapsed    | 56249    |
# |    total_timesteps | 2952346  |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.104    |
# |    ent_coef        | 7.22e-05 |
# |    ent_coef_loss   | 7.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2972144  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29825    |
# |    fps             | 8        |
# |    time_elapsed    | 56326    |
# |    total_timesteps | 2952841  |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.121    |
# |    ent_coef        | 0.000101 |
# |    ent_coef_loss   | -7.24    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2972639  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29830    |
# |    fps             | 8        |
# |    time_elapsed    | 56404    |
# |    total_timesteps | 2953336  |
# | train/             |          |
# |    actor_loss      | -11.6    |
# |    critic_loss     | 0.157    |
# |    ent_coef        | 0.000123 |
# |    ent_coef_loss   | 38.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2973134  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29835    |
# |    fps             | 8        |
# |    time_elapsed    | 56480    |
# |    total_timesteps | 2953831  |
# | train/             |          |
# |    actor_loss      | -11.4    |
# |    critic_loss     | 0.0723   |
# |    ent_coef        | 0.000229 |
# |    ent_coef_loss   | 24.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2973629  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29840    |
# |    fps             | 8        |
# |    time_elapsed    | 56555    |
# |    total_timesteps | 2954326  |
# | train/             |          |
# |    actor_loss      | -11.8    |
# |    critic_loss     | 0.152    |
# |    ent_coef        | 0.000387 |
# |    ent_coef_loss   | 23.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2974124  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29845    |
# |    fps             | 8        |
# |    time_elapsed    | 56630    |
# |    total_timesteps | 2954821  |
# | train/             |          |
# |    actor_loss      | -11.5    |
# |    critic_loss     | 0.157    |
# |    ent_coef        | 0.000713 |
# |    ent_coef_loss   | 39       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2974619  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29850    |
# |    fps             | 8        |
# |    time_elapsed    | 56705    |
# |    total_timesteps | 2955316  |
# | train/             |          |
# |    actor_loss      | -11.7    |
# |    critic_loss     | 0.216    |
# |    ent_coef        | 0.0013   |
# |    ent_coef_loss   | 33.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2975114  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29855    |
# |    fps             | 8        |
# |    time_elapsed    | 56780    |
# |    total_timesteps | 2955811  |
# | train/             |          |
# |    actor_loss      | -11.1    |
# |    critic_loss     | 0.198    |
# |    ent_coef        | 0.00226  |
# |    ent_coef_loss   | 31.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2975609  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29860    |
# |    fps             | 8        |
# |    time_elapsed    | 56856    |
# |    total_timesteps | 2956306  |
# | train/             |          |
# |    actor_loss      | -10.6    |
# |    critic_loss     | 0.136    |
# |    ent_coef        | 0.00377  |
# |    ent_coef_loss   | 22.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2976104  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 29865    |
# |    fps             | 8        |
# |    time_elapsed    | 56932    |
# |    total_timesteps | 2956801  |
# | train/             |          |
# |    actor_loss      | -11      |
# |    critic_loss     | 0.154    |
# |    ent_coef        | 0.00248  |
# |    ent_coef_loss   | -52.8    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 2976599  |
# ---------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# finish learning
