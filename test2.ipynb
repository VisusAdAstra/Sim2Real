# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback


model = TQC.load("data/tqc1/tqc_model_873000_steps")
env = roboverse.make("Widow250PickPlace-v2",
                         gui=True,
                         observation_mode="pixels",
                         transpose_image=False)
model.set_env(env)
env = model.get_env()

obs = env.reset()
print("start render")
for i in range(int(1e4)):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(rewards)
    env.render("human")
env.close()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
import time
import numpy as np
from roboverse.policies import policies
from stable_baselines3.common.utils import set_random_seed


def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = roboverse.make(env_id,
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
        #env = TimeFeatureWrapper(env)
        #env.reset(seed=seed + rank)
        env.reset()
        return env
    set_random_seed(seed)
    return _init


def collect_data(env, model, policy, target, num_trajectories=100, num_timesteps=30):
    policy_class = policies[policy]
    policy = policy_class(env)
    num_success = 0
    num_saved = 0
    accept_trajectory_key = target
    noise = 0.1
    EPSILON = 0.1

    while num_saved < num_trajectories:
        num_saved += 1
        num_steps = 1e6
        rewards = []
        env.reset()
        policy.reset()
        time.sleep(0.1)
        success = False
        for j in range(num_timesteps):
            action, agent_info = policy.get_action()

            # In case we need to pad actions by 1 for easier realNVP modelling 
            env_action_dim = env.action_space.shape[0]
            #if env_action_dim - action.shape[0] == 1:
            #    action = np.append(action, 0)
            action += np.random.normal(scale=noise, size=(env_action_dim,))
            action = np.clip(action, -1 + EPSILON, 1 - EPSILON)
            observation = env.get_observation()
            observation["image"] = np.transpose(observation["image"], (2, 0, 1))
            next_observation, reward, done, info = env.step(action)
            next_observation["image"] = np.transpose(next_observation["image"], (2, 0, 1))
            rewards.append(reward)
            success = sum(rewards) > 70
            model.replay_buffer.add(observation, next_observation, action, reward, np.array([done]), [{}])

            if success and num_steps > 1e3: #info[accept_trajectory_key]
                num_steps = j

            if success and j > 23: #info[accept_trajectory_key]
                break
            if done or agent_info['done']:
                break

        if success: #info[accept_trajectory_key]
            PRINT = False
            if PRINT:
                print("num_timesteps: ", num_steps, rewards)
                #print(observation["image"].shape)
                #print(next_observation["image"].shape)
            num_success += 1
        if num_saved%100 == 0:
            print(f"num_trajectories: {num_saved} success rate: {num_success/num_saved} Reward: {sum(rewards)}")

    print("success rate: {}".format(num_success / (num_saved)))

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlaceMultiObject-v0",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 2
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

# model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
#              policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
#              replay_buffer_class=HerReplayBuffer,
#              replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
#              tau=0.05, learning_starts=200, verbose=1)

model = TQC.load("data/seed_1/tqc_pick_place", env=env)
model.set_env(env)

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start learning")
model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place_test")
print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# load_replay_buffer
# start learning
# Output()
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:219:
# DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is
# recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:225:
# DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:165: UserWarning:
# WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 193      |
# | time/              |          |
# |    episodes        | 9900     |
# |    fps             | 10       |
# |    time_elapsed    | 19       |
# |    total_timesteps | 980198   |
# | train/             |          |
# |    actor_loss      | -82.9    |
# |    critic_loss     | 11.6     |
# |    ent_coef        | 0.00557  |
# |    ent_coef_loss   | 250      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 999997   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 177      |
# | time/              |          |
# |    episodes        | 9905     |
# |    fps             | 10       |
# |    time_elapsed    | 67       |
# |    total_timesteps | 980693   |
# | train/             |          |
# |    actor_loss      | -123     |
# |    critic_loss     | 12.6     |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 85.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1000492  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 165      |
# | time/              |          |
# |    episodes        | 9910     |
# |    fps             | 10       |
# |    time_elapsed    | 115      |
# |    total_timesteps | 981188   |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 12.4     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | 48.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1000987  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 149      |
# | time/              |          |
# |    episodes        | 9915     |
# |    fps             | 10       |
# |    time_elapsed    | 165      |
# |    total_timesteps | 981683   |
# | train/             |          |
# |    actor_loss      | -84.6    |
# |    critic_loss     | 14.6     |
# |    ent_coef        | 0.0212   |
# |    ent_coef_loss   | 16.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1001482  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 133      |
# | time/              |          |
# |    episodes        | 9920     |
# |    fps             | 10       |
# |    time_elapsed    | 214      |
# |    total_timesteps | 982178   |
# | train/             |          |
# |    actor_loss      | -98.8    |
# |    critic_loss     | 18.3     |
# |    ent_coef        | 0.0256   |
# |    ent_coef_loss   | 19.4     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1001977  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 116      |
# | time/              |          |
# |    episodes        | 9925     |
# |    fps             | 10       |
# |    time_elapsed    | 260      |
# |    total_timesteps | 982673   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 13.8     |
# |    ent_coef        | 0.0309   |
# |    ent_coef_loss   | 13.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1002472  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 100      |
# | time/              |          |
# |    episodes        | 9930     |
# |    fps             | 10       |
# |    time_elapsed    | 310      |
# |    total_timesteps | 983168   |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 12.2     |
# |    ent_coef        | 0.0369   |
# |    ent_coef_loss   | 11.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1002967  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 90.6     |
# | time/              |          |
# |    episodes        | 9935     |
# |    fps             | 10       |
# |    time_elapsed    | 359      |
# |    total_timesteps | 983663   |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 12.3     |
# |    ent_coef        | 0.0437   |
# |    ent_coef_loss   | 7.25     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1003462  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 74.5     |
# | time/              |          |
# |    episodes        | 9940     |
# |    fps             | 10       |
# |    time_elapsed    | 406      |
# |    total_timesteps | 984158   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 9.34     |
# |    ent_coef        | 0.0505   |
# |    ent_coef_loss   | 4.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1003957  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 58.4     |
# | time/              |          |
# |    episodes        | 9945     |
# |    fps             | 10       |
# |    time_elapsed    | 455      |
# |    total_timesteps | 984653   |
# | train/             |          |
# |    actor_loss      | -122     |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0604   |
# |    ent_coef_loss   | 6.72     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1004452  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 42.2     |
# | time/              |          |
# |    episodes        | 9950     |
# |    fps             | 10       |
# |    time_elapsed    | 508      |
# |    total_timesteps | 985148   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 3.2      |
# |    ent_coef        | 0.0731   |
# |    ent_coef_loss   | 4.16     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1004947  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 26.4     |
# | time/              |          |
# |    episodes        | 9955     |
# |    fps             | 10       |
# |    time_elapsed    | 558      |
# |    total_timesteps | 985643   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 3.72     |
# |    ent_coef        | 0.0883   |
# |    ent_coef_loss   | 2.9      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1005442  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | 10.4     |
# | time/              |          |
# |    episodes        | 9960     |
# |    fps             | 10       |
# |    time_elapsed    | 609      |
# |    total_timesteps | 986138   |
# | train/             |          |
# |    actor_loss      | -121     |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.0884   |
# |    ent_coef_loss   | -2.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1005937  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -2.17    |
# | time/              |          |
# |    episodes        | 9965     |
# |    fps             | 10       |
# |    time_elapsed    | 659      |
# |    total_timesteps | 986633   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.0726   |
# |    ent_coef_loss   | -0.752   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1006432  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -15.8    |
# | time/              |          |
# |    episodes        | 9970     |
# |    fps             | 10       |
# |    time_elapsed    | 708      |
# |    total_timesteps | 987128   |
# | train/             |          |
# |    actor_loss      | -126     |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.0654   |
# |    ent_coef_loss   | -1.45    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1006927  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -28.7    |
# | time/              |          |
# |    episodes        | 9975     |
# |    fps             | 10       |
# |    time_elapsed    | 761      |
# |    total_timesteps | 987623   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 5.95     |
# |    ent_coef        | 0.0598   |
# |    ent_coef_loss   | -0.0678  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1007422  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42      |
# | time/              |          |
# |    episodes        | 9980     |
# |    fps             | 10       |
# |    time_elapsed    | 810      |
# |    total_timesteps | 988118   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 5.17     |
# |    ent_coef        | 0.0473   |
# |    ent_coef_loss   | -1.39    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1007917  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -58      |
# | time/              |          |
# |    episodes        | 9985     |
# |    fps             | 9        |
# |    time_elapsed    | 862      |
# |    total_timesteps | 988613   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 7.29     |
# |    ent_coef        | 0.0445   |
# |    ent_coef_loss   | 0.701    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1008412  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -70.6    |
# | time/              |          |
# |    episodes        | 9990     |
# |    fps             | 9        |
# |    time_elapsed    | 911      |
# |    total_timesteps | 989108   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 6.02     |
# |    ent_coef        | 0.0494   |
# |    ent_coef_loss   | 0.203    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1008907  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.5    |
# | time/              |          |
# |    episodes        | 9995     |
# |    fps             | 10       |
# |    time_elapsed    | 960      |
# |    total_timesteps | 989603   |
# | train/             |          |
# |    actor_loss      | -112     |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.0558   |
# |    ent_coef_loss   | -0.595   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1009402  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10000    |
# |    fps             | 10       |
# |    time_elapsed    | 1008     |
# |    total_timesteps | 990098   |
# | train/             |          |
# |    actor_loss      | -107     |
# |    critic_loss     | 4.29     |
# |    ent_coef        | 0.0561   |
# |    ent_coef_loss   | -0.176   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1009897  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10005    |
# |    fps             | 10       |
# |    time_elapsed    | 1056     |
# |    total_timesteps | 990593   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 3.58     |
# |    ent_coef        | 0.0573   |
# |    ent_coef_loss   | -0.731   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1010392  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10010    |
# |    fps             | 10       |
# |    time_elapsed    | 1105     |
# |    total_timesteps | 991088   |
# | train/             |          |
# |    actor_loss      | -111     |
# |    critic_loss     | 3.05     |
# |    ent_coef        | 0.0577   |
# |    ent_coef_loss   | -0.301   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1010887  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10015    |
# |    fps             | 10       |
# |    time_elapsed    | 1154     |
# |    total_timesteps | 991583   |
# | train/             |          |
# |    actor_loss      | -114     |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0538   |
# |    ent_coef_loss   | 0.0106   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1011382  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.2    |
# | time/              |          |
# |    episodes        | 10020    |
# |    fps             | 10       |
# |    time_elapsed    | 1201     |
# |    total_timesteps | 992078   |
# | train/             |          |
# |    actor_loss      | -115     |
# |    critic_loss     | 2.05     |
# |    ent_coef        | 0.0554   |
# |    ent_coef_loss   | -0.286   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1011877  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -90.7    |
# | time/              |          |
# |    episodes        | 10025    |
# |    fps             | 10       |
# |    time_elapsed    | 1251     |
# |    total_timesteps | 992573   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 1.99     |
# |    ent_coef        | 0.0512   |
# |    ent_coef_loss   | -0.188   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1012372  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -88.2    |
# | time/              |          |
# |    episodes        | 10030    |
# |    fps             | 10       |
# |    time_elapsed    | 1302     |
# |    total_timesteps | 993068   |
# | train/             |          |
# |    actor_loss      | -113     |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0572   |
# |    ent_coef_loss   | -0.687   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1012867  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.3    |
# | time/              |          |
# |    episodes        | 10035    |
# |    fps             | 10       |
# |    time_elapsed    | 1351     |
# |    total_timesteps | 993563   |
# | train/             |          |
# |    actor_loss      | -118     |
# |    critic_loss     | 2.96     |
# |    ent_coef        | 0.0582   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1013362  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10040    |
# |    fps             | 10       |
# |    time_elapsed    | 1400     |
# |    total_timesteps | 994058   |
# | train/             |          |
# |    actor_loss      | -109     |
# |    critic_loss     | 3.15     |
# |    ent_coef        | 0.0479   |
# |    ent_coef_loss   | 0.762    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1013857  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10045    |
# |    fps             | 10       |
# |    time_elapsed    | 1447     |
# |    total_timesteps | 994553   |
# | train/             |          |
# |    actor_loss      | -116     |
# |    critic_loss     | 2.81     |
# |    ent_coef        | 0.0574   |
# |    ent_coef_loss   | 0.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1014352  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10050    |
# |    fps             | 10       |
# |    time_elapsed    | 1497     |
# |    total_timesteps | 995048   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 3.05     |
# |    ent_coef        | 0.0515   |
# |    ent_coef_loss   | -0.333   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1014847  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10055    |
# |    fps             | 10       |
# |    time_elapsed    | 1546     |
# |    total_timesteps | 995543   |
# | train/             |          |
# |    actor_loss      | -110     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0401   |
# |    ent_coef_loss   | -0.248   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1015342  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10060    |
# |    fps             | 10       |
# |    time_elapsed    | 1595     |
# |    total_timesteps | 996038   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | -0.406   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1015837  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.7    |
# | time/              |          |
# |    episodes        | 10065    |
# |    fps             | 10       |
# |    time_elapsed    | 1645     |
# |    total_timesteps | 996533   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.33     |
# |    ent_coef        | 0.0425   |
# |    ent_coef_loss   | 0.0373   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016332  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10070    |
# |    fps             | 10       |
# |    time_elapsed    | 1694     |
# |    total_timesteps | 997028   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0397   |
# |    ent_coef_loss   | -0.393   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016827  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10075    |
# |    fps             | 10       |
# |    time_elapsed    | 1743     |
# |    total_timesteps | 997523   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0429   |
# |    ent_coef_loss   | -0.873   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1017322  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10080    |
# |    fps             | 10       |
# |    time_elapsed    | 1792     |
# |    total_timesteps | 998018   |
# | train/             |          |
# |    actor_loss      | -105     |
# |    critic_loss     | 2.47     |
# |    ent_coef        | 0.0402   |
# |    ent_coef_loss   | -0.929   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1017817  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.3    |
# | time/              |          |
# |    episodes        | 10085    |
# |    fps             | 10       |
# |    time_elapsed    | 1841     |
# |    total_timesteps | 998513   |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0408   |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1018312  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10090    |
# |    fps             | 10       |
# |    time_elapsed    | 1888     |
# |    total_timesteps | 999008   |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.2      |
# |    ent_coef        | 0.0351   |
# |    ent_coef_loss   | 0.636    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1018807  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10095    |
# |    fps             | 10       |
# |    time_elapsed    | 1939     |
# |    total_timesteps | 999503   |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.11     |
# |    ent_coef        | 0.0323   |
# |    ent_coef_loss   | 0.686    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1019302  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87.2    |
# | time/              |          |
# |    episodes        | 10100    |
# |    fps             | 10       |
# |    time_elapsed    | 1987     |
# |    total_timesteps | 999998   |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.15     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | -0.515   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1019797  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10105    |
# |    fps             | 10       |
# |    time_elapsed    | 2038     |
# |    total_timesteps | 1000493  |
# | train/             |          |
# |    actor_loss      | -106     |
# |    critic_loss     | 2.34     |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | 0.408    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1020292  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10110    |
# |    fps             | 10       |
# |    time_elapsed    | 2084     |
# |    total_timesteps | 1000988  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0339   |
# |    ent_coef_loss   | 0.861    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1020787  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.6    |
# | time/              |          |
# |    episodes        | 10115    |
# |    fps             | 10       |
# |    time_elapsed    | 2134     |
# |    total_timesteps | 1001483  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.6      |
# |    ent_coef        | 0.0338   |
# |    ent_coef_loss   | 0.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1021282  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.4    |
# | time/              |          |
# |    episodes        | 10120    |
# |    fps             | 10       |
# |    time_elapsed    | 2183     |
# |    total_timesteps | 1001978  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 2.71     |
# |    ent_coef        | 0.0325   |
# |    ent_coef_loss   | -1.46    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1021777  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.4    |
# | time/              |          |
# |    episodes        | 10125    |
# |    fps             | 10       |
# |    time_elapsed    | 2231     |
# |    total_timesteps | 1002473  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.038    |
# |    ent_coef_loss   | 0.77     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1022272  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.9    |
# | time/              |          |
# |    episodes        | 10130    |
# |    fps             | 10       |
# |    time_elapsed    | 2279     |
# |    total_timesteps | 1002968  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.44     |
# |    ent_coef        | 0.039    |
# |    ent_coef_loss   | 0.391    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1022767  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -88.8    |
# | time/              |          |
# |    episodes        | 10135    |
# |    fps             | 10       |
# |    time_elapsed    | 2328     |
# |    total_timesteps | 1003463  |
# | train/             |          |
# |    actor_loss      | -99.5    |
# |    critic_loss     | 2.68     |
# |    ent_coef        | 0.035    |
# |    ent_coef_loss   | 2.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1023262  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10140    |
# |    fps             | 10       |
# |    time_elapsed    | 2376     |
# |    total_timesteps | 1003958  |
# | train/             |          |
# |    actor_loss      | -98.1    |
# |    critic_loss     | 2.67     |
# |    ent_coef        | 0.0378   |
# |    ent_coef_loss   | 0.159    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1023757  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10145    |
# |    fps             | 10       |
# |    time_elapsed    | 2425     |
# |    total_timesteps | 1004453  |
# | train/             |          |
# |    actor_loss      | -98.4    |
# |    critic_loss     | 2.69     |
# |    ent_coef        | 0.0421   |
# |    ent_coef_loss   | 0.234    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1024252  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -86.2    |
# | time/              |          |
# |    episodes        | 10150    |
# |    fps             | 10       |
# |    time_elapsed    | 2476     |
# |    total_timesteps | 1004948  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0462   |
# |    ent_coef_loss   | 0.0695   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1024747  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.8    |
# | time/              |          |
# |    episodes        | 10155    |
# |    fps             | 10       |
# |    time_elapsed    | 2524     |
# |    total_timesteps | 1005443  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.53     |
# |    ent_coef        | 0.045    |
# |    ent_coef_loss   | -0.377   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1025242  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10160    |
# |    fps             | 10       |
# |    time_elapsed    | 2573     |
# |    total_timesteps | 1005938  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.0453   |
# |    ent_coef_loss   | 0.485    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1025737  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10165    |
# |    fps             | 10       |
# |    time_elapsed    | 2623     |
# |    total_timesteps | 1006433  |
# | train/             |          |
# |    actor_loss      | -103     |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0413   |
# |    ent_coef_loss   | -0.382   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1026232  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10170    |
# |    fps             | 10       |
# |    time_elapsed    | 2673     |
# |    total_timesteps | 1006928  |
# | train/             |          |
# |    actor_loss      | -104     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0412   |
# |    ent_coef_loss   | 0.756    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1026727  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.3    |
# | time/              |          |
# |    episodes        | 10175    |
# |    fps             | 10       |
# |    time_elapsed    | 2723     |
# |    total_timesteps | 1007423  |
# | train/             |          |
# |    actor_loss      | -101     |
# |    critic_loss     | 2.46     |
# |    ent_coef        | 0.044    |
# |    ent_coef_loss   | -1.03    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1027222  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 10180    |
# |    fps             | 10       |
# |    time_elapsed    | 2770     |
# |    total_timesteps | 1007918  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.89     |
# |    ent_coef        | 0.0438   |
# |    ent_coef_loss   | 1.18     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1027717  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79.3    |
# | time/              |          |
# |    episodes        | 10185    |
# |    fps             | 10       |
# |    time_elapsed    | 2818     |
# |    total_timesteps | 1008413  |
# | train/             |          |
# |    actor_loss      | -99.9    |
# |    critic_loss     | 2.82     |
# |    ent_coef        | 0.0419   |
# |    ent_coef_loss   | 0.119    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1028212  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.7    |
# | time/              |          |
# |    episodes        | 10190    |
# |    fps             | 10       |
# |    time_elapsed    | 2866     |
# |    total_timesteps | 1008908  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 3.09     |
# |    ent_coef        | 0.062    |
# |    ent_coef_loss   | 0.162    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1028707  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79      |
# | time/              |          |
# |    episodes        | 10195    |
# |    fps             | 10       |
# |    time_elapsed    | 2916     |
# |    total_timesteps | 1009403  |
# | train/             |          |
# |    actor_loss      | -99.3    |
# |    critic_loss     | 2.9      |
# |    ent_coef        | 0.058    |
# |    ent_coef_loss   | -0.997   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1029202  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79      |
# | time/              |          |
# |    episodes        | 10200    |
# |    fps             | 10       |
# |    time_elapsed    | 2963     |
# |    total_timesteps | 1009898  |
# | train/             |          |
# |    actor_loss      | -98.9    |
# |    critic_loss     | 2.86     |
# |    ent_coef        | 0.0452   |
# |    ent_coef_loss   | 0.63     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1029697  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10205    |
# |    fps             | 10       |
# |    time_elapsed    | 3011     |
# |    total_timesteps | 1010393  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.48     |
# |    ent_coef        | 0.0406   |
# |    ent_coef_loss   | -0.134   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1030192  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10210    |
# |    fps             | 10       |
# |    time_elapsed    | 3059     |
# |    total_timesteps | 1010888  |
# | train/             |          |
# |    actor_loss      | -97.9    |
# |    critic_loss     | 2.66     |
# |    ent_coef        | 0.0365   |
# |    ent_coef_loss   | -0.0321  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1030687  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.7    |
# | time/              |          |
# |    episodes        | 10215    |
# |    fps             | 10       |
# |    time_elapsed    | 3105     |
# |    total_timesteps | 1011383  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.5      |
# |    ent_coef        | 0.0344   |
# |    ent_coef_loss   | -0.789   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1031182  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 10220    |
# |    fps             | 10       |
# |    time_elapsed    | 3153     |
# |    total_timesteps | 1011878  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.0348   |
# |    ent_coef_loss   | -0.377   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1031677  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10225    |
# |    fps             | 10       |
# |    time_elapsed    | 3201     |
# |    total_timesteps | 1012373  |
# | train/             |          |
# |    actor_loss      | -96.3    |
# |    critic_loss     | 2.32     |
# |    ent_coef        | 0.0311   |
# |    ent_coef_loss   | -0.969   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1032172  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10230    |
# |    fps             | 10       |
# |    time_elapsed    | 3250     |
# |    total_timesteps | 1012868  |
# | train/             |          |
# |    actor_loss      | -102     |
# |    critic_loss     | 2.08     |
# |    ent_coef        | 0.0334   |
# |    ent_coef_loss   | 0.161    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1032667  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.5    |
# | time/              |          |
# |    episodes        | 10235    |
# |    fps             | 10       |
# |    time_elapsed    | 3300     |
# |    total_timesteps | 1013363  |
# | train/             |          |
# |    actor_loss      | -100     |
# |    critic_loss     | 2.21     |
# |    ent_coef        | 0.0357   |
# |    ent_coef_loss   | -0.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1033162  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10240    |
# |    fps             | 10       |
# |    time_elapsed    | 3347     |
# |    total_timesteps | 1013858  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 2.31     |
# |    ent_coef        | 0.0326   |
# |    ent_coef_loss   | -0.607   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1033657  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10245    |
# |    fps             | 10       |
# |    time_elapsed    | 3397     |
# |    total_timesteps | 1014353  |
# | train/             |          |
# |    actor_loss      | -97.1    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0304   |
# |    ent_coef_loss   | 1.76     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1034152  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -80.8    |
# | time/              |          |
# |    episodes        | 10250    |
# |    fps             | 10       |
# |    time_elapsed    | 3445     |
# |    total_timesteps | 1014848  |
# | train/             |          |
# |    actor_loss      | -95.7    |
# |    critic_loss     | 2.28     |
# |    ent_coef        | 0.0314   |
# |    ent_coef_loss   | -0.251   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1034647  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.2    |
# | time/              |          |
# |    episodes        | 10255    |
# |    fps             | 10       |
# |    time_elapsed    | 3496     |
# |    total_timesteps | 1015343  |
# | train/             |          |
# |    actor_loss      | -96.2    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0322   |
# |    ent_coef_loss   | 1.41     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1035142  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10260    |
# |    fps             | 10       |
# |    time_elapsed    | 3544     |
# |    total_timesteps | 1015838  |
# | train/             |          |
# |    actor_loss      | -95      |
# |    critic_loss     | 2.51     |
# |    ent_coef        | 0.0301   |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1035637  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 10265    |
# |    fps             | 10       |
# |    time_elapsed    | 3593     |
# |    total_timesteps | 1016333  |
# | train/             |          |
# |    actor_loss      | -94.9    |
# |    critic_loss     | 2.3      |
# |    ent_coef        | 0.0329   |
# |    ent_coef_loss   | 0.334    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1036132  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -84.3    |
# | time/              |          |
# |    episodes        | 10270    |
# |    fps             | 10       |
# |    time_elapsed    | 3641     |
# |    total_timesteps | 1016828  |
# | train/             |          |
# |    actor_loss      | -93.3    |
# |    critic_loss     | 2.43     |
# |    ent_coef        | 0.0386   |
# |    ent_coef_loss   | 0.51     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1036627  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82      |
# | time/              |          |
# |    episodes        | 10275    |
# |    fps             | 10       |
# |    time_elapsed    | 3689     |
# |    total_timesteps | 1017323  |
# | train/             |          |
# |    actor_loss      | -91.9    |
# |    critic_loss     | 2.49     |
# |    ent_coef        | 0.0382   |
# |    ent_coef_loss   | -0.898   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1037122  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.5    |
# | time/              |          |
# |    episodes        | 10280    |
# |    fps             | 10       |
# |    time_elapsed    | 3738     |
# |    total_timesteps | 1017818  |
# | train/             |          |
# |    actor_loss      | -93.8    |
# |    critic_loss     | 2.41     |
# |    ent_coef        | 0.0361   |
# |    ent_coef_loss   | -0.329   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1037617  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.3    |
# | time/              |          |
# |    episodes        | 10285    |
# |    fps             | 10       |
# |    time_elapsed    | 3786     |
# |    total_timesteps | 1018313  |
# | train/             |          |
# |    actor_loss      | -92.4    |
# |    critic_loss     | 2.63     |
# |    ent_coef        | 0.0317   |
# |    ent_coef_loss   | 0.484    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1038112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -79.6    |
# | time/              |          |
# |    episodes        | 10290    |
# |    fps             | 10       |
# |    time_elapsed    | 3834     |
# |    total_timesteps | 1018808  |
# | train/             |          |
# |    actor_loss      | -90.3    |
# |    critic_loss     | 2.39     |
# |    ent_coef        | 0.0315   |
# |    ent_coef_loss   | 0.0425   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1038607  |
# ---------------------------------
# ---------------------------------
# ...
# |    fps             | 10       |
# |    time_elapsed    | 14142    |
# |    total_timesteps | 1605878  |
# | train/             |          |
# |    actor_loss      | -73.5    |
# |    critic_loss     | 3.44     |
# |    ent_coef        | 0.0173   |
# |    ent_coef_loss   | -0.604   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1625677  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -50.2    |
# | time/              |          |
# |    episodes        | 16225    |
# |    fps             | 10       |
# |    time_elapsed    | 14191    |
# |    total_timesteps | 1606373  |
# | train/             |          |
# |    actor_loss      | -74.3    |
# |    critic_loss     | 3.8      |
# |    ent_coef        | 0.0167   |
# |    ent_coef_loss   | 0.456    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1626172  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -47.6    |
# | time/              |          |
# |    episodes        | 16230    |
# |    fps             | 10       |
# |    time_elapsed    | 14239    |
# |    total_timesteps | 1606868  |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 3.37     |
# |    ent_coef        | 0.0165   |
# |    ent_coef_loss   | 1.24     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1626667  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -45.1    |
# | time/              |          |
# |    episodes        | 16235    |
# |    fps             | 10       |
# |    time_elapsed    | 14288    |
# |    total_timesteps | 1607363  |
# | train/             |          |
# |    actor_loss      | -71.6    |
# |    critic_loss     | 3.39     |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | -0.626   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1627162  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -47.4    |
# | time/              |          |
# |    episodes        | 16240    |
# |    fps             | 10       |
# |    time_elapsed    | 14335    |
# |    total_timesteps | 1607858  |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 3.16     |
# |    ent_coef        | 0.0178   |
# |    ent_coef_loss   | -1.36    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1627657  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -47.4    |
# | time/              |          |
# |    episodes        | 16245    |
# |    fps             | 10       |
# |    time_elapsed    | 14382    |
# |    total_timesteps | 1608353  |
# | train/             |          |
# |    actor_loss      | -72.3    |
# |    critic_loss     | 3.45     |
# |    ent_coef        | 0.0168   |
# |    ent_coef_loss   | 0.159    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1628152  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -45.6    |
# | time/              |          |
# |    episodes        | 16250    |
# |    fps             | 10       |
# |    time_elapsed    | 14431    |
# |    total_timesteps | 1608848  |
# | train/             |          |
# |    actor_loss      | -71.5    |
# |    critic_loss     | 3.47     |
# |    ent_coef        | 0.0163   |
# |    ent_coef_loss   | -0.161   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1628647  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -38.7    |
# | time/              |          |
# |    episodes        | 16255    |
# |    fps             | 10       |
# |    time_elapsed    | 14478    |
# |    total_timesteps | 1609343  |
# | train/             |          |
# |    actor_loss      | -72.6    |
# |    critic_loss     | 3.35     |
# |    ent_coef        | 0.0164   |
# |    ent_coef_loss   | 1.2      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1629142  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -37.3    |
# | time/              |          |
# |    episodes        | 16260    |
# |    fps             | 10       |
# |    time_elapsed    | 14525    |
# |    total_timesteps | 1609838  |
# | train/             |          |
# |    actor_loss      | -72.4    |
# |    critic_loss     | 3.84     |
# |    ent_coef        | 0.0172   |
# |    ent_coef_loss   | 1.19     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1629637  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -39.9    |
# | time/              |          |
# |    episodes        | 16265    |
# |    fps             | 10       |
# |    time_elapsed    | 14571    |
# |    total_timesteps | 1610333  |
# | train/             |          |
# |    actor_loss      | -73.9    |
# |    critic_loss     | 4.23     |
# |    ent_coef        | 0.021    |
# |    ent_coef_loss   | 1.48     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1630132  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.1    |
# | time/              |          |
# |    episodes        | 16270    |
# |    fps             | 10       |
# |    time_elapsed    | 14621    |
# |    total_timesteps | 1610828  |
# | train/             |          |
# |    actor_loss      | -70.3    |
# |    critic_loss     | 4.19     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -0.805   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1630627  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -42.1    |
# | time/              |          |
# |    episodes        | 16275    |
# |    fps             | 10       |
# |    time_elapsed    | 14668    |
# |    total_timesteps | 1611323  |
# | train/             |          |
# |    actor_loss      | -71.7    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.0199   |
# |    ent_coef_loss   | 0.57     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1631122  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -39.4    |
# | time/              |          |
# |    episodes        | 16280    |
# |    fps             | 10       |
# |    time_elapsed    | 14715    |
# |    total_timesteps | 1611818  |
# | train/             |          |
# |    actor_loss      | -71.4    |
# |    critic_loss     | 3.67     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | 0.443    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1631617  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -33.5    |
# | time/              |          |
# |    episodes        | 16285    |
# |    fps             | 10       |
# |    time_elapsed    | 14763    |
# |    total_timesteps | 1612313  |
# | train/             |          |
# |    actor_loss      | -69.3    |
# |    critic_loss     | 3.51     |
# |    ent_coef        | 0.0186   |
# |    ent_coef_loss   | -0.676   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1632112  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -36.2    |
# | time/              |          |
# |    episodes        | 16290    |
# |    fps             | 10       |
# |    time_elapsed    | 14813    |
# |    total_timesteps | 1612808  |
# | train/             |          |
# |    actor_loss      | -70.8    |
# |    critic_loss     | 3.68     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 0.0242   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1632607  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -34      |
# | time/              |          |
# |    episodes        | 16295    |
# |    fps             | 10       |
# |    time_elapsed    | 14865    |
# |    total_timesteps | 1613303  |
# | train/             |          |
# |    actor_loss      | -72.9    |
# |    critic_loss     | 3.7      |
# |    ent_coef        | 0.0184   |
# |    ent_coef_loss   | 0.162    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1633102  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -35.9    |
# | time/              |          |
# |    episodes        | 16300    |
# |    fps             | 10       |
# |    time_elapsed    | 14913    |
# |    total_timesteps | 1613798  |
# | train/             |          |
# |    actor_loss      | -70.4    |
# |    critic_loss     | 3.61     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | -0.753   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1633597  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -35.4    |
# | time/              |          |
# |    episodes        | 16305    |
# |    fps             | 10       |
# |    time_elapsed    | 14960    |
# |    total_timesteps | 1614293  |
# | train/             |          |
# |    actor_loss      | -75.2    |
# |    critic_loss     | 3.85     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | 1.02     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1634092  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -35.4    |
# | time/              |          |
# |    episodes        | 16310    |
# |    fps             | 10       |
# |    time_elapsed    | 15008    |
# |    total_timesteps | 1614788  |
# | train/             |          |
# |    actor_loss      | -73.6    |
# |    critic_loss     | 3.54     |
# |    ent_coef        | 0.0195   |
# |    ent_coef_loss   | 1.89     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1634587  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -29.6    |
# | time/              |          |
# |    episodes        | 16315    |
# |    fps             | 10       |
# |    time_elapsed    | 15056    |
# |    total_timesteps | 1615283  |
# | train/             |          |
# |    actor_loss      | -69.8    |
# |    critic_loss     | 3.78     |
# |    ent_coef        | 0.0188   |
# |    ent_coef_loss   | -1.21    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1635082  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -26.2    |
# | time/              |          |
# |    episodes        | 16320    |
# |    fps             | 10       |
# |    time_elapsed    | 15103    |
# |    total_timesteps | 1615778  |
# | train/             |          |
# |    actor_loss      | -69.9    |
# |    critic_loss     | 3.47     |
# |    ent_coef        | 0.0185   |
# |    ent_coef_loss   | 0.848    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1635577  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -31.8    |
# | time/              |          |
# |    episodes        | 16325    |
# |    fps             | 10       |
# |    time_elapsed    | 15152    |
# |    total_timesteps | 1616273  |
# | train/             |          |
# |    actor_loss      | -70.3    |
# |    critic_loss     | 3.65     |
# |    ent_coef        | 0.0179   |
# |    ent_coef_loss   | -0.275   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1636072  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -29      |
# | time/              |          |
# |    episodes        | 16330    |
# |    fps             | 10       |
# |    time_elapsed    | 15201    |
# |    total_timesteps | 1616768  |
# | train/             |          |
# |    actor_loss      | -70.9    |
# |    critic_loss     | 3.74     |
# |    ent_coef        | 0.0189   |
# |    ent_coef_loss   | -0.83    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1636567  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -29      |
# | time/              |          |
# |    episodes        | 16335    |
# |    fps             | 10       |
# |    time_elapsed    | 15248    |
# |    total_timesteps | 1617263  |
# | train/             |          |
# |    actor_loss      | -70.7    |
# |    critic_loss     | 3.38     |
# |    ent_coef        | 0.0198   |
# |    ent_coef_loss   | -1.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1637062  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -25.7    |
# | time/              |          |
# |    episodes        | 16340    |
# |    fps             | 10       |
# |    time_elapsed    | 15295    |
# |    total_timesteps | 1617758  |
# | train/             |          |
# |    actor_loss      | -70      |
# |    critic_loss     | 3.8      |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -0.529   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1637557  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -25.4    |
# | time/              |          |
# |    episodes        | 16345    |
# |    fps             | 10       |
# |    time_elapsed    | 15342    |
# |    total_timesteps | 1618253  |
# | train/             |          |
# |    actor_loss      | -69.6    |
# |    critic_loss     | 3.76     |
# |    ent_coef        | 0.018    |
# |    ent_coef_loss   | 0.0131   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1638052  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -25.1    |
# | time/              |          |
# |    episodes        | 16350    |
# |    fps             | 10       |
# |    time_elapsed    | 15391    |
# |    total_timesteps | 1618748  |
# | train/             |          |
# |    actor_loss      | -71      |
# |    critic_loss     | 3.33     |
# |    ent_coef        | 0.0169   |
# |    ent_coef_loss   | -0.589   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1638547  |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -29.4    |
# | time/              |          |
# |    episodes        | 16355    |
# |    fps             | 10       |
# |    time_elapsed    | 15440    |
# |    total_timesteps | 1619243  |
# | train/             |          |
# |    actor_loss      | -71.5    |
# |    critic_loss     | 3.57     |
# |    ent_coef        | 0.019    |
# |    ent_coef_loss   | -0.735   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1639042  |
# ---------------------------------
