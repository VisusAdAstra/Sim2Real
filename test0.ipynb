# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback


model = TQC.load("data/tqc1/tqc_model_873000_steps")
env = roboverse.make("Widow250PickPlace-v2",
                         gui=True,
                         observation_mode="pixels",
                         transpose_image=False)
model.set_env(env)
env = model.get_env()

obs = env.reset()
print("start render")
for i in range(int(1e4)):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(rewards)
    env.render("human")
env.close()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
import time
import numpy as np
from roboverse.policies import policies
from stable_baselines3.common.utils import set_random_seed


def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = roboverse.make(env_id,
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
        #env = TimeFeatureWrapper(env)
        #env.reset(seed=seed + rank)
        env.reset()
        return env
    set_random_seed(seed)
    return _init


def collect_data(env, model, policy, target, num_trajectories=100, num_timesteps=30):
    policy_class = policies[policy]
    policy = policy_class(env)
    num_success = 0
    num_saved = 0
    accept_trajectory_key = target
    noise = 0.1
    EPSILON = 0.1

    while num_saved < num_trajectories:
        num_saved += 1
        num_steps = 1e6
        rewards = []
        env.reset()
        policy.reset()
        time.sleep(0.1)
        success = False
        for j in range(num_timesteps):
            action, agent_info = policy.get_action()

            # In case we need to pad actions by 1 for easier realNVP modelling 
            env_action_dim = env.action_space.shape[0]
            #if env_action_dim - action.shape[0] == 1:
            #    action = np.append(action, 0)
            action += np.random.normal(scale=noise, size=(env_action_dim,))
            action = np.clip(action, -1 + EPSILON, 1 - EPSILON)
            observation = env.get_observation()
            observation["image"] = np.transpose(observation["image"], (2, 0, 1))
            next_observation, reward, done, info = env.step(action)
            next_observation["image"] = np.transpose(next_observation["image"], (2, 0, 1))
            rewards.append(reward)
            success = sum(rewards) > 70
            model.replay_buffer.add(observation, next_observation, action, reward, np.array([done]), [{}])

            if success and num_steps > 1e3: #info[accept_trajectory_key]
                num_steps = j

            if success and j > 23: #info[accept_trajectory_key]
                break
            if done or agent_info['done']:
                break

        if success: #info[accept_trajectory_key]
            PRINT = False
            if PRINT:
                print("num_timesteps: ", num_steps, rewards)
                #print(observation["image"].shape)
                #print(next_observation["image"].shape)
            num_success += 1
        if num_saved%100 == 0:
            print(f"num_trajectories: {num_saved} success rate: {num_success/num_saved} Reward: {sum(rewards)}")

    print("success rate: {}".format(num_success / (num_saved)))

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlace-v2",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 0
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
             policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
             #replay_buffer_class=HerReplayBuffer,
             #replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
             tau=0.05, learning_starts=0, verbose=1)

#model = TQC.load("data/tqc")
#model.set_env(env)
COLLECT=True
if COLLECT:
    collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
    model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
else:
    print("load_replay_buffer")
    model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start pre-training from buffer only")
model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.train(gradient_steps=20000)

print("start learning")
model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Widow250PickPlace-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# num_trajectories: 100 success rate: 0.93 Reward: 82.0
# num_trajectories: 200 success rate: 0.91 Reward: 82.0
# num_trajectories: 300 success rate: 0.9033333333333333 Reward: 80.0
# num_trajectories: 400 success rate: 0.9025 Reward: 75.0
# num_trajectories: 500 success rate: 0.914 Reward: 72.0
# num_trajectories: 600 success rate: 0.9166666666666666 Reward: 79.0
# num_trajectories: 700 success rate: 0.9214285714285714 Reward: 129.0
# num_trajectories: 800 success rate: 0.9175 Reward: 82.0
# num_trajectories: 900 success rate: 0.9222222222222223 Reward: 78.0
# num_trajectories: 1000 success rate: 0.923 Reward: 90.0
# num_trajectories: 1100 success rate: 0.9209090909090909 Reward: -35.0
# num_trajectories: 1200 success rate: 0.92 Reward: 78.0
# num_trajectories: 1300 success rate: 0.9176923076923077 Reward: 74.0
# num_trajectories: 1400 success rate: 0.9207142857142857 Reward: -35.0
# num_trajectories: 1500 success rate: 0.9193333333333333 Reward: -35.0
# num_trajectories: 1600 success rate: 0.92125 Reward: 81.0
# num_trajectories: 1700 success rate: 0.9211764705882353 Reward: 76.0
# num_trajectories: 1800 success rate: 0.9211111111111111 Reward: 127.0
# num_trajectories: 1900 success rate: 0.9210526315789473 Reward: 127.0
# num_trajectories: 2000 success rate: 0.922 Reward: 82.0
# num_trajectories: 2100 success rate: 0.9204761904761904 Reward: 83.0
# num_trajectories: 2200 success rate: 0.9195454545454546 Reward: 73.0
# num_trajectories: 2300 success rate: 0.9195652173913044 Reward: 77.0
# num_trajectories: 2400 success rate: 0.92125 Reward: 133.0
# num_trajectories: 2500 success rate: 0.922 Reward: 86.0
# num_trajectories: 2600 success rate: 0.9226923076923077 Reward: 80.0
# num_trajectories: 2700 success rate: 0.922962962962963 Reward: 88.0
# num_trajectories: 2800 success rate: 0.9228571428571428 Reward: 139.0
# num_trajectories: 2900 success rate: 0.9213793103448276 Reward: 135.0
# num_trajectories: 3000 success rate: 0.9206666666666666 Reward: 134.0
# num_trajectories: 3100 success rate: 0.92 Reward: -35.0
# num_trajectories: 3200 success rate: 0.9190625 Reward: 84.0
# num_trajectories: 3300 success rate: 0.9178787878787878 Reward: 74.0
# num_trajectories: 3400 success rate: 0.918235294117647 Reward: 82.0
# num_trajectories: 3500 success rate: 0.9185714285714286 Reward: 84.0
# num_trajectories: 3600 success rate: 0.9180555555555555 Reward: 86.0
# num_trajectories: 3700 success rate: 0.917027027027027 Reward: 130.0
# num_trajectories: 3800 success rate: 0.9163157894736842 Reward: 82.0
# num_trajectories: 3900 success rate: 0.9153846153846154 Reward: 82.0
# num_trajectories: 4000 success rate: 0.9155 Reward: 127.0
# num_trajectories: 4100 success rate: 0.9151219512195122 Reward: 77.0
# num_trajectories: 4200 success rate: 0.9152380952380952 Reward: -35.0
# num_trajectories: 4300 success rate: 0.9155813953488372 Reward: 131.0
# num_trajectories: 4400 success rate: 0.9145454545454546 Reward: 76.0
# num_trajectories: 4500 success rate: 0.9144444444444444 Reward: 76.0
# num_trajectories: 4600 success rate: 0.9141304347826087 Reward: 86.0
# num_trajectories: 4700 success rate: 0.9148936170212766 Reward: 79.0
# num_trajectories: 4800 success rate: 0.9147916666666667 Reward: 76.0
# num_trajectories: 4900 success rate: 0.9142857142857143 Reward: 78.0
# num_trajectories: 5000 success rate: 0.9136 Reward: 127.0
# num_trajectories: 5100 success rate: 0.9131372549019607 Reward: 16.0
# num_trajectories: 5200 success rate: 0.9134615384615384 Reward: 80.0
# num_trajectories: 5300 success rate: 0.9132075471698113 Reward: 124.0
# num_trajectories: 5400 success rate: 0.9135185185185185 Reward: 76.0
# num_trajectories: 5500 success rate: 0.9129090909090909 Reward: 86.0
# num_trajectories: 5600 success rate: 0.9135714285714286 Reward: 75.0
# num_trajectories: 5700 success rate: 0.913859649122807 Reward: 80.0
# num_trajectories: 5800 success rate: 0.9146551724137931 Reward: 78.0
# num_trajectories: 5900 success rate: 0.9144067796610169 Reward: 80.0
# num_trajectories: 6000 success rate: 0.9143333333333333 Reward: 82.0
# num_trajectories: 6100 success rate: 0.9144262295081967 Reward: 76.0
# num_trajectories: 6200 success rate: 0.9138709677419354 Reward: 127.0
# num_trajectories: 6300 success rate: 0.9134920634920635 Reward: -35.0
# num_trajectories: 6400 success rate: 0.91359375 Reward: 82.0
# num_trajectories: 6500 success rate: 0.9135384615384615 Reward: 82.0
# num_trajectories: 6600 success rate: 0.9130303030303031 Reward: 86.0
# num_trajectories: 6700 success rate: 0.9134328358208955 Reward: -35.0
# num_trajectories: 6800 success rate: 0.9136764705882353 Reward: 79.0
# num_trajectories: 6900 success rate: 0.9134782608695652 Reward: 84.0
# num_trajectories: 7000 success rate: 0.9137142857142857 Reward: 86.0
# num_trajectories: 7100 success rate: 0.9142253521126761 Reward: 82.0
# num_trajectories: 7200 success rate: 0.9147222222222222 Reward: 77.0
# num_trajectories: 7300 success rate: 0.9138356164383562 Reward: 76.0
# num_trajectories: 7400 success rate: 0.913918918918919 Reward: 76.0
# num_trajectories: 7500 success rate: 0.9144 Reward: 77.0
# num_trajectories: 7600 success rate: 0.9144736842105263 Reward: 76.0
# num_trajectories: 7700 success rate: 0.9141558441558442 Reward: 135.0
# num_trajectories: 7800 success rate: 0.9142307692307692 Reward: 82.0
# num_trajectories: 7900 success rate: 0.9143037974683544 Reward: 78.0
# num_trajectories: 8000 success rate: 0.91475 Reward: 78.0
# num_trajectories: 8100 success rate: 0.9146913580246914 Reward: 82.0
# num_trajectories: 8200 success rate: 0.9142682926829269 Reward: 82.0
# num_trajectories: 8300 success rate: 0.9143373493975904 Reward: 76.0
# num_trajectories: 8400 success rate: 0.9144047619047619 Reward: 137.0
# num_trajectories: 8500 success rate: 0.9144705882352941 Reward: 84.0
# num_trajectories: 8600 success rate: 0.9140697674418604 Reward: 86.0
# num_trajectories: 8700 success rate: 0.9139080459770115 Reward: 128.0
# num_trajectories: 8800 success rate: 0.9140909090909091 Reward: 74.0
# num_trajectories: 8900 success rate: 0.9142696629213484 Reward: 16.0
# num_trajectories: 9000 success rate: 0.914 Reward: 137.0
# num_trajectories: 9100 success rate: 0.9136263736263737 Reward: 82.0
# num_trajectories: 9200 success rate: 0.9139130434782609 Reward: 76.0
# num_trajectories: 9300 success rate: 0.9137634408602151 Reward: 80.0
# num_trajectories: 9400 success rate: 0.9138297872340425 Reward: 135.0
# num_trajectories: 9500 success rate: 0.9136842105263158 Reward: 78.0
# num_trajectories: 9600 success rate: 0.9135416666666667 Reward: 139.0
# num_trajectories: 9700 success rate: 0.9129896907216495 Reward: 75.0
# num_trajectories: 9800 success rate: 0.9131632653061225 Reward: 129.0
# num_trajectories: 9900 success rate: 0.9133333333333333 Reward: 78.0
# num_trajectories: 10000 success rate: 0.914 Reward: 131.0
# success rate: 0.914
# start pre-training from buffer only
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# start learning
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5         |
# |    fps             | 14        |
# |    time_elapsed    | 34        |
# |    total_timesteps | 495       |
# | train/             |           |
# |    actor_loss      | -3.62e+08 |
# |    critic_loss     | 3.23e+06  |
# |    ent_coef        | 1.63e+05  |
# |    ent_coef_loss   | 2.52      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20494     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 14        |
# |    time_elapsed    | 69        |
# |    total_timesteps | 990       |
# | train/             |           |
# |    actor_loss      | -3.75e+08 |
# |    critic_loss     | 3.33e+06  |
# |    ent_coef        | 1.36e+05  |
# |    ent_coef_loss   | 1.03      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20989     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 14       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 1485     |
# | train/             |          |
# |    actor_loss      | -3.9e+08 |
# |    critic_loss     | 3.52e+06 |
# |    ent_coef        | 1.33e+05 |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21484    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 14        |
# |    time_elapsed    | 139       |
# |    total_timesteps | 1980      |
# | train/             |           |
# |    actor_loss      | -4.27e+08 |
# |    critic_loss     | 3.93e+06  |
# |    ent_coef        | 1.43e+05  |
# |    ent_coef_loss   | 2.44      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21979     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 25        |
# |    fps             | 14        |
# |    time_elapsed    | 175       |
# |    total_timesteps | 2475      |
# | train/             |           |
# |    actor_loss      | -4.81e+08 |
# |    critic_loss     | 4.22e+06  |
# |    ent_coef        | 1.53e+05  |
# |    ent_coef_loss   | -3.13     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22474     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 13        |
# |    time_elapsed    | 212       |
# |    total_timesteps | 2970      |
# | train/             |           |
# |    actor_loss      | -5.34e+08 |
# |    critic_loss     | 4.54e+06  |
# |    ent_coef        | 1.79e+05  |
# |    ent_coef_loss   | -0.0463   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22969     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 35        |
# |    fps             | 13        |
# |    time_elapsed    | 247       |
# |    total_timesteps | 3465      |
# | train/             |           |
# |    actor_loss      | -5.98e+08 |
# |    critic_loss     | 5.12e+06  |
# |    ent_coef        | 2.07e+05  |
# |    ent_coef_loss   | 0.145     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23464     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 13        |
# |    time_elapsed    | 285       |
# |    total_timesteps | 3960      |
# | train/             |           |
# |    actor_loss      | -6.71e+08 |
# |    critic_loss     | 5.72e+06  |
# |    ent_coef        | 2.32e+05  |
# |    ent_coef_loss   | 0.115     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23959     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 45        |
# |    fps             | 13        |
# |    time_elapsed    | 324       |
# |    total_timesteps | 4455      |
# | train/             |           |
# |    actor_loss      | -7.45e+08 |
# |    critic_loss     | 6.34e+06  |
# |    ent_coef        | 2.63e+05  |
# |    ent_coef_loss   | -0.342    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24454     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 50        |
# |    fps             | 13        |
# |    time_elapsed    | 362       |
# |    total_timesteps | 4950      |
# | train/             |           |
# |    actor_loss      | -8.37e+08 |
# |    critic_loss     | 6.95e+06  |
# |    ent_coef        | 2.91e+05  |
# |    ent_coef_loss   | -2.06     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24949     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 13        |
# |    time_elapsed    | 399       |
# |    total_timesteps | 5445      |
# | train/             |           |
# |    actor_loss      | -9.31e+08 |
# |    critic_loss     | 8.21e+06  |
# |    ent_coef        | 3.23e+05  |
# |    ent_coef_loss   | 1.43      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25444     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 13        |
# |    time_elapsed    | 435       |
# |    total_timesteps | 5940      |
# | train/             |           |
# |    actor_loss      | -1.02e+09 |
# |    critic_loss     | 8.8e+06   |
# |    ent_coef        | 3.58e+05  |
# |    ent_coef_loss   | -2.75     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25939     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 65        |
# |    fps             | 13        |
# |    time_elapsed    | 471       |
# |    total_timesteps | 6435      |
# | train/             |           |
# |    actor_loss      | -1.14e+09 |
# |    critic_loss     | 9.71e+06  |
# |    ent_coef        | 3.88e+05  |
# |    ent_coef_loss   | -2.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26434     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 70        |
# |    fps             | 13        |
# |    time_elapsed    | 509       |
# |    total_timesteps | 6930      |
# | train/             |           |
# |    actor_loss      | -1.25e+09 |
# |    critic_loss     | 1.04e+07  |
# |    ent_coef        | 4.19e+05  |
# |    ent_coef_loss   | 0.359     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26929     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 75        |
# |    fps             | 13        |
# |    time_elapsed    | 546       |
# |    total_timesteps | 7425      |
# | train/             |           |
# |    actor_loss      | -1.37e+09 |
# |    critic_loss     | 1.29e+07  |
# |    ent_coef        | 4.62e+05  |
# |    ent_coef_loss   | -1.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27424     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 13       |
# |    time_elapsed    | 583      |
# |    total_timesteps | 7920     |
# | train/             |          |
# |    actor_loss      | -1.5e+09 |
# |    critic_loss     | 1.32e+07 |
# |    ent_coef        | 5.11e+05 |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27919    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 13        |
# |    time_elapsed    | 622       |
# |    total_timesteps | 8415      |
# | train/             |           |
# |    actor_loss      | -1.65e+09 |
# |    critic_loss     | 1.44e+07  |
# |    ent_coef        | 5.69e+05  |
# |    ent_coef_loss   | 0.112     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28414     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 13       |
# |    time_elapsed    | 660      |
# |    total_timesteps | 8910     |
# | train/             |          |
# |    actor_loss      | -1.8e+09 |
# |    critic_loss     | 1.68e+07 |
# |    ent_coef        | 6.27e+05 |
# |    ent_coef_loss   | 3.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28909    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 95        |
# |    fps             | 13        |
# |    time_elapsed    | 696       |
# |    total_timesteps | 9405      |
# | train/             |           |
# |    actor_loss      | -1.98e+09 |
# |    critic_loss     | 1.84e+07  |
# |    ent_coef        | 6.83e+05  |
# |    ent_coef_loss   | -1.81     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29404     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 13        |
# |    time_elapsed    | 733       |
# |    total_timesteps | 9900      |
# | train/             |           |
# |    actor_loss      | -2.18e+09 |
# |    critic_loss     | 1.95e+07  |
# |    ent_coef        | 7.53e+05  |
# |    ent_coef_loss   | -1.37     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29899     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 105       |
# |    fps             | 13        |
# |    time_elapsed    | 770       |
# |    total_timesteps | 10395     |
# | train/             |           |
# |    actor_loss      | -2.35e+09 |
# |    critic_loss     | 2.12e+07  |
# |    ent_coef        | 8.17e+05  |
# |    ent_coef_loss   | 4.28      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30394     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 110       |
# |    fps             | 13        |
# |    time_elapsed    | 807       |
# |    total_timesteps | 10890     |
# | train/             |           |
# |    actor_loss      | -2.61e+09 |
# |    critic_loss     | 2.31e+07  |
# |    ent_coef        | 8.96e+05  |
# |    ent_coef_loss   | -1.15     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30889     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 115       |
# |    fps             | 13        |
# |    time_elapsed    | 845       |
# |    total_timesteps | 11385     |
# | train/             |           |
# |    actor_loss      | -2.81e+09 |
# |    critic_loss     | 2.62e+07  |
# |    ent_coef        | 9.57e+05  |
# |    ent_coef_loss   | -1.75     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31384     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 13        |
# |    time_elapsed    | 882       |
# |    total_timesteps | 11880     |
# | train/             |           |
# |    actor_loss      | -3.05e+09 |
# |    critic_loss     | 2.92e+07  |
# |    ent_coef        | 1.06e+06  |
# |    ent_coef_loss   | -0.198    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31879     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 125       |
# |    fps             | 13        |
# |    time_elapsed    | 920       |
# |    total_timesteps | 12375     |
# | train/             |           |
# |    actor_loss      | -3.29e+09 |
# |    critic_loss     | 3.24e+07  |
# |    ent_coef        | 1.13e+06  |
# |    ent_coef_loss   | -0.579    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32374     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 130       |
# |    fps             | 13        |
# |    time_elapsed    | 956       |
# |    total_timesteps | 12870     |
# | train/             |           |
# |    actor_loss      | -3.58e+09 |
# |    critic_loss     | 3.81e+07  |
# |    ent_coef        | 1.2e+06   |
# |    ent_coef_loss   | 0.688     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32869     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 135       |
# |    fps             | 13        |
# |    time_elapsed    | 994       |
# |    total_timesteps | 13365     |
# | train/             |           |
# |    actor_loss      | -3.89e+09 |
# |    critic_loss     | 3.62e+07  |
# |    ent_coef        | 1.28e+06  |
# |    ent_coef_loss   | -0.736    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33364     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 13        |
# |    time_elapsed    | 1031      |
# |    total_timesteps | 13860     |
# | train/             |           |
# |    actor_loss      | -4.16e+09 |
# |    critic_loss     | 4.17e+07  |
# |    ent_coef        | 1.37e+06  |
# |    ent_coef_loss   | -1.18     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33859     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 145       |
# |    fps             | 13        |
# |    time_elapsed    | 1069      |
# |    total_timesteps | 14355     |
# | train/             |           |
# |    actor_loss      | -4.47e+09 |
# |    critic_loss     | 4.28e+07  |
# |    ent_coef        | 1.47e+06  |
# |    ent_coef_loss   | -2.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34354     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 13       |
# |    time_elapsed    | 1107     |
# |    total_timesteps | 14850    |
# | train/             |          |
# |    actor_loss      | -4.8e+09 |
# |    critic_loss     | 4.97e+07 |
# |    ent_coef        | 1.56e+06 |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34849    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 155       |
# |    fps             | 13        |
# |    time_elapsed    | 1143      |
# |    total_timesteps | 15345     |
# | train/             |           |
# |    actor_loss      | -5.09e+09 |
# |    critic_loss     | 4.87e+07  |
# |    ent_coef        | 1.67e+06  |
# |    ent_coef_loss   | 0.134     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35344     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 13        |
# |    time_elapsed    | 1179      |
# |    total_timesteps | 15840     |
# | train/             |           |
# |    actor_loss      | -5.51e+09 |
# |    critic_loss     | 5.29e+07  |
# |    ent_coef        | 1.77e+06  |
# |    ent_coef_loss   | -1.58     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35839     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 165       |
# |    fps             | 13        |
# |    time_elapsed    | 1218      |
# |    total_timesteps | 16335     |
# | train/             |           |
# |    actor_loss      | -5.83e+09 |
# |    critic_loss     | 5.9e+07   |
# |    ent_coef        | 1.87e+06  |
# |    ent_coef_loss   | 0.939     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36334     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 170       |
# |    fps             | 13        |
# |    time_elapsed    | 1256      |
# |    total_timesteps | 16830     |
# | train/             |           |
# |    actor_loss      | -6.16e+09 |
# |    critic_loss     | 6.41e+07  |
# |    ent_coef        | 1.99e+06  |
# |    ent_coef_loss   | 2.6       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36829     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 175       |
# |    fps             | 13        |
# |    time_elapsed    | 1293      |
# |    total_timesteps | 17325     |
# | train/             |           |
# |    actor_loss      | -6.62e+09 |
# |    critic_loss     | 6.96e+07  |
# |    ent_coef        | 2.11e+06  |
# |    ent_coef_loss   | 0.567     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37324     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 13        |
# |    time_elapsed    | 1330      |
# |    total_timesteps | 17820     |
# | train/             |           |
# |    actor_loss      | -6.99e+09 |
# |    critic_loss     | 7.42e+07  |
# |    ent_coef        | 2.24e+06  |
# |    ent_coef_loss   | 1.69      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37819     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 185       |
# |    fps             | 13        |
# |    time_elapsed    | 1367      |
# |    total_timesteps | 18315     |
# | train/             |           |
# |    actor_loss      | -7.45e+09 |
# |    critic_loss     | 7.22e+07  |
# |    ent_coef        | 2.37e+06  |
# |    ent_coef_loss   | -1.42     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38314     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 190       |
# |    fps             | 13        |
# |    time_elapsed    | 1406      |
# |    total_timesteps | 18810     |
# | train/             |           |
# |    actor_loss      | -7.97e+09 |
# |    critic_loss     | 7.78e+07  |
# |    ent_coef        | 2.52e+06  |
# |    ent_coef_loss   | -0.167    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38809     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 195       |
# |    fps             | 13        |
# |    time_elapsed    | 1443      |
# |    total_timesteps | 19305     |
# | train/             |           |
# |    actor_loss      | -8.46e+09 |
# |    critic_loss     | 8.61e+07  |
# |    ent_coef        | 2.7e+06   |
# |    ent_coef_loss   | -0.684    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39304     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 13        |
# |    time_elapsed    | 1480      |
# |    total_timesteps | 19800     |
# | train/             |           |
# |    actor_loss      | -8.87e+09 |
# |    critic_loss     | 8.66e+07  |
# |    ent_coef        | 2.88e+06  |
# |    ent_coef_loss   | 2.48      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 205       |
# |    fps             | 13        |
# |    time_elapsed    | 1516      |
# |    total_timesteps | 20295     |
# | train/             |           |
# |    actor_loss      | -9.38e+09 |
# |    critic_loss     | 9.71e+07  |
# |    ent_coef        | 3.02e+06  |
# |    ent_coef_loss   | 2.61      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40294     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 210       |
# |    fps             | 13        |
# |    time_elapsed    | 1553      |
# |    total_timesteps | 20790     |
# | train/             |           |
# |    actor_loss      | -9.89e+09 |
# |    critic_loss     | 9.8e+07   |
# |    ent_coef        | 3.18e+06  |
# |    ent_coef_loss   | 2.79      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40789     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 215       |
# |    fps             | 13        |
# |    time_elapsed    | 1590      |
# |    total_timesteps | 21285     |
# | train/             |           |
# |    actor_loss      | -1.04e+10 |
# |    critic_loss     | 1.1e+08   |
# |    ent_coef        | 3.4e+06   |
# |    ent_coef_loss   | 4.42      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41284     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 13       |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 21780    |
# | train/             |          |
# |    actor_loss      | -1.1e+10 |
# |    critic_loss     | 1.09e+08 |
# |    ent_coef        | 3.56e+06 |
# |    ent_coef_loss   | -0.443   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41779    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 225       |
# |    fps             | 13        |
# |    time_elapsed    | 1667      |
# |    total_timesteps | 22275     |
# | train/             |           |
# |    actor_loss      | -1.16e+10 |
# |    critic_loss     | 1.19e+08  |
# |    ent_coef        | 3.75e+06  |
# |    ent_coef_loss   | 2.15      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42274     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 230       |
# |    fps             | 13        |
# |    time_elapsed    | 1705      |
# |    total_timesteps | 22770     |
# | train/             |           |
# |    actor_loss      | -1.23e+10 |
# |    critic_loss     | 1.31e+08  |
# |    ent_coef        | 3.92e+06  |
# |    ent_coef_loss   | -1.74     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42769     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 235      |
# |    fps             | 13       |
# |    time_elapsed    | 1740     |
# |    total_timesteps | 23265    |
# | train/             |          |
# |    actor_loss      | -1.3e+10 |
# |    critic_loss     | 1.42e+08 |
# |    ent_coef        | 4.11e+06 |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43264    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 13        |
# |    time_elapsed    | 1778      |
# |    total_timesteps | 23760     |
# | train/             |           |
# |    actor_loss      | -1.37e+10 |
# |    critic_loss     | 1.42e+08  |
# |    ent_coef        | 4.29e+06  |
# |    ent_coef_loss   | 1.39      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43759     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 245       |
# |    fps             | 13        |
# |    time_elapsed    | 1816      |
# |    total_timesteps | 24255     |
# | train/             |           |
# |    actor_loss      | -1.41e+10 |
# |    critic_loss     | 1.52e+08  |
# |    ent_coef        | 4.47e+06  |
# |    ent_coef_loss   | -1.04     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44254     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 250       |
# |    fps             | 13        |
# |    time_elapsed    | 1853      |
# |    total_timesteps | 24750     |
# | train/             |           |
# |    actor_loss      | -1.49e+10 |
# |    critic_loss     | 1.47e+08  |
# |    ent_coef        | 4.62e+06  |
# |    ent_coef_loss   | 3.57      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44749     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 255       |
# |    fps             | 13        |
# |    time_elapsed    | 1890      |
# |    total_timesteps | 25245     |
# | train/             |           |
# |    actor_loss      | -1.55e+10 |
# |    critic_loss     | 1.67e+08  |
# |    ent_coef        | 4.73e+06  |
# |    ent_coef_loss   | 5.64      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45244     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 13        |
# |    time_elapsed    | 1927      |
# |    total_timesteps | 25740     |
# | train/             |           |
# |    actor_loss      | -1.61e+10 |
# |    critic_loss     | 1.75e+08  |
# |    ent_coef        | 4.92e+06  |
# |    ent_coef_loss   | 1.88      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45739     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 265      |
# |    fps             | 13       |
# |    time_elapsed    | 1966     |
# |    total_timesteps | 26235    |
# | train/             |          |
# |    actor_loss      | -1.7e+10 |
# |    critic_loss     | 1.87e+08 |
# |    ent_coef        | 5.13e+06 |
# |    ent_coef_loss   | -0.589   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46234    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 13       |
# |    time_elapsed    | 2004     |
# |    total_timesteps | 26730    |
# | train/             |          |
# |    actor_loss      | -1.8e+10 |
# |    critic_loss     | 1.92e+08 |
# |    ent_coef        | 5.4e+06  |
# |    ent_coef_loss   | -5.62    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46729    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 275       |
# |    fps             | 13        |
# |    time_elapsed    | 2043      |
# |    total_timesteps | 27225     |
# | train/             |           |
# |    actor_loss      | -1.87e+10 |
# |    critic_loss     | 2.05e+08  |
# |    ent_coef        | 5.64e+06  |
# |    ent_coef_loss   | 0.793     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47224     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 13        |
# |    time_elapsed    | 2080      |
# |    total_timesteps | 27720     |
# | train/             |           |
# |    actor_loss      | -1.94e+10 |
# |    critic_loss     | 2.15e+08  |
# |    ent_coef        | 5.8e+06   |
# |    ent_coef_loss   | 0.118     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47719     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 285      |
# |    fps             | 13       |
# |    time_elapsed    | 2118     |
# |    total_timesteps | 28215    |
# | train/             |          |
# |    actor_loss      | -2e+10   |
# |    critic_loss     | 2.24e+08 |
# |    ent_coef        | 6.09e+06 |
# |    ent_coef_loss   | -0.436   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48214    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 290       |
# |    fps             | 13        |
# |    time_elapsed    | 2153      |
# |    total_timesteps | 28710     |
# | train/             |           |
# |    actor_loss      | -2.15e+10 |
# |    critic_loss     | 2.36e+08  |
# |    ent_coef        | 6.37e+06  |
# |    ent_coef_loss   | -5        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48709     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 295       |
# |    fps             | 13        |
# |    time_elapsed    | 2191      |
# |    total_timesteps | 29205     |
# | train/             |           |
# |    actor_loss      | -2.24e+10 |
# |    critic_loss     | 2.39e+08  |
# |    ent_coef        | 6.65e+06  |
# |    ent_coef_loss   | -3.73     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49204     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 13        |
# |    time_elapsed    | 2227      |
# |    total_timesteps | 29700     |
# | train/             |           |
# |    actor_loss      | -2.33e+10 |
# |    critic_loss     | 2.46e+08  |
# |    ent_coef        | 6.92e+06  |
# |    ent_coef_loss   | 0.246     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49699     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 305       |
# |    fps             | 13        |
# |    time_elapsed    | 2263      |
# |    total_timesteps | 30195     |
# | train/             |           |
# |    actor_loss      | -2.42e+10 |
# |    critic_loss     | 2.63e+08  |
# |    ent_coef        | 7.29e+06  |
# |    ent_coef_loss   | 3.64      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50194     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 310       |
# |    fps             | 13        |
# |    time_elapsed    | 2300      |
# |    total_timesteps | 30690     |
# | train/             |           |
# |    actor_loss      | -2.52e+10 |
# |    critic_loss     | 2.7e+08   |
# |    ent_coef        | 7.54e+06  |
# |    ent_coef_loss   | -1.38     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50689     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 315       |
# |    fps             | 13        |
# |    time_elapsed    | 2337      |
# |    total_timesteps | 31185     |
# | train/             |           |
# |    actor_loss      | -2.63e+10 |
# |    critic_loss     | 2.9e+08   |
# |    ent_coef        | 7.85e+06  |
# |    ent_coef_loss   | 1.1       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 51184     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 13        |
# |    time_elapsed    | 2374      |
# |    total_timesteps | 31680     |
# | train/             |           |
# |    actor_loss      | -2.82e+10 |
# |    critic_loss     | 3.18e+08  |
# |    ent_coef        | 8.21e+06  |
# |    ent_coef_loss   | -8.09     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 51679     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 325       |
# |    fps             | 13        |
# |    time_elapsed    | 2412      |
# |    total_timesteps | 32175     |
# | train/             |           |
# |    actor_loss      | -2.85e+10 |
# |    critic_loss     | 3.28e+08  |
# |    ent_coef        | 8.44e+06  |
# |    ent_coef_loss   | -0.855    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52174     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 330       |
# |    fps             | 13        |
# |    time_elapsed    | 2450      |
# |    total_timesteps | 32670     |
# | train/             |           |
# |    actor_loss      | -2.95e+10 |
# |    critic_loss     | 3.33e+08  |
# |    ent_coef        | 8.74e+06  |
# |    ent_coef_loss   | -0.406    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52669     |
# ...
# |    fps             | 11        |
# |    time_elapsed    | 8300      |
# |    total_timesteps | 578678    |
# | train/             |           |
# |    actor_loss      | -1.27e+15 |
# |    critic_loss     | 2.27e+13  |
# |    ent_coef        | 2.58e+11  |
# |    ent_coef_loss   | 13.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 598677    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5850      |
# |    fps             | 11        |
# |    time_elapsed    | 8337      |
# |    total_timesteps | 579173    |
# | train/             |           |
# |    actor_loss      | -1.28e+15 |
# |    critic_loss     | 2.39e+13  |
# |    ent_coef        | 2.61e+11  |
# |    ent_coef_loss   | 5.14      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 599172    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5855      |
# |    fps             | 11        |
# |    time_elapsed    | 8375      |
# |    total_timesteps | 579668    |
# | train/             |           |
# |    actor_loss      | -1.28e+15 |
# |    critic_loss     | 2.35e+13  |
# |    ent_coef        | 2.57e+11  |
# |    ent_coef_loss   | 10.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 599667    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5860      |
# |    fps             | 11        |
# |    time_elapsed    | 8414      |
# |    total_timesteps | 580163    |
# | train/             |           |
# |    actor_loss      | -1.31e+15 |
# |    critic_loss     | 2.47e+13  |
# |    ent_coef        | 2.59e+11  |
# |    ent_coef_loss   | 0.186     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 600162    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5865      |
# |    fps             | 11        |
# |    time_elapsed    | 8454      |
# |    total_timesteps | 580658    |
# | train/             |           |
# |    actor_loss      | -1.29e+15 |
# |    critic_loss     | 2.24e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 3.06      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 600657    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5870      |
# |    fps             | 11        |
# |    time_elapsed    | 8491      |
# |    total_timesteps | 581153    |
# | train/             |           |
# |    actor_loss      | -1.27e+15 |
# |    critic_loss     | 2.27e+13  |
# |    ent_coef        | 2.57e+11  |
# |    ent_coef_loss   | 6.37      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 601152    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5875      |
# |    fps             | 11        |
# |    time_elapsed    | 8527      |
# |    total_timesteps | 581648    |
# | train/             |           |
# |    actor_loss      | -1.31e+15 |
# |    critic_loss     | 2.33e+13  |
# |    ent_coef        | 2.56e+11  |
# |    ent_coef_loss   | 0.309     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 601647    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5880     |
# |    fps             | 11       |
# |    time_elapsed    | 8564     |
# |    total_timesteps | 582143   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.24e+13 |
# |    ent_coef        | 2.57e+11 |
# |    ent_coef_loss   | 2.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 602142   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5885      |
# |    fps             | 11        |
# |    time_elapsed    | 8602      |
# |    total_timesteps | 582638    |
# | train/             |           |
# |    actor_loss      | -1.29e+15 |
# |    critic_loss     | 2.21e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 10.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 602637    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5890     |
# |    fps             | 11       |
# |    time_elapsed    | 8640     |
# |    total_timesteps | 583133   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.29e+13 |
# |    ent_coef        | 2.6e+11  |
# |    ent_coef_loss   | 2.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 603132   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5895     |
# |    fps             | 11       |
# |    time_elapsed    | 8676     |
# |    total_timesteps | 583628   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.55e+13 |
# |    ent_coef        | 2.57e+11 |
# |    ent_coef_loss   | -4.06    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 603627   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5900      |
# |    fps             | 11        |
# |    time_elapsed    | 8715      |
# |    total_timesteps | 584123    |
# | train/             |           |
# |    actor_loss      | -1.34e+15 |
# |    critic_loss     | 2.58e+13  |
# |    ent_coef        | 2.58e+11  |
# |    ent_coef_loss   | -3.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 604122    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5905      |
# |    fps             | 11        |
# |    time_elapsed    | 8752      |
# |    total_timesteps | 584618    |
# | train/             |           |
# |    actor_loss      | -1.32e+15 |
# |    critic_loss     | 2.37e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 5.59      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 604617    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5910      |
# |    fps             | 11        |
# |    time_elapsed    | 8789      |
# |    total_timesteps | 585113    |
# | train/             |           |
# |    actor_loss      | -1.35e+15 |
# |    critic_loss     | 2.51e+13  |
# |    ent_coef        | 2.61e+11  |
# |    ent_coef_loss   | -2.94     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 605112    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5915      |
# |    fps             | 11        |
# |    time_elapsed    | 8826      |
# |    total_timesteps | 585608    |
# | train/             |           |
# |    actor_loss      | -1.37e+15 |
# |    critic_loss     | 2.42e+13  |
# |    ent_coef        | 2.62e+11  |
# |    ent_coef_loss   | -2.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 605607    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5920      |
# |    fps             | 11        |
# |    time_elapsed    | 8865      |
# |    total_timesteps | 586103    |
# | train/             |           |
# |    actor_loss      | -1.37e+15 |
# |    critic_loss     | 2.67e+13  |
# |    ent_coef        | 2.62e+11  |
# |    ent_coef_loss   | -1.84     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 606102    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 63
#      60 collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
#      61 model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
# ---> 63 model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
#      64 model.save(f"data/seed_{seed}/tqc_pick_place")
#      65 model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")
#
# File ~/cog/cogv/lib/python3.8/site-packages/sb3_contrib/tqc/tqc.py:302, in TQC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     293 def learn(
#     294     self: SelfTQC,
#     295     total_timesteps: int,
#    (...)
#     300     progress_bar: bool = False,
#     301 ) -> SelfTQC:
# --> 302     return super().learn(
#     303         total_timesteps=total_timesteps,
#     304         callback=callback,
#     305         log_interval=log_interval,
#     306         tb_log_name=tb_log_name,
#     307         reset_num_timesteps=reset_num_timesteps,
#     308         progress_bar=progress_bar,
#     309     )
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/cog/cogv/lib/python3.8/site-packages/shimmy/openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# File ~/cog/cogv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/cog/cogv/lib/python3.8/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/Sim2Real/roboverse/envs/widow250.py:272, in Widow250Env.step(self, action)
#     267 target_ee_pos = np.clip(target_ee_pos, self.ee_pos_low,
#     268                         self.ee_pos_high)
#     269 target_gripper_state = np.clip(target_gripper_state, GRIPPER_LIMITS_LOW,
#     270                                GRIPPER_LIMITS_HIGH)
# --> 272 bullet.apply_action_ik(
#     273     target_ee_pos, target_ee_quat, target_gripper_state,
#     274     self.robot_id,
#     275     self.end_effector_index, self.movable_joints,
#     276     lower_limit=JOINT_LIMIT_LOWER,
#     277     upper_limit=JOINT_LIMIT_UPPER,
#     278     rest_pose=RESET_JOINT_VALUES,
#     279     joint_range=JOINT_RANGE,
#     280     num_sim_steps=num_sim_steps)
#     282 if self.use_neutral_action and neutral_action > 0.5:
#     283     if self.neutral_gripper_open:
#
# File ~/Sim2Real/roboverse/bullet/control.py:83, in apply_action_ik(target_ee_pos, target_ee_quat, target_gripper_state, robot_id, end_effector_index, movable_joints, lower_limit, upper_limit, rest_pose, joint_range, num_sim_steps)
#      75 p.setJointMotorControl2(robot_id,
#      76                         movable_joints[-1],
#      77                         controlMode=p.POSITION_CONTROL,
#      78                         targetPosition=target_gripper_state[1],
#      79                         force=500,
#      80                         positionGain=0.03)
#      82 for _ in range(num_sim_steps):
# ---> 83     p.stepSimulation()
#
# KeyboardInterrupt:

# %%
# import gymnasium as gym
# import numpy as np
# import roboverse

# from stable_baselines3 import TD3
# from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
# from stable_baselines3 import DDPG, HerReplayBuffer
# from sb3_contrib import TQC
# from sb3_contrib.common.wrappers import TimeFeatureWrapper
# from stable_baselines3.common.vec_env import VecNormalize
# from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
# from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


# env = roboverse.make("Widow250PickPlaceMultiObject-v0",
#                          gui=False,
#                          observation_mode="pixels",
#                          transpose_image=False)
# #env = TimeFeatureWrapper(env)
# #env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
# seed = 0
# obs = env.reset()

# # Save a checkpoint every 1000 steps
# checkpoint_callback = CheckpointCallback(
#   save_freq=1000,
#   save_path=f"./data/seed_{seed}/",
#   name_prefix="tqc_model",
#   save_replay_buffer=False,
#   save_vecnormalize=False,
# )

# model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
#              policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
#              replay_buffer_class=HerReplayBuffer,
#              replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
#              tau=0.05, learning_starts=200, verbose=1)

# #model = TQC.load("data/tqc")
# #model.set_env(env)
# COLLECT=False
# if COLLECT:
#     collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
#     model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
# else:
#     print("load_replay_buffer")
#     model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

# print("start pre-training from buffer only")
# model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
# model.train(gradient_steps=20000)

# print("start learning")
# model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
# model.save(f"data/seed_{seed}/tqc_pick_place")
# model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")

print("finish learning")
# Out:
# load_replay_buffer
# num_trajectories: 100 success rate: 0.93 Reward: 80.0
# num_trajectories: 200 success rate: 0.91 Reward: 74.0
# num_trajectories: 300 success rate: 0.9033333333333333 Reward: 78.0
# num_trajectories: 400 success rate: 0.905 Reward: 73.0
# num_trajectories: 500 success rate: 0.906 Reward: 80.0
# num_trajectories: 600 success rate: 0.905 Reward: 90.0
# num_trajectories: 700 success rate: 0.9014285714285715 Reward: 80.0
# num_trajectories: 800 success rate: 0.9 Reward: 75.0
# num_trajectories: 900 success rate: 0.8988888888888888 Reward: 84.0
# num_trajectories: 1000 success rate: 0.897 Reward: 75.0
# num_trajectories: 1100 success rate: 0.899090909090909 Reward: -35.0
# num_trajectories: 1200 success rate: 0.8983333333333333 Reward: 86.0
# num_trajectories: 1300 success rate: 0.9007692307692308 Reward: 90.0
# num_trajectories: 1400 success rate: 0.9035714285714286 Reward: 81.0
# num_trajectories: 1500 success rate: 0.9026666666666666 Reward: 78.0
# num_trajectories: 1600 success rate: 0.905 Reward: 88.0
# num_trajectories: 1700 success rate: 0.9029411764705882 Reward: 74.0
# num_trajectories: 1800 success rate: 0.9016666666666666 Reward: -35.0
# num_trajectories: 1900 success rate: 0.8994736842105263 Reward: 78.0
# num_trajectories: 2000 success rate: 0.9015 Reward: 124.0
# num_trajectories: 2100 success rate: 0.9004761904761904 Reward: -35.0
# num_trajectories: 2200 success rate: 0.9013636363636364 Reward: 141.0
# num_trajectories: 2300 success rate: 0.8995652173913044 Reward: 86.0
# num_trajectories: 2400 success rate: 0.8995833333333333 Reward: 75.0
# num_trajectories: 2500 success rate: 0.8984 Reward: 72.0
# num_trajectories: 2600 success rate: 0.8976923076923077 Reward: 72.0
# num_trajectories: 2700 success rate: 0.8985185185185185 Reward: 131.0
# num_trajectories: 2800 success rate: 0.8967857142857143 Reward: 71.0
# num_trajectories: 2900 success rate: 0.8979310344827586 Reward: 125.0
# num_trajectories: 3000 success rate: 0.897 Reward: 81.0
# num_trajectories: 3100 success rate: 0.8977419354838709 Reward: 76.0
# num_trajectories: 3200 success rate: 0.898125 Reward: 86.0
# num_trajectories: 3300 success rate: 0.8975757575757576 Reward: 122.0
# num_trajectories: 3400 success rate: 0.8985294117647059 Reward: 74.0
# num_trajectories: 3500 success rate: 0.8988571428571429 Reward: 131.0
# num_trajectories: 3600 success rate: 0.8994444444444445 Reward: 82.0
# num_trajectories: 3700 success rate: 0.8983783783783784 Reward: -35.0
# num_trajectories: 3800 success rate: 0.8989473684210526 Reward: 74.0
# num_trajectories: 3900 success rate: 0.8994871794871795 Reward: 135.0
# num_trajectories: 4000 success rate: 0.8985 Reward: 78.0
# num_trajectories: 4100 success rate: 0.8987804878048781 Reward: 78.0
# num_trajectories: 4200 success rate: 0.8997619047619048 Reward: 78.0
# num_trajectories: 4300 success rate: 0.9006976744186046 Reward: 71.0
# num_trajectories: 4400 success rate: 0.9006818181818181 Reward: 131.0
# num_trajectories: 4500 success rate: 0.9004444444444445 Reward: -35.0
# num_trajectories: 4600 success rate: 0.8989130434782608 Reward: 73.0
# num_trajectories: 4700 success rate: 0.898936170212766 Reward: 79.0
# num_trajectories: 4800 success rate: 0.8989583333333333 Reward: 131.0
# num_trajectories: 4900 success rate: 0.8989795918367347 Reward: 133.0
# num_trajectories: 5000 success rate: 0.8984 Reward: 135.0
# num_trajectories: 5100 success rate: 0.8988235294117647 Reward: 78.0
# num_trajectories: 5200 success rate: 0.8980769230769231 Reward: -35.0
# num_trajectories: 5300 success rate: 0.8977358490566038 Reward: 82.0
# num_trajectories: 5400 success rate: 0.8975925925925926 Reward: 74.0
# num_trajectories: 5500 success rate: 0.8978181818181818 Reward: 16.0
# num_trajectories: 5600 success rate: 0.8971428571428571 Reward: 80.0
# num_trajectories: 5700 success rate: 0.8966666666666666 Reward: -35.0
# num_trajectories: 5800 success rate: 0.896551724137931 Reward: 86.0
# num_trajectories: 5900 success rate: 0.8964406779661017 Reward: 139.0
# num_trajectories: 6000 success rate: 0.8953333333333333 Reward: 86.0
# num_trajectories: 6100 success rate: 0.8955737704918033 Reward: 78.0
# num_trajectories: 6200 success rate: 0.8956451612903226 Reward: 80.0
# num_trajectories: 6300 success rate: 0.8960317460317461 Reward: 131.0
# num_trajectories: 6400 success rate: 0.89640625 Reward: 76.0
# num_trajectories: 6500 success rate: 0.8969230769230769 Reward: 16.0
# num_trajectories: 6600 success rate: 0.8972727272727272 Reward: 74.0
# num_trajectories: 6700 success rate: 0.8974626865671642 Reward: 76.0
# num_trajectories: 6800 success rate: 0.8977941176470589 Reward: 80.0
# num_trajectories: 6900 success rate: 0.8981159420289855 Reward: 130.0
# num_trajectories: 7000 success rate: 0.8982857142857142 Reward: 76.0
# num_trajectories: 7100 success rate: 0.8980281690140846 Reward: -35.0
# num_trajectories: 7200 success rate: 0.8972222222222223 Reward: 126.0
# num_trajectories: 7300 success rate: 0.8976712328767124 Reward: 78.0
# num_trajectories: 7400 success rate: 0.8974324324324324 Reward: 75.0
# num_trajectories: 7500 success rate: 0.8977333333333334 Reward: 76.0
# num_trajectories: 7600 success rate: 0.8982894736842105 Reward: 80.0
# num_trajectories: 7700 success rate: 0.898961038961039 Reward: 80.0
# num_trajectories: 7800 success rate: 0.8987179487179487 Reward: 88.0
# num_trajectories: 7900 success rate: 0.899367088607595 Reward: 76.0
# num_trajectories: 8000 success rate: 0.899375 Reward: 71.0
# num_trajectories: 8100 success rate: 0.899753086419753 Reward: 78.0
# num_trajectories: 8200 success rate: 0.9 Reward: 84.0
# num_trajectories: 8300 success rate: 0.8997590361445783 Reward: 82.0
# num_trajectories: 8400 success rate: 0.8994047619047619 Reward: -35.0
# num_trajectories: 8500 success rate: 0.8995294117647059 Reward: 133.0
# num_trajectories: 8600 success rate: 0.898953488372093 Reward: 90.0
# num_trajectories: 8700 success rate: 0.899080459770115 Reward: 16.0
# num_trajectories: 8800 success rate: 0.899090909090909 Reward: 84.0
# num_trajectories: 8900 success rate: 0.898876404494382 Reward: 86.0
# num_trajectories: 9000 success rate: 0.8995555555555556 Reward: 76.0
# num_trajectories: 9100 success rate: 0.9001098901098901 Reward: 78.0
# num_trajectories: 9200 success rate: 0.9003260869565217 Reward: 75.0
# num_trajectories: 9300 success rate: 0.9005376344086021 Reward: 86.0
# num_trajectories: 9400 success rate: 0.9006382978723404 Reward: 75.0
# num_trajectories: 9500 success rate: 0.9005263157894737 Reward: 76.0
# num_trajectories: 9600 success rate: 0.9007291666666667 Reward: 133.0
# num_trajectories: 9700 success rate: 0.9009278350515464 Reward: 84.0
# num_trajectories: 9800 success rate: 0.9007142857142857 Reward: 74.0
# num_trajectories: 9900 success rate: 0.9009090909090909 Reward: 76.0
# num_trajectories: 10000 success rate: 0.9009 Reward: 137.0
# success rate: 0.9009
# Output()
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4850      |
# |    fps             | 12        |
# |    time_elapsed    | 14        |
# |    total_timesteps | 480173    |
# | train/             |           |
# |    actor_loss      | -2.87e+14 |
# |    critic_loss     | 3.24e+13  |
# |    ent_coef        | 5.2e+09   |
# |    ent_coef_loss   | -429      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 499972    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4855      |
# |    fps             | 12        |
# |    time_elapsed    | 53        |
# |    total_timesteps | 480668    |
# | train/             |           |
# |    actor_loss      | -3.03e+14 |
# |    critic_loss     | 3.26e+13  |
# |    ent_coef        | 1.14e+10  |
# |    ent_coef_loss   | -321      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 500467    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4860      |
# |    fps             | 11        |
# |    time_elapsed    | 98        |
# |    total_timesteps | 481163    |
# | train/             |           |
# |    actor_loss      | -3.09e+14 |
# |    critic_loss     | 3.23e+13  |
# |    ent_coef        | 1.91e+10  |
# |    ent_coef_loss   | -281      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 500962    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4865      |
# |    fps             | 11        |
# |    time_elapsed    | 142       |
# |    total_timesteps | 481658    |
# | train/             |           |
# |    actor_loss      | -3.26e+14 |
# |    critic_loss     | 3.3e+13   |
# |    ent_coef        | 2.9e+10   |
# |    ent_coef_loss   | -218      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 501457    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4870      |
# |    fps             | 11        |
# |    time_elapsed    | 186       |
# |    total_timesteps | 482153    |
# | train/             |           |
# |    actor_loss      | -3.25e+14 |
# |    critic_loss     | 3.2e+13   |
# |    ent_coef        | 4.14e+10  |
# |    ent_coef_loss   | -167      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 501952    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4875      |
# |    fps             | 11        |
# |    time_elapsed    | 233       |
# |    total_timesteps | 482648    |
# | train/             |           |
# |    actor_loss      | -3.32e+14 |
# |    critic_loss     | 3.21e+13  |
# |    ent_coef        | 5.69e+10  |
# |    ent_coef_loss   | -142      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 502447    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4880      |
# |    fps             | 11        |
# |    time_elapsed    | 277       |
# |    total_timesteps | 483143    |
# | train/             |           |
# |    actor_loss      | -3.25e+14 |
# |    critic_loss     | 3.09e+13  |
# |    ent_coef        | 7.43e+10  |
# |    ent_coef_loss   | -84.5     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 502942    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.3     |
# | time/              |           |
# |    episodes        | 4885      |
# |    fps             | 11        |
# |    time_elapsed    | 323       |
# |    total_timesteps | 483638    |
# | train/             |           |
# |    actor_loss      | -3.34e+14 |
# |    critic_loss     | 3.14e+13  |
# |    ent_coef        | 9.31e+10  |
# |    ent_coef_loss   | -59.8     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 503437    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4890      |
# |    fps             | 11        |
# |    time_elapsed    | 368       |
# |    total_timesteps | 484133    |
# | train/             |           |
# |    actor_loss      | -3.42e+14 |
# |    critic_loss     | 3.14e+13  |
# |    ent_coef        | 1.11e+11  |
# |    ent_coef_loss   | -35.7     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 503932    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 4895     |
# |    fps             | 11       |
# |    time_elapsed    | 414      |
# |    total_timesteps | 484628   |
# | train/             |          |
# |    actor_loss      | -3.4e+14 |
# |    critic_loss     | 3.15e+13 |
# |    ent_coef        | 1.27e+11 |
# |    ent_coef_loss   | -20.9    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 504427   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4900      |
# |    fps             | 11        |
# |    time_elapsed    | 459       |
# |    total_timesteps | 485123    |
# | train/             |           |
# |    actor_loss      | -3.53e+14 |
# |    critic_loss     | 3.18e+13  |
# |    ent_coef        | 1.4e+11   |
# |    ent_coef_loss   | -1.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 504922    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4905      |
# |    fps             | 11        |
# |    time_elapsed    | 507       |
# |    total_timesteps | 485618    |
# | train/             |           |
# |    actor_loss      | -3.42e+14 |
# |    critic_loss     | 3.08e+13  |
# |    ent_coef        | 1.48e+11  |
# |    ent_coef_loss   | -1.61     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 505417    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4910      |
# |    fps             | 11        |
# |    time_elapsed    | 552       |
# |    total_timesteps | 486113    |
# | train/             |           |
# |    actor_loss      | -3.43e+14 |
# |    critic_loss     | 3.07e+13  |
# |    ent_coef        | 1.53e+11  |
# |    ent_coef_loss   | 5.11      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 505912    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 4915     |
# |    fps             | 11       |
# |    time_elapsed    | 597      |
# |    total_timesteps | 486608   |
# | train/             |          |
# |    actor_loss      | -3.5e+14 |
# |    critic_loss     | 3.1e+13  |
# |    ent_coef        | 1.54e+11 |
# |    ent_coef_loss   | 6.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 506407   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4920      |
# |    fps             | 11        |
# |    time_elapsed    | 642       |
# |    total_timesteps | 487103    |
# | train/             |           |
# |    actor_loss      | -3.47e+14 |
# |    critic_loss     | 3.02e+13  |
# |    ent_coef        | 1.58e+11  |
# |    ent_coef_loss   | 8.47      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 506902    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4925      |
# |    fps             | 11        |
# |    time_elapsed    | 687       |
# |    total_timesteps | 487598    |
# | train/             |           |
# |    actor_loss      | -3.53e+14 |
# |    critic_loss     | 3.02e+13  |
# |    ent_coef        | 1.58e+11  |
# |    ent_coef_loss   | 9.11      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 507397    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4930      |
# |    fps             | 11        |
# |    time_elapsed    | 733       |
# |    total_timesteps | 488093    |
# | train/             |           |
# |    actor_loss      | -3.68e+14 |
# |    critic_loss     | 3.15e+13  |
# |    ent_coef        | 1.59e+11  |
# |    ent_coef_loss   | -1.74     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 507892    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -97.1     |
# | time/              |           |
# |    episodes        | 4935      |
# |    fps             | 11        |
# |    time_elapsed    | 779       |
# |    total_timesteps | 488588    |
# | train/             |           |
# |    actor_loss      | -3.65e+14 |
# |    critic_loss     | 3.15e+13  |
# |    ent_coef        | 1.61e+11  |
# |    ent_coef_loss   | -8.64     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 508387    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 4940     |
# |    fps             | 11       |
# |    time_elapsed    | 825      |
# |    total_timesteps | 489083   |
# | train/             |          |
# |    actor_loss      | -3.6e+14 |
# |    critic_loss     | 3.09e+13 |
# |    ent_coef        | 1.6e+11  |
# |    ent_coef_loss   | -2.68    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 508882   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -97.1    |
# | time/              |          |
# |    episodes        | 4945     |
# |    fps             | 11       |
# |    time_elapsed    | 869      |
# |    total_timesteps | 489578   |
# | train/             |          |
# |    actor_loss      | -3.7e+14 |
# |    critic_loss     | 3.07e+13 |
# |    ent_coef        | 1.61e+11 |
# |    ent_coef_loss   | 4.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 509377   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4950      |
# |    fps             | 11        |
# |    time_elapsed    | 914       |
# |    total_timesteps | 490073    |
# | train/             |           |
# |    actor_loss      | -3.72e+14 |
# |    critic_loss     | 3.09e+13  |
# |    ent_coef        | 1.64e+11  |
# |    ent_coef_loss   | -0.263    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 509872    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4955      |
# |    fps             | 11        |
# |    time_elapsed    | 960       |
# |    total_timesteps | 490568    |
# | train/             |           |
# |    actor_loss      | -3.69e+14 |
# |    critic_loss     | 3.06e+13  |
# |    ent_coef        | 1.65e+11  |
# |    ent_coef_loss   | 0.391     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 510367    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4960      |
# |    fps             | 10        |
# |    time_elapsed    | 1006      |
# |    total_timesteps | 491063    |
# | train/             |           |
# |    actor_loss      | -3.76e+14 |
# |    critic_loss     | 3.09e+13  |
# |    ent_coef        | 1.63e+11  |
# |    ent_coef_loss   | 3.99      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 510862    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4965      |
# |    fps             | 10        |
# |    time_elapsed    | 1052      |
# |    total_timesteps | 491558    |
# | train/             |           |
# |    actor_loss      | -3.88e+14 |
# |    critic_loss     | 3.21e+13  |
# |    ent_coef        | 1.69e+11  |
# |    ent_coef_loss   | -4.98     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 511357    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4970      |
# |    fps             | 10        |
# |    time_elapsed    | 1101      |
# |    total_timesteps | 492053    |
# | train/             |           |
# |    actor_loss      | -3.85e+14 |
# |    critic_loss     | 3.16e+13  |
# |    ent_coef        | 1.65e+11  |
# |    ent_coef_loss   | -0.969    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 511852    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.8    |
# | time/              |          |
# |    episodes        | 4975     |
# |    fps             | 10       |
# |    time_elapsed    | 1147     |
# |    total_timesteps | 492548   |
# | train/             |          |
# |    actor_loss      | -3.8e+14 |
# |    critic_loss     | 3.06e+13 |
# |    ent_coef        | 1.7e+11  |
# |    ent_coef_loss   | -0.116   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 512347   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.8    |
# | time/              |          |
# |    episodes        | 4980     |
# |    fps             | 10       |
# |    time_elapsed    | 1195     |
# |    total_timesteps | 493043   |
# | train/             |          |
# |    actor_loss      | -3.9e+14 |
# |    critic_loss     | 3.13e+13 |
# |    ent_coef        | 1.68e+11 |
# |    ent_coef_loss   | -2.57    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 512842   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.8     |
# | time/              |           |
# |    episodes        | 4985      |
# |    fps             | 10        |
# |    time_elapsed    | 1241      |
# |    total_timesteps | 493538    |
# | train/             |           |
# |    actor_loss      | -3.86e+14 |
# |    critic_loss     | 3.08e+13  |
# |    ent_coef        | 1.7e+11   |
# |    ent_coef_loss   | 5.16      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 513337    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4990      |
# |    fps             | 10        |
# |    time_elapsed    | 1291      |
# |    total_timesteps | 494033    |
# | train/             |           |
# |    actor_loss      | -3.96e+14 |
# |    critic_loss     | 3.18e+13  |
# |    ent_coef        | 1.75e+11  |
# |    ent_coef_loss   | -2.03     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 513832    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4995      |
# |    fps             | 10        |
# |    time_elapsed    | 1336      |
# |    total_timesteps | 494528    |
# | train/             |           |
# |    actor_loss      | -3.91e+14 |
# |    critic_loss     | 3.11e+13  |
# |    ent_coef        | 1.73e+11  |
# |    ent_coef_loss   | 11.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 514327    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5000      |
# |    fps             | 10        |
# |    time_elapsed    | 1380      |
# |    total_timesteps | 495023    |
# | train/             |           |
# |    actor_loss      | -3.95e+14 |
# |    critic_loss     | 3.14e+13  |
# |    ent_coef        | 1.73e+11  |
# |    ent_coef_loss   | -7.27     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 514822    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5005      |
# |    fps             | 10        |
# |    time_elapsed    | 1428      |
# |    total_timesteps | 495518    |
# | train/             |           |
# |    actor_loss      | -3.92e+14 |
# |    critic_loss     | 3.09e+13  |
# |    ent_coef        | 1.78e+11  |
# |    ent_coef_loss   | 3.03      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 515317    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5010     |
# |    fps             | 10       |
# |    time_elapsed    | 1475     |
# |    total_timesteps | 496013   |
# | train/             |          |
# |    actor_loss      | -4e+14   |
# |    critic_loss     | 3.1e+13  |
# |    ent_coef        | 1.72e+11 |
# |    ent_coef_loss   | -2.76    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 515812   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5015     |
# |    fps             | 10       |
# |    time_elapsed    | 1520     |
# |    total_timesteps | 496508   |
# | train/             |          |
# |    actor_loss      | -4e+14   |
# |    critic_loss     | 3.09e+13 |
# |    ent_coef        | 1.8e+11  |
# |    ent_coef_loss   | 9.97     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 516307   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5020      |
# |    fps             | 10        |
# |    time_elapsed    | 1569      |
# |    total_timesteps | 497003    |
# | train/             |           |
# |    actor_loss      | -4.06e+14 |
# |    critic_loss     | 3.1e+13   |
# |    ent_coef        | 1.76e+11  |
# |    ent_coef_loss   | 0.619     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 516802    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5025      |
# |    fps             | 10        |
# |    time_elapsed    | 1617      |
# |    total_timesteps | 497498    |
# | train/             |           |
# |    actor_loss      | -4.11e+14 |
# |    critic_loss     | 3.16e+13  |
# |    ent_coef        | 1.76e+11  |
# |    ent_coef_loss   | 12.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 517297    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5030      |
# |    fps             | 10        |
# |    time_elapsed    | 1665      |
# |    total_timesteps | 497993    |
# | train/             |           |
# |    actor_loss      | -4.08e+14 |
# |    critic_loss     | 3.09e+13  |
# |    ent_coef        | 1.79e+11  |
# |    ent_coef_loss   | 3.48      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 517792    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5035     |
# |    fps             | 10       |
# |    time_elapsed    | 1709     |
# |    total_timesteps | 498488   |
# | train/             |          |
# |    actor_loss      | -4.1e+14 |
# |    critic_loss     | 3.13e+13 |
# |    ent_coef        | 1.78e+11 |
# |    ent_coef_loss   | 0.627    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 518287   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5040      |
# |    fps             | 10        |
# |    time_elapsed    | 1756      |
# |    total_timesteps | 498983    |
# | train/             |           |
# |    actor_loss      | -4.24e+14 |
# |    critic_loss     | 3.18e+13  |
# |    ent_coef        | 1.8e+11   |
# |    ent_coef_loss   | 2.5       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 518782    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5045      |
# |    fps             | 10        |
# |    time_elapsed    | 1806      |
# |    total_timesteps | 499478    |
# | train/             |           |
# |    actor_loss      | -4.19e+14 |
# |    critic_loss     | 3.25e+13  |
# |    ent_coef        | 1.79e+11  |
# |    ent_coef_loss   | -4.65     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 519277    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5050      |
# |    fps             | 10        |
# |    time_elapsed    | 1851      |
# |    total_timesteps | 499973    |
# | train/             |           |
# |    actor_loss      | -4.26e+14 |
# |    critic_loss     | 3.21e+13  |
# |    ent_coef        | 1.8e+11   |
# |    ent_coef_loss   | -4.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 519772    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5055      |
# |    fps             | 10        |
# |    time_elapsed    | 1898      |
# |    total_timesteps | 500468    |
# | train/             |           |
# |    actor_loss      | -4.31e+14 |
# |    critic_loss     | 3.24e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | -3.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 520267    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5060      |
# |    fps             | 10        |
# |    time_elapsed    | 1944      |
# |    total_timesteps | 500963    |
# | train/             |           |
# |    actor_loss      | -4.32e+14 |
# |    critic_loss     | 3.23e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | 0.984     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 520762    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5065      |
# |    fps             | 10        |
# |    time_elapsed    | 1991      |
# |    total_timesteps | 501458    |
# | train/             |           |
# |    actor_loss      | -4.27e+14 |
# |    critic_loss     | 3.23e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | -1.94     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 521257    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5070      |
# |    fps             | 10        |
# |    time_elapsed    | 2041      |
# |    total_timesteps | 501953    |
# | train/             |           |
# |    actor_loss      | -4.26e+14 |
# |    critic_loss     | 3.16e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | 3.37      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 521752    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5075      |
# |    fps             | 10        |
# |    time_elapsed    | 2091      |
# |    total_timesteps | 502448    |
# | train/             |           |
# |    actor_loss      | -4.35e+14 |
# |    critic_loss     | 3.26e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | -9.59     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 522247    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5080      |
# |    fps             | 10        |
# |    time_elapsed    | 2137      |
# |    total_timesteps | 502943    |
# | train/             |           |
# |    actor_loss      | -4.29e+14 |
# |    critic_loss     | 3.22e+13  |
# |    ent_coef        | 1.81e+11  |
# |    ent_coef_loss   | -1.17     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 522742    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5085      |
# |    fps             | 10        |
# |    time_elapsed    | 2185      |
# |    total_timesteps | 503438    |
# | train/             |           |
# |    actor_loss      | -4.36e+14 |
# |    critic_loss     | 3.27e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | 4.19      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 523237    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5090      |
# |    fps             | 10        |
# |    time_elapsed    | 2231      |
# |    total_timesteps | 503933    |
# | train/             |           |
# |    actor_loss      | -4.37e+14 |
# |    critic_loss     | 3.18e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | 3.82      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 523732    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5095      |
# |    fps             | 10        |
# |    time_elapsed    | 2278      |
# |    total_timesteps | 504428    |
# | train/             |           |
# |    actor_loss      | -4.41e+14 |
# |    critic_loss     | 3.19e+13  |
# |    ent_coef        | 1.85e+11  |
# |    ent_coef_loss   | 4.57      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 524227    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5100      |
# |    fps             | 10        |
# |    time_elapsed    | 2322      |
# |    total_timesteps | 504923    |
# | train/             |           |
# |    actor_loss      | -4.47e+14 |
# |    critic_loss     | 3.36e+13  |
# |    ent_coef        | 1.87e+11  |
# |    ent_coef_loss   | -5        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 524722    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5105      |
# |    fps             | 10        |
# |    time_elapsed    | 2368      |
# |    total_timesteps | 505418    |
# | train/             |           |
# |    actor_loss      | -4.35e+14 |
# |    critic_loss     | 3.26e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | -3.09     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 525217    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5110      |
# |    fps             | 10        |
# |    time_elapsed    | 2416      |
# |    total_timesteps | 505913    |
# | train/             |           |
# |    actor_loss      | -4.44e+14 |
# |    critic_loss     | 3.29e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | -2.33     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 525712    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5115      |
# |    fps             | 10        |
# |    time_elapsed    | 2465      |
# |    total_timesteps | 506408    |
# | train/             |           |
# |    actor_loss      | -4.43e+14 |
# |    critic_loss     | 3.23e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | 1.88      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 526207    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5120      |
# |    fps             | 10        |
# |    time_elapsed    | 2511      |
# |    total_timesteps | 506903    |
# | train/             |           |
# |    actor_loss      | -4.35e+14 |
# |    critic_loss     | 3.23e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | 1.9       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 526702    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5125      |
# |    fps             | 10        |
# |    time_elapsed    | 2559      |
# |    total_timesteps | 507398    |
# | train/             |           |
# |    actor_loss      | -4.43e+14 |
# |    critic_loss     | 3.29e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | -6.37     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 527197    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5130      |
# |    fps             | 10        |
# |    time_elapsed    | 2608      |
# |    total_timesteps | 507893    |
# | train/             |           |
# |    actor_loss      | -4.44e+14 |
# |    critic_loss     | 3.27e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | -7.98     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 527692    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5135      |
# |    fps             | 10        |
# |    time_elapsed    | 2656      |
# |    total_timesteps | 508388    |
# | train/             |           |
# |    actor_loss      | -4.48e+14 |
# |    critic_loss     | 3.26e+13  |
# |    ent_coef        | 1.82e+11  |
# |    ent_coef_loss   | -4.42     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 528187    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5140     |
# |    fps             | 10       |
# |    time_elapsed    | 2700     |
# |    total_timesteps | 508883   |
# | train/             |          |
# |    actor_loss      | -4.5e+14 |
# |    critic_loss     | 3.34e+13 |
# |    ent_coef        | 1.77e+11 |
# |    ent_coef_loss   | -0.66    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 528682   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5145      |
# |    fps             | 10        |
# |    time_elapsed    | 2746      |
# |    total_timesteps | 509378    |
# | train/             |           |
# |    actor_loss      | -4.51e+14 |
# |    critic_loss     | 3.36e+13  |
# |    ent_coef        | 1.81e+11  |
# |    ent_coef_loss   | 1.9       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 529177    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5150      |
# |    fps             | 10        |
# |    time_elapsed    | 2793      |
# |    total_timesteps | 509873    |
# | train/             |           |
# |    actor_loss      | -4.46e+14 |
# |    critic_loss     | 3.34e+13  |
# |    ent_coef        | 1.8e+11   |
# |    ent_coef_loss   | 8.79      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 529672    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5155     |
# |    fps             | 10       |
# |    time_elapsed    | 2840     |
# |    total_timesteps | 510368   |
# | train/             |          |
# |    actor_loss      | -4.5e+14 |
# |    critic_loss     | 3.36e+13 |
# |    ent_coef        | 1.77e+11 |
# |    ent_coef_loss   | -2.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 530167   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5160      |
# |    fps             | 10        |
# |    time_elapsed    | 2885      |
# |    total_timesteps | 510863    |
# | train/             |           |
# |    actor_loss      | -4.51e+14 |
# |    critic_loss     | 3.34e+13  |
# |    ent_coef        | 1.79e+11  |
# |    ent_coef_loss   | -3.88     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 530662    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5165      |
# |    fps             | 10        |
# |    time_elapsed    | 2936      |
# |    total_timesteps | 511358    |
# | train/             |           |
# |    actor_loss      | -4.48e+14 |
# |    critic_loss     | 3.33e+13  |
# |    ent_coef        | 1.77e+11  |
# |    ent_coef_loss   | -1.75     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 531157    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5170      |
# |    fps             | 10        |
# |    time_elapsed    | 2982      |
# |    total_timesteps | 511853    |
# | train/             |           |
# |    actor_loss      | -4.59e+14 |
# |    critic_loss     | 3.36e+13  |
# |    ent_coef        | 1.77e+11  |
# |    ent_coef_loss   | 7.73      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 531652    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5175      |
# |    fps             | 10        |
# |    time_elapsed    | 3031      |
# |    total_timesteps | 512348    |
# | train/             |           |
# |    actor_loss      | -4.59e+14 |
# |    critic_loss     | 3.41e+13  |
# |    ent_coef        | 1.79e+11  |
# |    ent_coef_loss   | -3.86     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 532147    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5180     |
# |    fps             | 10       |
# |    time_elapsed    | 3077     |
# |    total_timesteps | 512843   |
# | train/             |          |
# |    actor_loss      | -4.5e+14 |
# |    critic_loss     | 3.35e+13 |
# |    ent_coef        | 1.76e+11 |
# |    ent_coef_loss   | 2.87     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 532642   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5185      |
# |    fps             | 10        |
# |    time_elapsed    | 3123      |
# |    total_timesteps | 513338    |
# | train/             |           |
# |    actor_loss      | -4.64e+14 |
# |    critic_loss     | 3.42e+13  |
# |    ent_coef        | 1.75e+11  |
# |    ent_coef_loss   | -6.45     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 533137    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5190      |
# |    fps             | 10        |
# |    time_elapsed    | 3169      |
# |    total_timesteps | 513833    |
# | train/             |           |
# |    actor_loss      | -4.65e+14 |
# |    critic_loss     | 3.47e+13  |
# |    ent_coef        | 1.76e+11  |
# |    ent_coef_loss   | 3.32      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 533632    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5195      |
# |    fps             | 10        |
# |    time_elapsed    | 3214      |
# |    total_timesteps | 514328    |
# | train/             |           |
# |    actor_loss      | -4.62e+14 |
# ...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6450      |
# |    fps             | 10        |
# |    time_elapsed    | 15073     |
# |    total_timesteps | 638573    |
# | train/             |           |
# |    actor_loss      | -8.12e+14 |
# |    critic_loss     | 8.16e+13  |
# |    ent_coef        | 1.85e+11  |
# |    ent_coef_loss   | 1.7       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 658372    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.9    |
# | time/              |          |
# |    episodes        | 6455     |
# |    fps             | 10       |
# |    time_elapsed    | 15122    |
# |    total_timesteps | 639068   |
# | train/             |          |
# |    actor_loss      | -8.5e+14 |
# |    critic_loss     | 8.54e+13 |
# |    ent_coef        | 1.88e+11 |
# |    ent_coef_loss   | 1.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 658867   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6460      |
# |    fps             | 10        |
# |    time_elapsed    | 15174     |
# |    total_timesteps | 639563    |
# | train/             |           |
# |    actor_loss      | -8.53e+14 |
# |    critic_loss     | 8.68e+13  |
# |    ent_coef        | 1.91e+11  |
# |    ent_coef_loss   | -0.528    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 659362    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6465      |
# |    fps             | 10        |
# |    time_elapsed    | 15221     |
# |    total_timesteps | 640058    |
# | train/             |           |
# |    actor_loss      | -8.46e+14 |
# |    critic_loss     | 8.61e+13  |
# |    ent_coef        | 1.92e+11  |
# |    ent_coef_loss   | -0.582    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 659857    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6470      |
# |    fps             | 10        |
# |    time_elapsed    | 15270     |
# |    total_timesteps | 640553    |
# | train/             |           |
# |    actor_loss      | -8.38e+14 |
# |    critic_loss     | 8.58e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | 4.65      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 660352    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6475      |
# |    fps             | 10        |
# |    time_elapsed    | 15319     |
# |    total_timesteps | 641048    |
# | train/             |           |
# |    actor_loss      | -8.58e+14 |
# |    critic_loss     | 8.76e+13  |
# |    ent_coef        | 1.89e+11  |
# |    ent_coef_loss   | 5.89      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 660847    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6480      |
# |    fps             | 10        |
# |    time_elapsed    | 15365     |
# |    total_timesteps | 641543    |
# | train/             |           |
# |    actor_loss      | -8.42e+14 |
# |    critic_loss     | 8.51e+13  |
# |    ent_coef        | 1.85e+11  |
# |    ent_coef_loss   | 2.56      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 661342    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6485      |
# |    fps             | 10        |
# |    time_elapsed    | 15416     |
# |    total_timesteps | 642038    |
# | train/             |           |
# |    actor_loss      | -8.56e+14 |
# |    critic_loss     | 8.76e+13  |
# |    ent_coef        | 1.9e+11   |
# |    ent_coef_loss   | -4.28     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 661837    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6490      |
# |    fps             | 10        |
# |    time_elapsed    | 15466     |
# |    total_timesteps | 642533    |
# | train/             |           |
# |    actor_loss      | -8.41e+14 |
# |    critic_loss     | 8.52e+13  |
# |    ent_coef        | 1.86e+11  |
# |    ent_coef_loss   | 6.91      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 662332    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.9     |
# | time/              |           |
# |    episodes        | 6495      |
# |    fps             | 10        |
# |    time_elapsed    | 15515     |
# |    total_timesteps | 643028    |
# | train/             |           |
# |    actor_loss      | -8.63e+14 |
# |    critic_loss     | 8.88e+13  |
# |    ent_coef        | 1.9e+11   |
# |    ent_coef_loss   | -1.44     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 662827    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.9    |
# | time/              |          |
# |    episodes        | 6500     |
# |    fps             | 10       |
# |    time_elapsed    | 15564    |
# |    total_timesteps | 643523   |
# | train/             |          |
# |    actor_loss      | -8.5e+14 |
# |    critic_loss     | 8.68e+13 |
# |    ent_coef        | 1.88e+11 |
# |    ent_coef_loss   | 9.11     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 663322   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 6505      |
# |    fps             | 10        |
# |    time_elapsed    | 15609     |
# |    total_timesteps | 644018    |
# | train/             |           |
# |    actor_loss      | -8.42e+14 |
# |    critic_loss     | 8.59e+13  |
# |    ent_coef        | 1.88e+11  |
# |    ent_coef_loss   | 0.774     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 663817    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 6510      |
# |    fps             | 10        |
# |    time_elapsed    | 15653     |
# |    total_timesteps | 644513    |
# | train/             |           |
# |    actor_loss      | -8.66e+14 |
# |    critic_loss     | 8.93e+13  |
# |    ent_coef        | 1.88e+11  |
# |    ent_coef_loss   | 0.351     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 664312    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 6515      |
# |    fps             | 10        |
# |    time_elapsed    | 15697     |
# |    total_timesteps | 645008    |
# | train/             |           |
# |    actor_loss      | -8.49e+14 |
# |    critic_loss     | 8.74e+13  |
# |    ent_coef        | 1.89e+11  |
# |    ent_coef_loss   | 4.29      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 664807    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 6520     |
# |    fps             | 10       |
# |    time_elapsed    | 15745    |
# |    total_timesteps | 645503   |
# | train/             |          |
# |    actor_loss      | -8.4e+14 |
# |    critic_loss     | 8.63e+13 |
# |    ent_coef        | 1.87e+11 |
# |    ent_coef_loss   | 16.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 665302   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 6525      |
# |    fps             | 10        |
# |    time_elapsed    | 15794     |
# |    total_timesteps | 645998    |
# | train/             |           |
# |    actor_loss      | -8.68e+14 |
# |    critic_loss     | 8.95e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | 1.29      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 665797    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6530      |
# |    fps             | 10        |
# |    time_elapsed    | 15840     |
# |    total_timesteps | 646493    |
# | train/             |           |
# |    actor_loss      | -8.84e+14 |
# |    critic_loss     | 9.12e+13  |
# |    ent_coef        | 1.81e+11  |
# |    ent_coef_loss   | -10.1     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 666292    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6535      |
# |    fps             | 10        |
# |    time_elapsed    | 15886     |
# |    total_timesteps | 646988    |
# | train/             |           |
# |    actor_loss      | -8.37e+14 |
# |    critic_loss     | 8.55e+13  |
# |    ent_coef        | 1.9e+11   |
# |    ent_coef_loss   | 9.34      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 666787    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6540      |
# |    fps             | 10        |
# |    time_elapsed    | 15934     |
# |    total_timesteps | 647483    |
# | train/             |           |
# |    actor_loss      | -8.63e+14 |
# |    critic_loss     | 8.76e+13  |
# |    ent_coef        | 1.87e+11  |
# |    ent_coef_loss   | -4.48     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 667282    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6545      |
# |    fps             | 10        |
# |    time_elapsed    | 15982     |
# |    total_timesteps | 647978    |
# | train/             |           |
# |    actor_loss      | -8.72e+14 |
# |    critic_loss     | 9.02e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | -13.2     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 667777    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6550      |
# |    fps             | 10        |
# |    time_elapsed    | 16035     |
# |    total_timesteps | 648473    |
# | train/             |           |
# |    actor_loss      | -8.73e+14 |
# |    critic_loss     | 9.07e+13  |
# |    ent_coef        | 1.83e+11  |
# |    ent_coef_loss   | -2.82     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 668272    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6555      |
# |    fps             | 10        |
# |    time_elapsed    | 16082     |
# |    total_timesteps | 648968    |
# | train/             |           |
# |    actor_loss      | -8.59e+14 |
# |    critic_loss     | 9e+13     |
# |    ent_coef        | 1.92e+11  |
# |    ent_coef_loss   | 6.01      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 668767    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6560      |
# |    fps             | 10        |
# |    time_elapsed    | 16128     |
# |    total_timesteps | 649463    |
# | train/             |           |
# |    actor_loss      | -8.64e+14 |
# |    critic_loss     | 9.04e+13  |
# |    ent_coef        | 1.91e+11  |
# |    ent_coef_loss   | 8.97      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 669262    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6565      |
# |    fps             | 10        |
# |    time_elapsed    | 16178     |
# |    total_timesteps | 649958    |
# | train/             |           |
# |    actor_loss      | -8.44e+14 |
# |    critic_loss     | 8.79e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | 4.61      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 669757    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -96.2    |
# | time/              |          |
# |    episodes        | 6570     |
# |    fps             | 10       |
# |    time_elapsed    | 16225    |
# |    total_timesteps | 650453   |
# | train/             |          |
# |    actor_loss      | -8.4e+14 |
# |    critic_loss     | 8.65e+13 |
# |    ent_coef        | 1.84e+11 |
# |    ent_coef_loss   | 14.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 670252   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -96.2     |
# | time/              |           |
# |    episodes        | 6575      |
# |    fps             | 10        |
# |    time_elapsed    | 16275     |
# |    total_timesteps | 650948    |
# | train/             |           |
# |    actor_loss      | -8.94e+14 |
# |    critic_loss     | 9.32e+13  |
# |    ent_coef        | 1.87e+11  |
# |    ent_coef_loss   | -2.87     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 670747    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -95.6     |
# | time/              |           |
# |    episodes        | 6580      |
# |    fps             | 10        |
# |    time_elapsed    | 16322     |
# |    total_timesteps | 651443    |
# | train/             |           |
# |    actor_loss      | -8.94e+14 |
# |    critic_loss     | 9.35e+13  |
# |    ent_coef        | 1.84e+11  |
# |    ent_coef_loss   | -4.22     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 671242    |
# ----------------------------------
