# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback


model = TQC.load("data/tqc1/tqc_model_873000_steps")
env = roboverse.make("Widow250PickPlace-v2",
                         gui=True,
                         observation_mode="pixels",
                         transpose_image=False)
model.set_env(env)
env = model.get_env()

obs = env.reset()
print("start render")
for i in range(int(1e4)):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    print(rewards)
    env.render("human")
env.close()

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

# %%
import time
import numpy as np
from roboverse.policies import policies
from stable_baselines3.common.utils import set_random_seed


def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = roboverse.make(env_id,
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
        #env = TimeFeatureWrapper(env)
        #env.reset(seed=seed + rank)
        env.reset()
        return env
    set_random_seed(seed)
    return _init


def collect_data(env, model, policy, target, num_trajectories=100, num_timesteps=30):
    policy_class = policies[policy]
    policy = policy_class(env)
    num_success = 0
    num_saved = 0
    accept_trajectory_key = target
    noise = 0.1
    EPSILON = 0.1

    while num_saved < num_trajectories:
        num_saved += 1
        num_steps = 1e6
        rewards = []
        env.reset()
        policy.reset()
        time.sleep(0.1)
        success = False
        for j in range(num_timesteps):
            action, agent_info = policy.get_action()

            # In case we need to pad actions by 1 for easier realNVP modelling 
            env_action_dim = env.action_space.shape[0]
            #if env_action_dim - action.shape[0] == 1:
            #    action = np.append(action, 0)
            action += np.random.normal(scale=noise, size=(env_action_dim,))
            action = np.clip(action, -1 + EPSILON, 1 - EPSILON)
            observation = env.get_observation()
            observation["image"] = np.transpose(observation["image"], (2, 0, 1))
            next_observation, reward, done, info = env.step(action)
            next_observation["image"] = np.transpose(next_observation["image"], (2, 0, 1))
            rewards.append(reward)
            success = sum(rewards) > 70
            model.replay_buffer.add(observation, next_observation, action, reward, np.array([done]), [{}])

            if success and num_steps > 1e3: #info[accept_trajectory_key]
                num_steps = j

            if success and j > 23: #info[accept_trajectory_key]
                break
            if done or agent_info['done']:
                break

        if success: #info[accept_trajectory_key]
            PRINT = False
            if PRINT:
                print("num_timesteps: ", num_steps, rewards)
                #print(observation["image"].shape)
                #print(next_observation["image"].shape)
            num_success += 1
        if num_saved%100 == 0:
            print(f"num_trajectories: {num_saved} success rate: {num_success/num_saved} Reward: {sum(rewards)}")

    print("success rate: {}".format(num_success / (num_saved)))
# Out:
# pybullet build time: May 20 2022 19:44:17

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlace-v2",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 0
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
             policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
             #replay_buffer_class=HerReplayBuffer,
             #replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
             tau=0.05, learning_starts=0, verbose=1)

#model = TQC.load("data/tqc")
#model.set_env(env)
COLLECT=True
if COLLECT:
    collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
    model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
else:
    print("load_replay_buffer")
    model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start pre-training from buffer only")
model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.train(gradient_steps=20000)

print("start learning")
model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Widow250PickPlace-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# num_trajectories: 100 success rate: 0.93 Reward: 82.0
# num_trajectories: 200 success rate: 0.91 Reward: 82.0
# num_trajectories: 300 success rate: 0.9033333333333333 Reward: 80.0
# num_trajectories: 400 success rate: 0.9025 Reward: 75.0
# num_trajectories: 500 success rate: 0.914 Reward: 72.0
# num_trajectories: 600 success rate: 0.9166666666666666 Reward: 79.0
# num_trajectories: 700 success rate: 0.9214285714285714 Reward: 129.0
# num_trajectories: 800 success rate: 0.9175 Reward: 82.0
# num_trajectories: 900 success rate: 0.9222222222222223 Reward: 78.0
# num_trajectories: 1000 success rate: 0.923 Reward: 90.0
# num_trajectories: 1100 success rate: 0.9209090909090909 Reward: -35.0
# num_trajectories: 1200 success rate: 0.92 Reward: 78.0
# num_trajectories: 1300 success rate: 0.9176923076923077 Reward: 74.0
# num_trajectories: 1400 success rate: 0.9207142857142857 Reward: -35.0
# num_trajectories: 1500 success rate: 0.9193333333333333 Reward: -35.0
# num_trajectories: 1600 success rate: 0.92125 Reward: 81.0
# num_trajectories: 1700 success rate: 0.9211764705882353 Reward: 76.0
# num_trajectories: 1800 success rate: 0.9211111111111111 Reward: 127.0
# num_trajectories: 1900 success rate: 0.9210526315789473 Reward: 127.0
# num_trajectories: 2000 success rate: 0.922 Reward: 82.0
# num_trajectories: 2100 success rate: 0.9204761904761904 Reward: 83.0
# num_trajectories: 2200 success rate: 0.9195454545454546 Reward: 73.0
# num_trajectories: 2300 success rate: 0.9195652173913044 Reward: 77.0
# num_trajectories: 2400 success rate: 0.92125 Reward: 133.0
# num_trajectories: 2500 success rate: 0.922 Reward: 86.0
# num_trajectories: 2600 success rate: 0.9226923076923077 Reward: 80.0
# num_trajectories: 2700 success rate: 0.922962962962963 Reward: 88.0
# num_trajectories: 2800 success rate: 0.9228571428571428 Reward: 139.0
# num_trajectories: 2900 success rate: 0.9213793103448276 Reward: 135.0
# num_trajectories: 3000 success rate: 0.9206666666666666 Reward: 134.0
# num_trajectories: 3100 success rate: 0.92 Reward: -35.0
# num_trajectories: 3200 success rate: 0.9190625 Reward: 84.0
# num_trajectories: 3300 success rate: 0.9178787878787878 Reward: 74.0
# num_trajectories: 3400 success rate: 0.918235294117647 Reward: 82.0
# num_trajectories: 3500 success rate: 0.9185714285714286 Reward: 84.0
# num_trajectories: 3600 success rate: 0.9180555555555555 Reward: 86.0
# num_trajectories: 3700 success rate: 0.917027027027027 Reward: 130.0
# num_trajectories: 3800 success rate: 0.9163157894736842 Reward: 82.0
# num_trajectories: 3900 success rate: 0.9153846153846154 Reward: 82.0
# num_trajectories: 4000 success rate: 0.9155 Reward: 127.0
# num_trajectories: 4100 success rate: 0.9151219512195122 Reward: 77.0
# num_trajectories: 4200 success rate: 0.9152380952380952 Reward: -35.0
# num_trajectories: 4300 success rate: 0.9155813953488372 Reward: 131.0
# num_trajectories: 4400 success rate: 0.9145454545454546 Reward: 76.0
# num_trajectories: 4500 success rate: 0.9144444444444444 Reward: 76.0
# num_trajectories: 4600 success rate: 0.9141304347826087 Reward: 86.0
# num_trajectories: 4700 success rate: 0.9148936170212766 Reward: 79.0
# num_trajectories: 4800 success rate: 0.9147916666666667 Reward: 76.0
# num_trajectories: 4900 success rate: 0.9142857142857143 Reward: 78.0
# num_trajectories: 5000 success rate: 0.9136 Reward: 127.0
# num_trajectories: 5100 success rate: 0.9131372549019607 Reward: 16.0
# num_trajectories: 5200 success rate: 0.9134615384615384 Reward: 80.0
# num_trajectories: 5300 success rate: 0.9132075471698113 Reward: 124.0
# num_trajectories: 5400 success rate: 0.9135185185185185 Reward: 76.0
# num_trajectories: 5500 success rate: 0.9129090909090909 Reward: 86.0
# num_trajectories: 5600 success rate: 0.9135714285714286 Reward: 75.0
# num_trajectories: 5700 success rate: 0.913859649122807 Reward: 80.0
# num_trajectories: 5800 success rate: 0.9146551724137931 Reward: 78.0
# num_trajectories: 5900 success rate: 0.9144067796610169 Reward: 80.0
# num_trajectories: 6000 success rate: 0.9143333333333333 Reward: 82.0
# num_trajectories: 6100 success rate: 0.9144262295081967 Reward: 76.0
# num_trajectories: 6200 success rate: 0.9138709677419354 Reward: 127.0
# num_trajectories: 6300 success rate: 0.9134920634920635 Reward: -35.0
# num_trajectories: 6400 success rate: 0.91359375 Reward: 82.0
# num_trajectories: 6500 success rate: 0.9135384615384615 Reward: 82.0
# num_trajectories: 6600 success rate: 0.9130303030303031 Reward: 86.0
# num_trajectories: 6700 success rate: 0.9134328358208955 Reward: -35.0
# num_trajectories: 6800 success rate: 0.9136764705882353 Reward: 79.0
# num_trajectories: 6900 success rate: 0.9134782608695652 Reward: 84.0
# num_trajectories: 7000 success rate: 0.9137142857142857 Reward: 86.0
# num_trajectories: 7100 success rate: 0.9142253521126761 Reward: 82.0
# num_trajectories: 7200 success rate: 0.9147222222222222 Reward: 77.0
# num_trajectories: 7300 success rate: 0.9138356164383562 Reward: 76.0
# num_trajectories: 7400 success rate: 0.913918918918919 Reward: 76.0
# num_trajectories: 7500 success rate: 0.9144 Reward: 77.0
# num_trajectories: 7600 success rate: 0.9144736842105263 Reward: 76.0
# num_trajectories: 7700 success rate: 0.9141558441558442 Reward: 135.0
# num_trajectories: 7800 success rate: 0.9142307692307692 Reward: 82.0
# num_trajectories: 7900 success rate: 0.9143037974683544 Reward: 78.0
# num_trajectories: 8000 success rate: 0.91475 Reward: 78.0
# num_trajectories: 8100 success rate: 0.9146913580246914 Reward: 82.0
# num_trajectories: 8200 success rate: 0.9142682926829269 Reward: 82.0
# num_trajectories: 8300 success rate: 0.9143373493975904 Reward: 76.0
# num_trajectories: 8400 success rate: 0.9144047619047619 Reward: 137.0
# num_trajectories: 8500 success rate: 0.9144705882352941 Reward: 84.0
# num_trajectories: 8600 success rate: 0.9140697674418604 Reward: 86.0
# num_trajectories: 8700 success rate: 0.9139080459770115 Reward: 128.0
# num_trajectories: 8800 success rate: 0.9140909090909091 Reward: 74.0
# num_trajectories: 8900 success rate: 0.9142696629213484 Reward: 16.0
# num_trajectories: 9000 success rate: 0.914 Reward: 137.0
# num_trajectories: 9100 success rate: 0.9136263736263737 Reward: 82.0
# num_trajectories: 9200 success rate: 0.9139130434782609 Reward: 76.0
# num_trajectories: 9300 success rate: 0.9137634408602151 Reward: 80.0
# num_trajectories: 9400 success rate: 0.9138297872340425 Reward: 135.0
# num_trajectories: 9500 success rate: 0.9136842105263158 Reward: 78.0
# num_trajectories: 9600 success rate: 0.9135416666666667 Reward: 139.0
# num_trajectories: 9700 success rate: 0.9129896907216495 Reward: 75.0
# num_trajectories: 9800 success rate: 0.9131632653061225 Reward: 129.0
# num_trajectories: 9900 success rate: 0.9133333333333333 Reward: 78.0
# num_trajectories: 10000 success rate: 0.914 Reward: 131.0
# success rate: 0.914
# start pre-training from buffer only
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# start learning
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5         |
# |    fps             | 14        |
# |    time_elapsed    | 34        |
# |    total_timesteps | 495       |
# | train/             |           |
# |    actor_loss      | -3.62e+08 |
# |    critic_loss     | 3.23e+06  |
# |    ent_coef        | 1.63e+05  |
# |    ent_coef_loss   | 2.52      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20494     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 14        |
# |    time_elapsed    | 69        |
# |    total_timesteps | 990       |
# | train/             |           |
# |    actor_loss      | -3.75e+08 |
# |    critic_loss     | 3.33e+06  |
# |    ent_coef        | 1.36e+05  |
# |    ent_coef_loss   | 1.03      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20989     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 15       |
# |    fps             | 14       |
# |    time_elapsed    | 105      |
# |    total_timesteps | 1485     |
# | train/             |          |
# |    actor_loss      | -3.9e+08 |
# |    critic_loss     | 3.52e+06 |
# |    ent_coef        | 1.33e+05 |
# |    ent_coef_loss   | -0.117   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 21484    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 14        |
# |    time_elapsed    | 139       |
# |    total_timesteps | 1980      |
# | train/             |           |
# |    actor_loss      | -4.27e+08 |
# |    critic_loss     | 3.93e+06  |
# |    ent_coef        | 1.43e+05  |
# |    ent_coef_loss   | 2.44      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21979     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 25        |
# |    fps             | 14        |
# |    time_elapsed    | 175       |
# |    total_timesteps | 2475      |
# | train/             |           |
# |    actor_loss      | -4.81e+08 |
# |    critic_loss     | 4.22e+06  |
# |    ent_coef        | 1.53e+05  |
# |    ent_coef_loss   | -3.13     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22474     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 13        |
# |    time_elapsed    | 212       |
# |    total_timesteps | 2970      |
# | train/             |           |
# |    actor_loss      | -5.34e+08 |
# |    critic_loss     | 4.54e+06  |
# |    ent_coef        | 1.79e+05  |
# |    ent_coef_loss   | -0.0463   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22969     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 35        |
# |    fps             | 13        |
# |    time_elapsed    | 247       |
# |    total_timesteps | 3465      |
# | train/             |           |
# |    actor_loss      | -5.98e+08 |
# |    critic_loss     | 5.12e+06  |
# |    ent_coef        | 2.07e+05  |
# |    ent_coef_loss   | 0.145     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23464     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 13        |
# |    time_elapsed    | 285       |
# |    total_timesteps | 3960      |
# | train/             |           |
# |    actor_loss      | -6.71e+08 |
# |    critic_loss     | 5.72e+06  |
# |    ent_coef        | 2.32e+05  |
# |    ent_coef_loss   | 0.115     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23959     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 45        |
# |    fps             | 13        |
# |    time_elapsed    | 324       |
# |    total_timesteps | 4455      |
# | train/             |           |
# |    actor_loss      | -7.45e+08 |
# |    critic_loss     | 6.34e+06  |
# |    ent_coef        | 2.63e+05  |
# |    ent_coef_loss   | -0.342    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24454     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 50        |
# |    fps             | 13        |
# |    time_elapsed    | 362       |
# |    total_timesteps | 4950      |
# | train/             |           |
# |    actor_loss      | -8.37e+08 |
# |    critic_loss     | 6.95e+06  |
# |    ent_coef        | 2.91e+05  |
# |    ent_coef_loss   | -2.06     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24949     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 13        |
# |    time_elapsed    | 399       |
# |    total_timesteps | 5445      |
# | train/             |           |
# |    actor_loss      | -9.31e+08 |
# |    critic_loss     | 8.21e+06  |
# |    ent_coef        | 3.23e+05  |
# |    ent_coef_loss   | 1.43      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25444     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 13        |
# |    time_elapsed    | 435       |
# |    total_timesteps | 5940      |
# | train/             |           |
# |    actor_loss      | -1.02e+09 |
# |    critic_loss     | 8.8e+06   |
# |    ent_coef        | 3.58e+05  |
# |    ent_coef_loss   | -2.75     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25939     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 65        |
# |    fps             | 13        |
# |    time_elapsed    | 471       |
# |    total_timesteps | 6435      |
# | train/             |           |
# |    actor_loss      | -1.14e+09 |
# |    critic_loss     | 9.71e+06  |
# |    ent_coef        | 3.88e+05  |
# |    ent_coef_loss   | -2.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26434     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 70        |
# |    fps             | 13        |
# |    time_elapsed    | 509       |
# |    total_timesteps | 6930      |
# | train/             |           |
# |    actor_loss      | -1.25e+09 |
# |    critic_loss     | 1.04e+07  |
# |    ent_coef        | 4.19e+05  |
# |    ent_coef_loss   | 0.359     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26929     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 75        |
# |    fps             | 13        |
# |    time_elapsed    | 546       |
# |    total_timesteps | 7425      |
# | train/             |           |
# |    actor_loss      | -1.37e+09 |
# |    critic_loss     | 1.29e+07  |
# |    ent_coef        | 4.62e+05  |
# |    ent_coef_loss   | -1.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27424     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 80       |
# |    fps             | 13       |
# |    time_elapsed    | 583      |
# |    total_timesteps | 7920     |
# | train/             |          |
# |    actor_loss      | -1.5e+09 |
# |    critic_loss     | 1.32e+07 |
# |    ent_coef        | 5.11e+05 |
# |    ent_coef_loss   | 1.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 27919    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 13        |
# |    time_elapsed    | 622       |
# |    total_timesteps | 8415      |
# | train/             |           |
# |    actor_loss      | -1.65e+09 |
# |    critic_loss     | 1.44e+07  |
# |    ent_coef        | 5.69e+05  |
# |    ent_coef_loss   | 0.112     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28414     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 90       |
# |    fps             | 13       |
# |    time_elapsed    | 660      |
# |    total_timesteps | 8910     |
# | train/             |          |
# |    actor_loss      | -1.8e+09 |
# |    critic_loss     | 1.68e+07 |
# |    ent_coef        | 6.27e+05 |
# |    ent_coef_loss   | 3.43     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 28909    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 95        |
# |    fps             | 13        |
# |    time_elapsed    | 696       |
# |    total_timesteps | 9405      |
# | train/             |           |
# |    actor_loss      | -1.98e+09 |
# |    critic_loss     | 1.84e+07  |
# |    ent_coef        | 6.83e+05  |
# |    ent_coef_loss   | -1.81     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29404     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 13        |
# |    time_elapsed    | 733       |
# |    total_timesteps | 9900      |
# | train/             |           |
# |    actor_loss      | -2.18e+09 |
# |    critic_loss     | 1.95e+07  |
# |    ent_coef        | 7.53e+05  |
# |    ent_coef_loss   | -1.37     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29899     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 105       |
# |    fps             | 13        |
# |    time_elapsed    | 770       |
# |    total_timesteps | 10395     |
# | train/             |           |
# |    actor_loss      | -2.35e+09 |
# |    critic_loss     | 2.12e+07  |
# |    ent_coef        | 8.17e+05  |
# |    ent_coef_loss   | 4.28      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30394     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 110       |
# |    fps             | 13        |
# |    time_elapsed    | 807       |
# |    total_timesteps | 10890     |
# | train/             |           |
# |    actor_loss      | -2.61e+09 |
# |    critic_loss     | 2.31e+07  |
# |    ent_coef        | 8.96e+05  |
# |    ent_coef_loss   | -1.15     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30889     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 115       |
# |    fps             | 13        |
# |    time_elapsed    | 845       |
# |    total_timesteps | 11385     |
# | train/             |           |
# |    actor_loss      | -2.81e+09 |
# |    critic_loss     | 2.62e+07  |
# |    ent_coef        | 9.57e+05  |
# |    ent_coef_loss   | -1.75     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31384     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 13        |
# |    time_elapsed    | 882       |
# |    total_timesteps | 11880     |
# | train/             |           |
# |    actor_loss      | -3.05e+09 |
# |    critic_loss     | 2.92e+07  |
# |    ent_coef        | 1.06e+06  |
# |    ent_coef_loss   | -0.198    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31879     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 125       |
# |    fps             | 13        |
# |    time_elapsed    | 920       |
# |    total_timesteps | 12375     |
# | train/             |           |
# |    actor_loss      | -3.29e+09 |
# |    critic_loss     | 3.24e+07  |
# |    ent_coef        | 1.13e+06  |
# |    ent_coef_loss   | -0.579    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32374     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 130       |
# |    fps             | 13        |
# |    time_elapsed    | 956       |
# |    total_timesteps | 12870     |
# | train/             |           |
# |    actor_loss      | -3.58e+09 |
# |    critic_loss     | 3.81e+07  |
# |    ent_coef        | 1.2e+06   |
# |    ent_coef_loss   | 0.688     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32869     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 135       |
# |    fps             | 13        |
# |    time_elapsed    | 994       |
# |    total_timesteps | 13365     |
# | train/             |           |
# |    actor_loss      | -3.89e+09 |
# |    critic_loss     | 3.62e+07  |
# |    ent_coef        | 1.28e+06  |
# |    ent_coef_loss   | -0.736    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33364     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 13        |
# |    time_elapsed    | 1031      |
# |    total_timesteps | 13860     |
# | train/             |           |
# |    actor_loss      | -4.16e+09 |
# |    critic_loss     | 4.17e+07  |
# |    ent_coef        | 1.37e+06  |
# |    ent_coef_loss   | -1.18     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33859     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 145       |
# |    fps             | 13        |
# |    time_elapsed    | 1069      |
# |    total_timesteps | 14355     |
# | train/             |           |
# |    actor_loss      | -4.47e+09 |
# |    critic_loss     | 4.28e+07  |
# |    ent_coef        | 1.47e+06  |
# |    ent_coef_loss   | -2.8      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34354     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 150      |
# |    fps             | 13       |
# |    time_elapsed    | 1107     |
# |    total_timesteps | 14850    |
# | train/             |          |
# |    actor_loss      | -4.8e+09 |
# |    critic_loss     | 4.97e+07 |
# |    ent_coef        | 1.56e+06 |
# |    ent_coef_loss   | -1.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 34849    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 155       |
# |    fps             | 13        |
# |    time_elapsed    | 1143      |
# |    total_timesteps | 15345     |
# | train/             |           |
# |    actor_loss      | -5.09e+09 |
# |    critic_loss     | 4.87e+07  |
# |    ent_coef        | 1.67e+06  |
# |    ent_coef_loss   | 0.134     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35344     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 13        |
# |    time_elapsed    | 1179      |
# |    total_timesteps | 15840     |
# | train/             |           |
# |    actor_loss      | -5.51e+09 |
# |    critic_loss     | 5.29e+07  |
# |    ent_coef        | 1.77e+06  |
# |    ent_coef_loss   | -1.58     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35839     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 165       |
# |    fps             | 13        |
# |    time_elapsed    | 1218      |
# |    total_timesteps | 16335     |
# | train/             |           |
# |    actor_loss      | -5.83e+09 |
# |    critic_loss     | 5.9e+07   |
# |    ent_coef        | 1.87e+06  |
# |    ent_coef_loss   | 0.939     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36334     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 170       |
# |    fps             | 13        |
# |    time_elapsed    | 1256      |
# |    total_timesteps | 16830     |
# | train/             |           |
# |    actor_loss      | -6.16e+09 |
# |    critic_loss     | 6.41e+07  |
# |    ent_coef        | 1.99e+06  |
# |    ent_coef_loss   | 2.6       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36829     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 175       |
# |    fps             | 13        |
# |    time_elapsed    | 1293      |
# |    total_timesteps | 17325     |
# | train/             |           |
# |    actor_loss      | -6.62e+09 |
# |    critic_loss     | 6.96e+07  |
# |    ent_coef        | 2.11e+06  |
# |    ent_coef_loss   | 0.567     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37324     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 180       |
# |    fps             | 13        |
# |    time_elapsed    | 1330      |
# |    total_timesteps | 17820     |
# | train/             |           |
# |    actor_loss      | -6.99e+09 |
# |    critic_loss     | 7.42e+07  |
# |    ent_coef        | 2.24e+06  |
# |    ent_coef_loss   | 1.69      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37819     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 185       |
# |    fps             | 13        |
# |    time_elapsed    | 1367      |
# |    total_timesteps | 18315     |
# | train/             |           |
# |    actor_loss      | -7.45e+09 |
# |    critic_loss     | 7.22e+07  |
# |    ent_coef        | 2.37e+06  |
# |    ent_coef_loss   | -1.42     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38314     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 190       |
# |    fps             | 13        |
# |    time_elapsed    | 1406      |
# |    total_timesteps | 18810     |
# | train/             |           |
# |    actor_loss      | -7.97e+09 |
# |    critic_loss     | 7.78e+07  |
# |    ent_coef        | 2.52e+06  |
# |    ent_coef_loss   | -0.167    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38809     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 195       |
# |    fps             | 13        |
# |    time_elapsed    | 1443      |
# |    total_timesteps | 19305     |
# | train/             |           |
# |    actor_loss      | -8.46e+09 |
# |    critic_loss     | 8.61e+07  |
# |    ent_coef        | 2.7e+06   |
# |    ent_coef_loss   | -0.684    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39304     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 13        |
# |    time_elapsed    | 1480      |
# |    total_timesteps | 19800     |
# | train/             |           |
# |    actor_loss      | -8.87e+09 |
# |    critic_loss     | 8.66e+07  |
# |    ent_coef        | 2.88e+06  |
# |    ent_coef_loss   | 2.48      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39799     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 205       |
# |    fps             | 13        |
# |    time_elapsed    | 1516      |
# |    total_timesteps | 20295     |
# | train/             |           |
# |    actor_loss      | -9.38e+09 |
# |    critic_loss     | 9.71e+07  |
# |    ent_coef        | 3.02e+06  |
# |    ent_coef_loss   | 2.61      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40294     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 210       |
# |    fps             | 13        |
# |    time_elapsed    | 1553      |
# |    total_timesteps | 20790     |
# | train/             |           |
# |    actor_loss      | -9.89e+09 |
# |    critic_loss     | 9.8e+07   |
# |    ent_coef        | 3.18e+06  |
# |    ent_coef_loss   | 2.79      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40789     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 215       |
# |    fps             | 13        |
# |    time_elapsed    | 1590      |
# |    total_timesteps | 21285     |
# | train/             |           |
# |    actor_loss      | -1.04e+10 |
# |    critic_loss     | 1.1e+08   |
# |    ent_coef        | 3.4e+06   |
# |    ent_coef_loss   | 4.42      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41284     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 220      |
# |    fps             | 13       |
# |    time_elapsed    | 1629     |
# |    total_timesteps | 21780    |
# | train/             |          |
# |    actor_loss      | -1.1e+10 |
# |    critic_loss     | 1.09e+08 |
# |    ent_coef        | 3.56e+06 |
# |    ent_coef_loss   | -0.443   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41779    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 225       |
# |    fps             | 13        |
# |    time_elapsed    | 1667      |
# |    total_timesteps | 22275     |
# | train/             |           |
# |    actor_loss      | -1.16e+10 |
# |    critic_loss     | 1.19e+08  |
# |    ent_coef        | 3.75e+06  |
# |    ent_coef_loss   | 2.15      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42274     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 230       |
# |    fps             | 13        |
# |    time_elapsed    | 1705      |
# |    total_timesteps | 22770     |
# | train/             |           |
# |    actor_loss      | -1.23e+10 |
# |    critic_loss     | 1.31e+08  |
# |    ent_coef        | 3.92e+06  |
# |    ent_coef_loss   | -1.74     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42769     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 235      |
# |    fps             | 13       |
# |    time_elapsed    | 1740     |
# |    total_timesteps | 23265    |
# | train/             |          |
# |    actor_loss      | -1.3e+10 |
# |    critic_loss     | 1.42e+08 |
# |    ent_coef        | 4.11e+06 |
# |    ent_coef_loss   | -1.12    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 43264    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 13        |
# |    time_elapsed    | 1778      |
# |    total_timesteps | 23760     |
# | train/             |           |
# |    actor_loss      | -1.37e+10 |
# |    critic_loss     | 1.42e+08  |
# |    ent_coef        | 4.29e+06  |
# |    ent_coef_loss   | 1.39      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43759     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 245       |
# |    fps             | 13        |
# |    time_elapsed    | 1816      |
# |    total_timesteps | 24255     |
# | train/             |           |
# |    actor_loss      | -1.41e+10 |
# |    critic_loss     | 1.52e+08  |
# |    ent_coef        | 4.47e+06  |
# |    ent_coef_loss   | -1.04     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44254     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 250       |
# |    fps             | 13        |
# |    time_elapsed    | 1853      |
# |    total_timesteps | 24750     |
# | train/             |           |
# |    actor_loss      | -1.49e+10 |
# |    critic_loss     | 1.47e+08  |
# |    ent_coef        | 4.62e+06  |
# |    ent_coef_loss   | 3.57      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44749     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 255       |
# |    fps             | 13        |
# |    time_elapsed    | 1890      |
# |    total_timesteps | 25245     |
# | train/             |           |
# |    actor_loss      | -1.55e+10 |
# |    critic_loss     | 1.67e+08  |
# |    ent_coef        | 4.73e+06  |
# |    ent_coef_loss   | 5.64      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45244     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 260       |
# |    fps             | 13        |
# |    time_elapsed    | 1927      |
# |    total_timesteps | 25740     |
# | train/             |           |
# |    actor_loss      | -1.61e+10 |
# |    critic_loss     | 1.75e+08  |
# |    ent_coef        | 4.92e+06  |
# |    ent_coef_loss   | 1.88      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45739     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 265      |
# |    fps             | 13       |
# |    time_elapsed    | 1966     |
# |    total_timesteps | 26235    |
# | train/             |          |
# |    actor_loss      | -1.7e+10 |
# |    critic_loss     | 1.87e+08 |
# |    ent_coef        | 5.13e+06 |
# |    ent_coef_loss   | -0.589   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46234    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 270      |
# |    fps             | 13       |
# |    time_elapsed    | 2004     |
# |    total_timesteps | 26730    |
# | train/             |          |
# |    actor_loss      | -1.8e+10 |
# |    critic_loss     | 1.92e+08 |
# |    ent_coef        | 5.4e+06  |
# |    ent_coef_loss   | -5.62    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 46729    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 275       |
# |    fps             | 13        |
# |    time_elapsed    | 2043      |
# |    total_timesteps | 27225     |
# | train/             |           |
# |    actor_loss      | -1.87e+10 |
# |    critic_loss     | 2.05e+08  |
# |    ent_coef        | 5.64e+06  |
# |    ent_coef_loss   | 0.793     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47224     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 13        |
# |    time_elapsed    | 2080      |
# |    total_timesteps | 27720     |
# | train/             |           |
# |    actor_loss      | -1.94e+10 |
# |    critic_loss     | 2.15e+08  |
# |    ent_coef        | 5.8e+06   |
# |    ent_coef_loss   | 0.118     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47719     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 285      |
# |    fps             | 13       |
# |    time_elapsed    | 2118     |
# |    total_timesteps | 28215    |
# | train/             |          |
# |    actor_loss      | -2e+10   |
# |    critic_loss     | 2.24e+08 |
# |    ent_coef        | 6.09e+06 |
# |    ent_coef_loss   | -0.436   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 48214    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 290       |
# |    fps             | 13        |
# |    time_elapsed    | 2153      |
# |    total_timesteps | 28710     |
# | train/             |           |
# |    actor_loss      | -2.15e+10 |
# |    critic_loss     | 2.36e+08  |
# |    ent_coef        | 6.37e+06  |
# |    ent_coef_loss   | -5        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48709     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 295       |
# |    fps             | 13        |
# |    time_elapsed    | 2191      |
# |    total_timesteps | 29205     |
# | train/             |           |
# |    actor_loss      | -2.24e+10 |
# |    critic_loss     | 2.39e+08  |
# |    ent_coef        | 6.65e+06  |
# |    ent_coef_loss   | -3.73     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49204     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 13        |
# |    time_elapsed    | 2227      |
# |    total_timesteps | 29700     |
# | train/             |           |
# |    actor_loss      | -2.33e+10 |
# |    critic_loss     | 2.46e+08  |
# |    ent_coef        | 6.92e+06  |
# |    ent_coef_loss   | 0.246     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49699     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 305       |
# |    fps             | 13        |
# |    time_elapsed    | 2263      |
# |    total_timesteps | 30195     |
# | train/             |           |
# |    actor_loss      | -2.42e+10 |
# |    critic_loss     | 2.63e+08  |
# |    ent_coef        | 7.29e+06  |
# |    ent_coef_loss   | 3.64      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50194     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 310       |
# |    fps             | 13        |
# |    time_elapsed    | 2300      |
# |    total_timesteps | 30690     |
# | train/             |           |
# |    actor_loss      | -2.52e+10 |
# |    critic_loss     | 2.7e+08   |
# |    ent_coef        | 7.54e+06  |
# |    ent_coef_loss   | -1.38     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50689     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 315       |
# |    fps             | 13        |
# |    time_elapsed    | 2337      |
# |    total_timesteps | 31185     |
# | train/             |           |
# |    actor_loss      | -2.63e+10 |
# |    critic_loss     | 2.9e+08   |
# |    ent_coef        | 7.85e+06  |
# |    ent_coef_loss   | 1.1       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 51184     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 320       |
# |    fps             | 13        |
# |    time_elapsed    | 2374      |
# |    total_timesteps | 31680     |
# | train/             |           |
# |    actor_loss      | -2.82e+10 |
# |    critic_loss     | 3.18e+08  |
# |    ent_coef        | 8.21e+06  |
# |    ent_coef_loss   | -8.09     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 51679     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 325       |
# |    fps             | 13        |
# |    time_elapsed    | 2412      |
# |    total_timesteps | 32175     |
# | train/             |           |
# |    actor_loss      | -2.85e+10 |
# |    critic_loss     | 3.28e+08  |
# |    ent_coef        | 8.44e+06  |
# |    ent_coef_loss   | -0.855    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52174     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 330       |
# |    fps             | 13        |
# |    time_elapsed    | 2450      |
# |    total_timesteps | 32670     |
# | train/             |           |
# |    actor_loss      | -2.95e+10 |
# |    critic_loss     | 3.33e+08  |
# |    ent_coef        | 8.74e+06  |
# |    ent_coef_loss   | -0.406    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52669     |
# ...
# |    fps             | 11        |
# |    time_elapsed    | 8300      |
# |    total_timesteps | 578678    |
# | train/             |           |
# |    actor_loss      | -1.27e+15 |
# |    critic_loss     | 2.27e+13  |
# |    ent_coef        | 2.58e+11  |
# |    ent_coef_loss   | 13.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 598677    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5850      |
# |    fps             | 11        |
# |    time_elapsed    | 8337      |
# |    total_timesteps | 579173    |
# | train/             |           |
# |    actor_loss      | -1.28e+15 |
# |    critic_loss     | 2.39e+13  |
# |    ent_coef        | 2.61e+11  |
# |    ent_coef_loss   | 5.14      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 599172    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5855      |
# |    fps             | 11        |
# |    time_elapsed    | 8375      |
# |    total_timesteps | 579668    |
# | train/             |           |
# |    actor_loss      | -1.28e+15 |
# |    critic_loss     | 2.35e+13  |
# |    ent_coef        | 2.57e+11  |
# |    ent_coef_loss   | 10.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 599667    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5860      |
# |    fps             | 11        |
# |    time_elapsed    | 8414      |
# |    total_timesteps | 580163    |
# | train/             |           |
# |    actor_loss      | -1.31e+15 |
# |    critic_loss     | 2.47e+13  |
# |    ent_coef        | 2.59e+11  |
# |    ent_coef_loss   | 0.186     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 600162    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5865      |
# |    fps             | 11        |
# |    time_elapsed    | 8454      |
# |    total_timesteps | 580658    |
# | train/             |           |
# |    actor_loss      | -1.29e+15 |
# |    critic_loss     | 2.24e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 3.06      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 600657    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5870      |
# |    fps             | 11        |
# |    time_elapsed    | 8491      |
# |    total_timesteps | 581153    |
# | train/             |           |
# |    actor_loss      | -1.27e+15 |
# |    critic_loss     | 2.27e+13  |
# |    ent_coef        | 2.57e+11  |
# |    ent_coef_loss   | 6.37      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 601152    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5875      |
# |    fps             | 11        |
# |    time_elapsed    | 8527      |
# |    total_timesteps | 581648    |
# | train/             |           |
# |    actor_loss      | -1.31e+15 |
# |    critic_loss     | 2.33e+13  |
# |    ent_coef        | 2.56e+11  |
# |    ent_coef_loss   | 0.309     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 601647    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5880     |
# |    fps             | 11       |
# |    time_elapsed    | 8564     |
# |    total_timesteps | 582143   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.24e+13 |
# |    ent_coef        | 2.57e+11 |
# |    ent_coef_loss   | 2.6      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 602142   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5885      |
# |    fps             | 11        |
# |    time_elapsed    | 8602      |
# |    total_timesteps | 582638    |
# | train/             |           |
# |    actor_loss      | -1.29e+15 |
# |    critic_loss     | 2.21e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 10.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 602637    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5890     |
# |    fps             | 11       |
# |    time_elapsed    | 8640     |
# |    total_timesteps | 583133   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.29e+13 |
# |    ent_coef        | 2.6e+11  |
# |    ent_coef_loss   | 2.35     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 603132   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 5895     |
# |    fps             | 11       |
# |    time_elapsed    | 8676     |
# |    total_timesteps | 583628   |
# | train/             |          |
# |    actor_loss      | -1.3e+15 |
# |    critic_loss     | 2.55e+13 |
# |    ent_coef        | 2.57e+11 |
# |    ent_coef_loss   | -4.06    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 603627   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5900      |
# |    fps             | 11        |
# |    time_elapsed    | 8715      |
# |    total_timesteps | 584123    |
# | train/             |           |
# |    actor_loss      | -1.34e+15 |
# |    critic_loss     | 2.58e+13  |
# |    ent_coef        | 2.58e+11  |
# |    ent_coef_loss   | -3.5      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 604122    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5905      |
# |    fps             | 11        |
# |    time_elapsed    | 8752      |
# |    total_timesteps | 584618    |
# | train/             |           |
# |    actor_loss      | -1.32e+15 |
# |    critic_loss     | 2.37e+13  |
# |    ent_coef        | 2.6e+11   |
# |    ent_coef_loss   | 5.59      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 604617    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5910      |
# |    fps             | 11        |
# |    time_elapsed    | 8789      |
# |    total_timesteps | 585113    |
# | train/             |           |
# |    actor_loss      | -1.35e+15 |
# |    critic_loss     | 2.51e+13  |
# |    ent_coef        | 2.61e+11  |
# |    ent_coef_loss   | -2.94     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 605112    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5915      |
# |    fps             | 11        |
# |    time_elapsed    | 8826      |
# |    total_timesteps | 585608    |
# | train/             |           |
# |    actor_loss      | -1.37e+15 |
# |    critic_loss     | 2.42e+13  |
# |    ent_coef        | 2.62e+11  |
# |    ent_coef_loss   | -2.26     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 605607    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5920      |
# |    fps             | 11        |
# |    time_elapsed    | 8865      |
# |    total_timesteps | 586103    |
# | train/             |           |
# |    actor_loss      | -1.37e+15 |
# |    critic_loss     | 2.67e+13  |
# |    ent_coef        | 2.62e+11  |
# |    ent_coef_loss   | -1.84     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 606102    |
# ----------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 63
#      60 collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
#      61 model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
# ---> 63 model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
#      64 model.save(f"data/seed_{seed}/tqc_pick_place")
#      65 model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")
#
# File ~/cog/cogv/lib/python3.8/site-packages/sb3_contrib/tqc/tqc.py:302, in TQC.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     293 def learn(
#     294     self: SelfTQC,
#     295     total_timesteps: int,
#    (...)
#     300     progress_bar: bool = False,
#     301 ) -> SelfTQC:
# --> 302     return super().learn(
#     303         total_timesteps=total_timesteps,
#     304         callback=callback,
#     305         log_interval=log_interval,
#     306         tb_log_name=tb_log_name,
#     307         reset_num_timesteps=reset_num_timesteps,
#     308         progress_bar=progress_bar,
#     309     )
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:328, in OffPolicyAlgorithm.learn(self, total_timesteps, callback, log_interval, tb_log_name, reset_num_timesteps, progress_bar)
#     325 assert isinstance(self.train_freq, TrainFreq)  # check done in _setup_learn()
#     327 while self.num_timesteps < total_timesteps:
# --> 328     rollout = self.collect_rollouts(
#     329         self.env,
#     330         train_freq=self.train_freq,
#     331         action_noise=self.action_noise,
#     332         callback=callback,
#     333         learning_starts=self.learning_starts,
#     334         replay_buffer=self.replay_buffer,
#     335         log_interval=log_interval,
#     336     )
#     338     if not rollout.continue_training:
#     339         break
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/off_policy_algorithm.py:560, in OffPolicyAlgorithm.collect_rollouts(self, env, callback, train_freq, replay_buffer, action_noise, learning_starts, log_interval)
#     557 actions, buffer_actions = self._sample_action(learning_starts, action_noise, env.num_envs)
#     559 # Rescale and perform action
# --> 560 new_obs, rewards, dones, infos = env.step(actions)
#     562 self.num_timesteps += env.num_envs
#     563 num_collected_steps += 1
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/base_vec_env.py:206, in VecEnv.step(self, actions)
#     199 """
#     200 Step the environments with the given action
#     201
#     202 :param actions: the action
#     203 :return: observation, reward, done, information
#     204 """
#     205 self.step_async(actions)
# --> 206 return self.step_wait()
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/vec_transpose.py:97, in VecTransposeImage.step_wait(self)
#      96 def step_wait(self) -> VecEnvStepReturn:
# ---> 97     observations, rewards, dones, infos = self.venv.step_wait()
#      99     # Transpose the terminal observations
#     100     for idx, done in enumerate(dones):
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/dummy_vec_env.py:58, in DummyVecEnv.step_wait(self)
#      55 def step_wait(self) -> VecEnvStepReturn:
#      56     # Avoid circular imports
#      57     for env_idx in range(self.num_envs):
# ---> 58         obs, self.buf_rews[env_idx], terminated, truncated, self.buf_infos[env_idx] = self.envs[env_idx].step(
#      59             self.actions[env_idx]
#      60         )
#      61         # convert to SB3 VecEnv api
#      62         self.buf_dones[env_idx] = terminated or truncated
#
# File ~/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/monitor.py:94, in Monitor.step(self, action)
#      92 if self.needs_reset:
#      93     raise RuntimeError("Tried to step environment that needs reset")
# ---> 94 observation, reward, terminated, truncated, info = self.env.step(action)
#      95 self.rewards.append(float(reward))
#      96 if terminated or truncated:
#
# File ~/cog/cogv/lib/python3.8/site-packages/shimmy/openai_gym_compatibility.py:251, in GymV21CompatibilityV0.step(self, action)
#     242 def step(self, action: ActType) -> tuple[Any, float, bool, bool, dict]:
#     243     """Steps through the environment.
#     244
#     245     Args:
#    (...)
#     249         (observation, reward, terminated, truncated, info)
#     250     """
# --> 251     obs, reward, done, info = self.gym_env.step(action)
#     253     if self.render_mode is not None:
#     254         self.render()
#
# File ~/cog/cogv/lib/python3.8/site-packages/gym/wrappers/order_enforcing.py:37, in OrderEnforcing.step(self, action)
#      35 if not self._has_reset:
#      36     raise ResetNeeded("Cannot call env.step() before calling env.reset()")
# ---> 37 return self.env.step(action)
#
# File ~/cog/cogv/lib/python3.8/site-packages/gym/wrappers/env_checker.py:39, in PassiveEnvChecker.step(self, action)
#      37     return env_step_passive_checker(self.env, action)
#      38 else:
# ---> 39     return self.env.step(action)
#
# File ~/Sim2Real/roboverse/envs/widow250.py:272, in Widow250Env.step(self, action)
#     267 target_ee_pos = np.clip(target_ee_pos, self.ee_pos_low,
#     268                         self.ee_pos_high)
#     269 target_gripper_state = np.clip(target_gripper_state, GRIPPER_LIMITS_LOW,
#     270                                GRIPPER_LIMITS_HIGH)
# --> 272 bullet.apply_action_ik(
#     273     target_ee_pos, target_ee_quat, target_gripper_state,
#     274     self.robot_id,
#     275     self.end_effector_index, self.movable_joints,
#     276     lower_limit=JOINT_LIMIT_LOWER,
#     277     upper_limit=JOINT_LIMIT_UPPER,
#     278     rest_pose=RESET_JOINT_VALUES,
#     279     joint_range=JOINT_RANGE,
#     280     num_sim_steps=num_sim_steps)
#     282 if self.use_neutral_action and neutral_action > 0.5:
#     283     if self.neutral_gripper_open:
#
# File ~/Sim2Real/roboverse/bullet/control.py:83, in apply_action_ik(target_ee_pos, target_ee_quat, target_gripper_state, robot_id, end_effector_index, movable_joints, lower_limit, upper_limit, rest_pose, joint_range, num_sim_steps)
#      75 p.setJointMotorControl2(robot_id,
#      76                         movable_joints[-1],
#      77                         controlMode=p.POSITION_CONTROL,
#      78                         targetPosition=target_gripper_state[1],
#      79                         force=500,
#      80                         positionGain=0.03)
#      82 for _ in range(num_sim_steps):
# ---> 83     p.stepSimulation()
#
# KeyboardInterrupt:

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlaceMultiObject-v0",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 3
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
             policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
             replay_buffer_class=HerReplayBuffer,
             replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
             tau=0.05, learning_starts=200, verbose=1)

#model = TQC.load("data/tqc")
#model.set_env(env)
COLLECT=False
if COLLECT:
    collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
    model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
else:
    print("load_replay_buffer")
    model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start pre-training from buffer only")
model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.train(gradient_steps=20000)

print("start learning")
model.learn(total_timesteps=480_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")

print("finish learning")
# Out:
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# load_replay_buffer
# start pre-training from buffer only
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:219:
# DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is
# recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:225:
# DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:165: UserWarning:
# WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# start learning
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 5         |
# |    fps             | 20        |
# |    time_elapsed    | 23        |
# |    total_timesteps | 495       |
# | train/             |           |
# |    actor_loss      | -1.31e+08 |
# |    critic_loss     | 8.91e+05  |
# |    ent_coef        | 4.72e+04  |
# |    ent_coef_loss   | 0.726     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20294     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 10        |
# |    fps             | 17        |
# |    time_elapsed    | 55        |
# |    total_timesteps | 990       |
# | train/             |           |
# |    actor_loss      | -1.29e+08 |
# |    critic_loss     | 7.39e+05  |
# |    ent_coef        | 3.41e+04  |
# |    ent_coef_loss   | 1.22      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20789     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 15        |
# |    fps             | 17        |
# |    time_elapsed    | 86        |
# |    total_timesteps | 1485      |
# | train/             |           |
# |    actor_loss      | -1.25e+08 |
# |    critic_loss     | 7.54e+05  |
# |    ent_coef        | 3.57e+04  |
# |    ent_coef_loss   | 0.443     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21284     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 20        |
# |    fps             | 16        |
# |    time_elapsed    | 118       |
# |    total_timesteps | 1980      |
# | train/             |           |
# |    actor_loss      | -1.28e+08 |
# |    critic_loss     | 8.6e+05   |
# |    ent_coef        | 3.01e+04  |
# |    ent_coef_loss   | -0.465    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 21779     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 25        |
# |    fps             | 16        |
# |    time_elapsed    | 149       |
# |    total_timesteps | 2475      |
# | train/             |           |
# |    actor_loss      | -1.37e+08 |
# |    critic_loss     | 8.56e+05  |
# |    ent_coef        | 3.69e+04  |
# |    ent_coef_loss   | -0.738    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22274     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 30        |
# |    fps             | 16        |
# |    time_elapsed    | 181       |
# |    total_timesteps | 2970      |
# | train/             |           |
# |    actor_loss      | -1.45e+08 |
# |    critic_loss     | 9.47e+05  |
# |    ent_coef        | 4.34e+04  |
# |    ent_coef_loss   | -0.214    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 22769     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 35        |
# |    fps             | 16        |
# |    time_elapsed    | 215       |
# |    total_timesteps | 3465      |
# | train/             |           |
# |    actor_loss      | -1.52e+08 |
# |    critic_loss     | 1.04e+06  |
# |    ent_coef        | 4.46e+04  |
# |    ent_coef_loss   | 0.395     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23264     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 40        |
# |    fps             | 15        |
# |    time_elapsed    | 247       |
# |    total_timesteps | 3960      |
# | train/             |           |
# |    actor_loss      | -1.52e+08 |
# |    critic_loss     | 1.26e+06  |
# |    ent_coef        | 3.86e+04  |
# |    ent_coef_loss   | -0.768    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 23759     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 45        |
# |    fps             | 15        |
# |    time_elapsed    | 280       |
# |    total_timesteps | 4455      |
# | train/             |           |
# |    actor_loss      | -1.55e+08 |
# |    critic_loss     | 1.45e+06  |
# |    ent_coef        | 3.71e+04  |
# |    ent_coef_loss   | -0.874    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24254     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 50        |
# |    fps             | 15        |
# |    time_elapsed    | 311       |
# |    total_timesteps | 4950      |
# | train/             |           |
# |    actor_loss      | -1.61e+08 |
# |    critic_loss     | 1.52e+06  |
# |    ent_coef        | 3.78e+04  |
# |    ent_coef_loss   | -2.85     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 24749     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 55        |
# |    fps             | 15        |
# |    time_elapsed    | 343       |
# |    total_timesteps | 5445      |
# | train/             |           |
# |    actor_loss      | -1.73e+08 |
# |    critic_loss     | 1.35e+06  |
# |    ent_coef        | 3.94e+04  |
# |    ent_coef_loss   | -1.19     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25244     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 60        |
# |    fps             | 15        |
# |    time_elapsed    | 373       |
# |    total_timesteps | 5940      |
# | train/             |           |
# |    actor_loss      | -1.81e+08 |
# |    critic_loss     | 1.36e+06  |
# |    ent_coef        | 3.86e+04  |
# |    ent_coef_loss   | -1.02     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 25739     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 65       |
# |    fps             | 15       |
# |    time_elapsed    | 405      |
# |    total_timesteps | 6435     |
# | train/             |          |
# |    actor_loss      | -1.9e+08 |
# |    critic_loss     | 1.39e+06 |
# |    ent_coef        | 3.83e+04 |
# |    ent_coef_loss   | 1.3      |
# |    learning_rate   | 0.001    |
# |    n_updates       | 26234    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 70        |
# |    fps             | 15        |
# |    time_elapsed    | 437       |
# |    total_timesteps | 6930      |
# | train/             |           |
# |    actor_loss      | -1.97e+08 |
# |    critic_loss     | 1.31e+06  |
# |    ent_coef        | 4.35e+04  |
# |    ent_coef_loss   | 0.416     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 26729     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 75        |
# |    fps             | 15        |
# |    time_elapsed    | 469       |
# |    total_timesteps | 7425      |
# | train/             |           |
# |    actor_loss      | -1.99e+08 |
# |    critic_loss     | 1.23e+06  |
# |    ent_coef        | 4.33e+04  |
# |    ent_coef_loss   | -0.567    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27224     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 80        |
# |    fps             | 15        |
# |    time_elapsed    | 500       |
# |    total_timesteps | 7920      |
# | train/             |           |
# |    actor_loss      | -2.01e+08 |
# |    critic_loss     | 1.23e+06  |
# |    ent_coef        | 4.6e+04   |
# |    ent_coef_loss   | 0.19      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 27719     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 85        |
# |    fps             | 15        |
# |    time_elapsed    | 529       |
# |    total_timesteps | 8415      |
# | train/             |           |
# |    actor_loss      | -1.97e+08 |
# |    critic_loss     | 1.11e+06  |
# |    ent_coef        | 4.41e+04  |
# |    ent_coef_loss   | 0.241     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28214     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 90        |
# |    fps             | 15        |
# |    time_elapsed    | 560       |
# |    total_timesteps | 8910      |
# | train/             |           |
# |    actor_loss      | -1.94e+08 |
# |    critic_loss     | 1.16e+06  |
# |    ent_coef        | 4.51e+04  |
# |    ent_coef_loss   | 0.616     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 28709     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 95       |
# |    fps             | 15       |
# |    time_elapsed    | 592      |
# |    total_timesteps | 9405     |
# | train/             |          |
# |    actor_loss      | -1.9e+08 |
# |    critic_loss     | 1.05e+06 |
# |    ent_coef        | 4.43e+04 |
# |    ent_coef_loss   | 0.148    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29204    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 100       |
# |    fps             | 15        |
# |    time_elapsed    | 624       |
# |    total_timesteps | 9900      |
# | train/             |           |
# |    actor_loss      | -1.82e+08 |
# |    critic_loss     | 1e+06     |
# |    ent_coef        | 4.22e+04  |
# |    ent_coef_loss   | 0.712     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 29699     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 105       |
# |    fps             | 15        |
# |    time_elapsed    | 655       |
# |    total_timesteps | 10395     |
# | train/             |           |
# |    actor_loss      | -1.74e+08 |
# |    critic_loss     | 9.19e+05  |
# |    ent_coef        | 4.13e+04  |
# |    ent_coef_loss   | 2.49      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30194     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 110       |
# |    fps             | 15        |
# |    time_elapsed    | 686       |
# |    total_timesteps | 10890     |
# | train/             |           |
# |    actor_loss      | -1.65e+08 |
# |    critic_loss     | 8.82e+05  |
# |    ent_coef        | 4.05e+04  |
# |    ent_coef_loss   | 1.48      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 30689     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 115       |
# |    fps             | 15        |
# |    time_elapsed    | 718       |
# |    total_timesteps | 11385     |
# | train/             |           |
# |    actor_loss      | -1.54e+08 |
# |    critic_loss     | 9.19e+05  |
# |    ent_coef        | 3.71e+04  |
# |    ent_coef_loss   | -0.485    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31184     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 120       |
# |    fps             | 15        |
# |    time_elapsed    | 749       |
# |    total_timesteps | 11880     |
# | train/             |           |
# |    actor_loss      | -1.43e+08 |
# |    critic_loss     | 8.06e+05  |
# |    ent_coef        | 3.4e+04   |
# |    ent_coef_loss   | 0.642     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31679     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 125       |
# |    fps             | 15        |
# |    time_elapsed    | 781       |
# |    total_timesteps | 12375     |
# | train/             |           |
# |    actor_loss      | -1.33e+08 |
# |    critic_loss     | 6.82e+05  |
# |    ent_coef        | 3.11e+04  |
# |    ent_coef_loss   | -0.639    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32174     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 130       |
# |    fps             | 15        |
# |    time_elapsed    | 812       |
# |    total_timesteps | 12870     |
# | train/             |           |
# |    actor_loss      | -1.19e+08 |
# |    critic_loss     | 5.8e+05   |
# |    ent_coef        | 2.92e+04  |
# |    ent_coef_loss   | -0.74     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 32669     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 135       |
# |    fps             | 15        |
# |    time_elapsed    | 846       |
# |    total_timesteps | 13365     |
# | train/             |           |
# |    actor_loss      | -1.08e+08 |
# |    critic_loss     | 5.44e+05  |
# |    ent_coef        | 2.68e+04  |
# |    ent_coef_loss   | -0.973    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33164     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 140       |
# |    fps             | 15        |
# |    time_elapsed    | 877       |
# |    total_timesteps | 13860     |
# | train/             |           |
# |    actor_loss      | -9.85e+07 |
# |    critic_loss     | 4.74e+05  |
# |    ent_coef        | 2.48e+04  |
# |    ent_coef_loss   | 1.93      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 33659     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 145       |
# |    fps             | 15        |
# |    time_elapsed    | 909       |
# |    total_timesteps | 14355     |
# | train/             |           |
# |    actor_loss      | -8.91e+07 |
# |    critic_loss     | 4.64e+05  |
# |    ent_coef        | 2.3e+04   |
# |    ent_coef_loss   | 0.919     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34154     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 150       |
# |    fps             | 15        |
# |    time_elapsed    | 941       |
# |    total_timesteps | 14850     |
# | train/             |           |
# |    actor_loss      | -7.88e+07 |
# |    critic_loss     | 3.66e+05  |
# |    ent_coef        | 2.03e+04  |
# |    ent_coef_loss   | 0.919     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 34649     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 155       |
# |    fps             | 15        |
# |    time_elapsed    | 972       |
# |    total_timesteps | 15345     |
# | train/             |           |
# |    actor_loss      | -6.72e+07 |
# |    critic_loss     | 3.94e+05  |
# |    ent_coef        | 1.82e+04  |
# |    ent_coef_loss   | 1.92      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35144     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 160       |
# |    fps             | 15        |
# |    time_elapsed    | 1003      |
# |    total_timesteps | 15840     |
# | train/             |           |
# |    actor_loss      | -5.48e+07 |
# |    critic_loss     | 3.33e+05  |
# |    ent_coef        | 1.53e+04  |
# |    ent_coef_loss   | 1.22      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 35639     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 165       |
# |    fps             | 15        |
# |    time_elapsed    | 1036      |
# |    total_timesteps | 16335     |
# | train/             |           |
# |    actor_loss      | -4.35e+07 |
# |    critic_loss     | 2.66e+05  |
# |    ent_coef        | 1.27e+04  |
# |    ent_coef_loss   | 0.203     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36134     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 170       |
# |    fps             | 15        |
# |    time_elapsed    | 1067      |
# |    total_timesteps | 16830     |
# | train/             |           |
# |    actor_loss      | -3.11e+07 |
# |    critic_loss     | 1.97e+05  |
# |    ent_coef        | 1e+04     |
# |    ent_coef_loss   | 1.96      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 36629     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 175       |
# |    fps             | 15        |
# |    time_elapsed    | 1098      |
# |    total_timesteps | 17325     |
# | train/             |           |
# |    actor_loss      | -2.07e+07 |
# |    critic_loss     | 1.89e+05  |
# |    ent_coef        | 7.6e+03   |
# |    ent_coef_loss   | 0.073     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 37124     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 180      |
# |    fps             | 15       |
# |    time_elapsed    | 1131     |
# |    total_timesteps | 17820    |
# | train/             |          |
# |    actor_loss      | -1.6e+07 |
# |    critic_loss     | 2e+05    |
# |    ent_coef        | 7.32e+03 |
# |    ent_coef_loss   | -0.0631  |
# |    learning_rate   | 0.001    |
# |    n_updates       | 37619    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 185       |
# |    fps             | 15        |
# |    time_elapsed    | 1162      |
# |    total_timesteps | 18315     |
# | train/             |           |
# |    actor_loss      | -1.72e+07 |
# |    critic_loss     | 2.62e+05  |
# |    ent_coef        | 8.1e+03   |
# |    ent_coef_loss   | -2.43     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38114     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 190       |
# |    fps             | 15        |
# |    time_elapsed    | 1194      |
# |    total_timesteps | 18810     |
# | train/             |           |
# |    actor_loss      | -2.56e+07 |
# |    critic_loss     | 3.72e+05  |
# |    ent_coef        | 1.01e+04  |
# |    ent_coef_loss   | -2.98     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 38609     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 195       |
# |    fps             | 15        |
# |    time_elapsed    | 1226      |
# |    total_timesteps | 19305     |
# | train/             |           |
# |    actor_loss      | -4.02e+07 |
# |    critic_loss     | 5.57e+05  |
# |    ent_coef        | 1.41e+04  |
# |    ent_coef_loss   | 0.00304   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39104     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 200       |
# |    fps             | 15        |
# |    time_elapsed    | 1258      |
# |    total_timesteps | 19800     |
# | train/             |           |
# |    actor_loss      | -7.18e+07 |
# |    critic_loss     | 1.05e+06  |
# |    ent_coef        | 2.63e+04  |
# |    ent_coef_loss   | -3        |
# |    learning_rate   | 0.001     |
# |    n_updates       | 39599     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 205       |
# |    fps             | 15        |
# |    time_elapsed    | 1292      |
# |    total_timesteps | 20295     |
# | train/             |           |
# |    actor_loss      | -1.36e+08 |
# |    critic_loss     | 2.16e+06  |
# |    ent_coef        | 4.75e+04  |
# |    ent_coef_loss   | -5.62     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 40094     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 210      |
# |    fps             | 15       |
# |    time_elapsed    | 1326     |
# |    total_timesteps | 20790    |
# | train/             |          |
# |    actor_loss      | -2.3e+08 |
# |    critic_loss     | 3.64e+06 |
# |    ent_coef        | 8.64e+04 |
# |    ent_coef_loss   | -3.8     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 40589    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 215       |
# |    fps             | 15        |
# |    time_elapsed    | 1363      |
# |    total_timesteps | 21285     |
# | train/             |           |
# |    actor_loss      | -3.75e+08 |
# |    critic_loss     | 5.5e+06   |
# |    ent_coef        | 1.42e+05  |
# |    ent_coef_loss   | 0.751     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41084     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 220       |
# |    fps             | 15        |
# |    time_elapsed    | 1400      |
# |    total_timesteps | 21780     |
# | train/             |           |
# |    actor_loss      | -5.14e+08 |
# |    critic_loss     | 6.38e+06  |
# |    ent_coef        | 1.73e+05  |
# |    ent_coef_loss   | -1.55     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 41579     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 225       |
# |    fps             | 15        |
# |    time_elapsed    | 1440      |
# |    total_timesteps | 22275     |
# | train/             |           |
# |    actor_loss      | -6.24e+08 |
# |    critic_loss     | 7.94e+06  |
# |    ent_coef        | 2.09e+05  |
# |    ent_coef_loss   | -3.53     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42074     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 230       |
# |    fps             | 15        |
# |    time_elapsed    | 1474      |
# |    total_timesteps | 22770     |
# | train/             |           |
# |    actor_loss      | -7.27e+08 |
# |    critic_loss     | 9.09e+06  |
# |    ent_coef        | 2.29e+05  |
# |    ent_coef_loss   | 0.853     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 42569     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 235       |
# |    fps             | 15        |
# |    time_elapsed    | 1516      |
# |    total_timesteps | 23265     |
# | train/             |           |
# |    actor_loss      | -8.49e+08 |
# |    critic_loss     | 1.06e+07  |
# |    ent_coef        | 2.6e+05   |
# |    ent_coef_loss   | -3.91     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43064     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 240       |
# |    fps             | 15        |
# |    time_elapsed    | 1552      |
# |    total_timesteps | 23760     |
# | train/             |           |
# |    actor_loss      | -9.73e+08 |
# |    critic_loss     | 1.11e+07  |
# |    ent_coef        | 2.98e+05  |
# |    ent_coef_loss   | -0.173    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43559     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 245      |
# |    fps             | 15       |
# |    time_elapsed    | 1587     |
# |    total_timesteps | 24255    |
# | train/             |          |
# |    actor_loss      | -1.1e+09 |
# |    critic_loss     | 1.28e+07 |
# |    ent_coef        | 3.25e+05 |
# |    ent_coef_loss   | -1.92    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 44054    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 250       |
# |    fps             | 15        |
# |    time_elapsed    | 1627      |
# |    total_timesteps | 24750     |
# | train/             |           |
# |    actor_loss      | -1.23e+09 |
# |    critic_loss     | 1.28e+07  |
# |    ent_coef        | 3.58e+05  |
# |    ent_coef_loss   | -1.11     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 44549     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 255       |
# |    fps             | 15        |
# |    time_elapsed    | 1663      |
# |    total_timesteps | 25245     |
# | train/             |           |
# |    actor_loss      | -1.38e+09 |
# |    critic_loss     | 1.49e+07  |
# |    ent_coef        | 3.94e+05  |
# |    ent_coef_loss   | -0.212    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 45044     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.6    |
# | time/              |          |
# |    episodes        | 260      |
# |    fps             | 15       |
# |    time_elapsed    | 1700     |
# |    total_timesteps | 25740    |
# | train/             |          |
# |    actor_loss      | -1.5e+09 |
# |    critic_loss     | 1.47e+07 |
# |    ent_coef        | 4.21e+05 |
# |    ent_coef_loss   | 2.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 45539    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 265       |
# |    fps             | 15        |
# |    time_elapsed    | 1736      |
# |    total_timesteps | 26235     |
# | train/             |           |
# |    actor_loss      | -1.63e+09 |
# |    critic_loss     | 1.77e+07  |
# |    ent_coef        | 4.66e+05  |
# |    ent_coef_loss   | 2.09      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46034     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 270       |
# |    fps             | 15        |
# |    time_elapsed    | 1769      |
# |    total_timesteps | 26730     |
# | train/             |           |
# |    actor_loss      | -1.79e+09 |
# |    critic_loss     | 1.82e+07  |
# |    ent_coef        | 5.05e+05  |
# |    ent_coef_loss   | -0.0262   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 46529     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 275       |
# |    fps             | 15        |
# |    time_elapsed    | 1812      |
# |    total_timesteps | 27225     |
# | train/             |           |
# |    actor_loss      | -1.95e+09 |
# |    critic_loss     | 1.77e+07  |
# |    ent_coef        | 5.5e+05   |
# |    ent_coef_loss   | -3.66     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47024     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 280       |
# |    fps             | 14        |
# |    time_elapsed    | 1851      |
# |    total_timesteps | 27720     |
# | train/             |           |
# |    actor_loss      | -2.09e+09 |
# |    critic_loss     | 2.13e+07  |
# |    ent_coef        | 5.86e+05  |
# |    ent_coef_loss   | 0.279     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 47519     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 285       |
# |    fps             | 14        |
# |    time_elapsed    | 1885      |
# |    total_timesteps | 28215     |
# | train/             |           |
# |    actor_loss      | -2.21e+09 |
# |    critic_loss     | 2.15e+07  |
# |    ent_coef        | 6.21e+05  |
# |    ent_coef_loss   | 4.91      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48014     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 290       |
# |    fps             | 14        |
# |    time_elapsed    | 1918      |
# |    total_timesteps | 28710     |
# | train/             |           |
# |    actor_loss      | -2.36e+09 |
# |    critic_loss     | 2.34e+07  |
# |    ent_coef        | 6.42e+05  |
# |    ent_coef_loss   | -1.44     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 48509     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 295       |
# |    fps             | 14        |
# |    time_elapsed    | 1954      |
# |    total_timesteps | 29205     |
# | train/             |           |
# |    actor_loss      | -2.47e+09 |
# |    critic_loss     | 2.04e+07  |
# |    ent_coef        | 6.78e+05  |
# |    ent_coef_loss   | 1.26      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49004     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 300       |
# |    fps             | 14        |
# |    time_elapsed    | 1990      |
# |    total_timesteps | 29700     |
# | train/             |           |
# |    actor_loss      | -2.63e+09 |
# |    critic_loss     | 2.63e+07  |
# |    ent_coef        | 7.05e+05  |
# |    ent_coef_loss   | 4.21      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49499     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 305       |
# |    fps             | 14        |
# |    time_elapsed    | 2031      |
# |    total_timesteps | 30195     |
# | train/             |           |
# |    actor_loss      | -2.68e+09 |
# |    critic_loss     | 2.52e+07  |
# |    ent_coef        | 7.07e+05  |
# |    ent_coef_loss   | 0.453     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 49994     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 310       |
# |    fps             | 14        |
# |    time_elapsed    | 2069      |
# |    total_timesteps | 30690     |
# | train/             |           |
# |    actor_loss      | -2.81e+09 |
# |    critic_loss     | 2.8e+07   |
# |    ent_coef        | 7.36e+05  |
# |    ent_coef_loss   | 3.02      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50489     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 315       |
# |    fps             | 14        |
# |    time_elapsed    | 2101      |
# |    total_timesteps | 31185     |
# | train/             |           |
# |    actor_loss      | -2.98e+09 |
# |    critic_loss     | 3.17e+07  |
# |    ent_coef        | 7.56e+05  |
# |    ent_coef_loss   | -1.33     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 50984     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.6    |
# | time/              |          |
# |    episodes        | 320      |
# |    fps             | 14       |
# |    time_elapsed    | 2140     |
# |    total_timesteps | 31680    |
# | train/             |          |
# |    actor_loss      | -3e+09   |
# |    critic_loss     | 2.88e+07 |
# |    ent_coef        | 7.52e+05 |
# |    ent_coef_loss   | -0.236   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51479    |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.6    |
# | time/              |          |
# |    episodes        | 325      |
# |    fps             | 14       |
# |    time_elapsed    | 2179     |
# |    total_timesteps | 32175    |
# | train/             |          |
# |    actor_loss      | -3.1e+09 |
# |    critic_loss     | 2.96e+07 |
# |    ent_coef        | 7.76e+05 |
# |    ent_coef_loss   | 3.62     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 51974    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 330       |
# |    fps             | 14        |
# |    time_elapsed    | 2216      |
# |    total_timesteps | 32670     |
# | train/             |           |
# |    actor_loss      | -3.18e+09 |
# |    critic_loss     | 2.88e+07  |
# |    ent_coef        | 7.79e+05  |
# |    ent_coef_loss   | 5.54      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52469     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 335       |
# |    fps             | 14        |
# |    time_elapsed    | 2251      |
# |    total_timesteps | 33165     |
# | train/             |           |
# |    actor_loss      | -3.31e+09 |
# |    critic_loss     | 2.8e+07   |
# |    ent_coef        | 8.01e+05  |
# |    ent_coef_loss   | -1.31     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 52964     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 340       |
# |    fps             | 14        |
# |    time_elapsed    | 2289      |
# |    total_timesteps | 33660     |
# | train/             |           |
# |    actor_loss      | -3.37e+09 |
# |    critic_loss     | 3.57e+07  |
# |    ent_coef        | 8.1e+05   |
# |    ent_coef_loss   | -2.23     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 53459     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 345       |
# |    fps             | 14        |
# |    time_elapsed    | 2328      |
# |    total_timesteps | 34155     |
# | train/             |           |
# |    actor_loss      | -3.49e+09 |
# |    critic_loss     | 3.66e+07  |
# |    ent_coef        | 8.32e+05  |
# |    ent_coef_loss   | 1.93      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 53954     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.6     |
# | time/              |           |
# |    episodes        | 350       |
# |    fps             | 14        |
# |    time_elapsed    | 2370      |
# |    total_timesteps | 34650     |
# | train/             |           |
# |    actor_loss      | -3.48e+09 |
# |    critic_loss     | 3.26e+07  |
# |    ent_coef        | 8.2e+05   |
# |    ent_coef_loss   | 1.36      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 54449     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 355       |
# |    fps             | 14        |
# |    time_elapsed    | 2406      |
# |    total_timesteps | 35145     |
# | train/             |           |
# |    actor_loss      | -3.69e+09 |
# |    critic_loss     | 3.68e+07  |
# |    ent_coef        | 8.65e+05  |
# |    ent_coef_loss   | -1.33     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 54944     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 360       |
# |    fps             | 14        |
# |    time_elapsed    | 2442      |
# |    total_timesteps | 35640     |
# | train/             |           |
# |    actor_loss      | -3.72e+09 |
# |    critic_loss     | 3.29e+07  |
# |    ent_coef        | 8.57e+05  |
# |    ent_coef_loss   | -4.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 55439     |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 365       |
# |    fps             | 14        |
# |    time_elapsed    | 2480      |
# |    total_timesteps | 36135     |
# | train/             |           |
# |    actor_loss      | -3.89e+09 |
# |    critic_loss     | 3.33e+07  |
# |    ent_coef        | 8.88e+05  |
# |    ent_coef_loss   | 1.63      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 55934     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 370      |
# |    fps             | 14       |
# |    time_elapsed    | 2515     |
# |    total_timesteps | 36630    |
# | train/             |          |
# |    actor_loss      | -3.9e+09 |
# |    critic_loss     | 4.12e+07 |
# |    ent_coef        | 9.18e+05 |
# |    ent_coef_loss   | 4.07     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 56429    |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 375       |
# |    fps             | 14        |
# |    time_elapsed    | 2549      |
# |    total_timesteps | 37125     |
# | train/             |           |
# |    actor_loss      | -4.06e+09 |
# |    critic_loss     | 4.02e+07  |
# |    ent_coef        | 9.17e+05  |
# |    ent_coef_loss   | -0.467    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 56924     |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 380      |
# |    fps             | 14       |
# ...
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 1995      |
# |    fps             | 13        |
# |    time_elapsed    | 14773     |
# |    total_timesteps | 197505    |
# | train/             |           |
# |    actor_loss      | -6.86e+10 |
# |    critic_loss     | 1.54e+09  |
# |    ent_coef        | 5.97e+06  |
# |    ent_coef_loss   | 2.52      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 217304    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 2000     |
# |    fps             | 13       |
# |    time_elapsed    | 14813    |
# |    total_timesteps | 198000   |
# | train/             |          |
# |    actor_loss      | -6.4e+10 |
# |    critic_loss     | 1.38e+09 |
# |    ent_coef        | 5.83e+06 |
# |    ent_coef_loss   | 3.71     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 217799   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2005      |
# |    fps             | 13        |
# |    time_elapsed    | 14850     |
# |    total_timesteps | 198495    |
# | train/             |           |
# |    actor_loss      | -6.95e+10 |
# |    critic_loss     | 1.62e+09  |
# |    ent_coef        | 6.07e+06  |
# |    ent_coef_loss   | 1.5       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 218294    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2010      |
# |    fps             | 13        |
# |    time_elapsed    | 14889     |
# |    total_timesteps | 198990    |
# | train/             |           |
# |    actor_loss      | -6.96e+10 |
# |    critic_loss     | 1.51e+09  |
# |    ent_coef        | 6.21e+06  |
# |    ent_coef_loss   | -1.96     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 218789    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2015      |
# |    fps             | 13        |
# |    time_elapsed    | 14928     |
# |    total_timesteps | 199485    |
# | train/             |           |
# |    actor_loss      | -6.72e+10 |
# |    critic_loss     | 1.55e+09  |
# |    ent_coef        | 5.99e+06  |
# |    ent_coef_loss   | 6.08      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 219284    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2020      |
# |    fps             | 13        |
# |    time_elapsed    | 14968     |
# |    total_timesteps | 199980    |
# | train/             |           |
# |    actor_loss      | -6.91e+10 |
# |    critic_loss     | 1.44e+09  |
# |    ent_coef        | 5.96e+06  |
# |    ent_coef_loss   | 5.05      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 219779    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 2025     |
# |    fps             | 13       |
# |    time_elapsed    | 15006    |
# |    total_timesteps | 200475   |
# | train/             |          |
# |    actor_loss      | -6.9e+10 |
# |    critic_loss     | 1.46e+09 |
# |    ent_coef        | 6.05e+06 |
# |    ent_coef_loss   | 6.61     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 220274   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2030      |
# |    fps             | 13        |
# |    time_elapsed    | 15049     |
# |    total_timesteps | 200970    |
# | train/             |           |
# |    actor_loss      | -7.43e+10 |
# |    critic_loss     | 1.58e+09  |
# |    ent_coef        | 6.27e+06  |
# |    ent_coef_loss   | -0.324    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 220769    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2035      |
# |    fps             | 13        |
# |    time_elapsed    | 15089     |
# |    total_timesteps | 201465    |
# | train/             |           |
# |    actor_loss      | -7.18e+10 |
# |    critic_loss     | 1.66e+09  |
# |    ent_coef        | 6.22e+06  |
# |    ent_coef_loss   | 6.43      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 221264    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2040      |
# |    fps             | 13        |
# |    time_elapsed    | 15128     |
# |    total_timesteps | 201960    |
# | train/             |           |
# |    actor_loss      | -7.36e+10 |
# |    critic_loss     | 1.63e+09  |
# |    ent_coef        | 6.41e+06  |
# |    ent_coef_loss   | 0.376     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 221759    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2045      |
# |    fps             | 13        |
# |    time_elapsed    | 15168     |
# |    total_timesteps | 202455    |
# | train/             |           |
# |    actor_loss      | -7.55e+10 |
# |    critic_loss     | 1.66e+09  |
# |    ent_coef        | 6.34e+06  |
# |    ent_coef_loss   | -0.731    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 222254    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2050      |
# |    fps             | 13        |
# |    time_elapsed    | 15210     |
# |    total_timesteps | 202950    |
# | train/             |           |
# |    actor_loss      | -7.44e+10 |
# |    critic_loss     | 1.65e+09  |
# |    ent_coef        | 6.37e+06  |
# |    ent_coef_loss   | -0.374    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 222749    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2055      |
# |    fps             | 13        |
# |    time_elapsed    | 15251     |
# |    total_timesteps | 203445    |
# | train/             |           |
# |    actor_loss      | -7.44e+10 |
# |    critic_loss     | 1.63e+09  |
# |    ent_coef        | 6.26e+06  |
# |    ent_coef_loss   | 4.98      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 223244    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2060      |
# |    fps             | 13        |
# |    time_elapsed    | 15291     |
# |    total_timesteps | 203940    |
# | train/             |           |
# |    actor_loss      | -7.44e+10 |
# |    critic_loss     | 1.71e+09  |
# |    ent_coef        | 6.16e+06  |
# |    ent_coef_loss   | -3.02     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 223739    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2065      |
# |    fps             | 13        |
# |    time_elapsed    | 15333     |
# |    total_timesteps | 204435    |
# | train/             |           |
# |    actor_loss      | -7.55e+10 |
# |    critic_loss     | 1.74e+09  |
# |    ent_coef        | 6.13e+06  |
# |    ent_coef_loss   | 2.78      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 224234    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2070      |
# |    fps             | 13        |
# |    time_elapsed    | 15377     |
# |    total_timesteps | 204930    |
# | train/             |           |
# |    actor_loss      | -7.66e+10 |
# |    critic_loss     | 1.75e+09  |
# |    ent_coef        | 6.17e+06  |
# |    ent_coef_loss   | -2.83     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 224729    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2075      |
# |    fps             | 13        |
# |    time_elapsed    | 15416     |
# |    total_timesteps | 205425    |
# | train/             |           |
# |    actor_loss      | -7.48e+10 |
# |    critic_loss     | 1.74e+09  |
# |    ent_coef        | 5.92e+06  |
# |    ent_coef_loss   | 3.81      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 225224    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2080      |
# |    fps             | 13        |
# |    time_elapsed    | 15456     |
# |    total_timesteps | 205920    |
# | train/             |           |
# |    actor_loss      | -7.64e+10 |
# |    critic_loss     | 1.7e+09   |
# |    ent_coef        | 5.84e+06  |
# |    ent_coef_loss   | -4.95     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 225719    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2085      |
# |    fps             | 13        |
# |    time_elapsed    | 15498     |
# |    total_timesteps | 206415    |
# | train/             |           |
# |    actor_loss      | -7.72e+10 |
# |    critic_loss     | 1.76e+09  |
# |    ent_coef        | 5.97e+06  |
# |    ent_coef_loss   | -0.879    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 226214    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 2090     |
# |    fps             | 13       |
# |    time_elapsed    | 15536    |
# |    total_timesteps | 206910   |
# | train/             |          |
# |    actor_loss      | -7.4e+10 |
# |    critic_loss     | 1.78e+09 |
# |    ent_coef        | 5.84e+06 |
# |    ent_coef_loss   | 6.59     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 226709   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2095      |
# |    fps             | 13        |
# |    time_elapsed    | 15577     |
# |    total_timesteps | 207405    |
# | train/             |           |
# |    actor_loss      | -7.72e+10 |
# |    critic_loss     | 1.72e+09  |
# |    ent_coef        | 5.77e+06  |
# |    ent_coef_loss   | -1.67     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 227204    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2100      |
# |    fps             | 13        |
# |    time_elapsed    | 15616     |
# |    total_timesteps | 207900    |
# | train/             |           |
# |    actor_loss      | -7.77e+10 |
# |    critic_loss     | 1.78e+09  |
# |    ent_coef        | 5.81e+06  |
# |    ent_coef_loss   | 5.5       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 227699    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 2105      |
# |    fps             | 13        |
# |    time_elapsed    | 15659     |
# |    total_timesteps | 208395    |
# | train/             |           |
# |    actor_loss      | -7.88e+10 |
# |    critic_loss     | 1.72e+09  |
# |    ent_coef        | 5.87e+06  |
# |    ent_coef_loss   | -6.37     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 228194    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 2110      |
# |    fps             | 13        |
# |    time_elapsed    | 15700     |
# |    total_timesteps | 208890    |
# | train/             |           |
# |    actor_loss      | -7.86e+10 |
# |    critic_loss     | 1.65e+09  |
# |    ent_coef        | 6.07e+06  |
# |    ent_coef_loss   | 4.12      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 228689    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 2115      |
# |    fps             | 13        |
# |    time_elapsed    | 15740     |
# |    total_timesteps | 209385    |
# | train/             |           |
# |    actor_loss      | -7.77e+10 |
# |    critic_loss     | 1.67e+09  |
# |    ent_coef        | 6e+06     |
# |    ent_coef_loss   | 3.45      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 229184    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -98.5    |
# | time/              |          |
# |    episodes        | 2120     |
# |    fps             | 13       |
# |    time_elapsed    | 15778    |
# |    total_timesteps | 209880   |
# | train/             |          |
# |    actor_loss      | -7.9e+10 |
# |    critic_loss     | 1.75e+09 |
# |    ent_coef        | 6e+06    |
# |    ent_coef_loss   | 2.12     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 229679   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -98.5     |
# | time/              |           |
# |    episodes        | 2125      |
# |    fps             | 13        |
# |    time_elapsed    | 15821     |
# |    total_timesteps | 210375    |
# | train/             |           |
# |    actor_loss      | -8.15e+10 |
# |    critic_loss     | 1.86e+09  |
# |    ent_coef        | 5.93e+06  |
# |    ent_coef_loss   | 1.47      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 230174    |
# ----------------------------------

# %%
import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlaceMultiObject-v0",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 3
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
             policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
             replay_buffer_class=HerReplayBuffer,
             replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
             tau=0.05, learning_starts=200, verbose=1)

#model = TQC.load("data/tqc")
#model.set_env(env)
COLLECT=False
if COLLECT:
    collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
    model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
else:
    print("load_replay_buffer")
    model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

print("start pre-training from buffer only")
model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.train(gradient_steps=80000)

print("start learning")
model.learn(total_timesteps=450_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
collect_data(env, model, "pickplace", "place_success_target", 10000, 35)
model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")

print("finish learning")
# Out:
# load_replay_buffer
# num_trajectories: 100 success rate: 0.89 Reward: 126.0
# num_trajectories: 200 success rate: 0.875 Reward: 84.0
# num_trajectories: 300 success rate: 0.8833333333333333 Reward: 79.0
# num_trajectories: 400 success rate: 0.89 Reward: 86.0
# num_trajectories: 500 success rate: 0.896 Reward: 86.0
# num_trajectories: 600 success rate: 0.9 Reward: 88.0
# num_trajectories: 700 success rate: 0.9014285714285715 Reward: 80.0
# num_trajectories: 800 success rate: 0.9025 Reward: 16.0
# num_trajectories: 900 success rate: 0.9033333333333333 Reward: 86.0
# num_trajectories: 1000 success rate: 0.904 Reward: 76.0
# num_trajectories: 1100 success rate: 0.9054545454545454 Reward: -35.0
# num_trajectories: 1200 success rate: 0.9025 Reward: -35.0
# num_trajectories: 1300 success rate: 0.9030769230769231 Reward: 137.0
# num_trajectories: 1400 success rate: 0.9057142857142857 Reward: 82.0
# num_trajectories: 1500 success rate: 0.9066666666666666 Reward: 86.0
# num_trajectories: 1600 success rate: 0.9075 Reward: 82.0
# num_trajectories: 1700 success rate: 0.9070588235294118 Reward: 76.0
# num_trajectories: 1800 success rate: 0.9077777777777778 Reward: 88.0
# num_trajectories: 1900 success rate: 0.9084210526315789 Reward: 82.0
# num_trajectories: 2000 success rate: 0.9085 Reward: 78.0
# num_trajectories: 2100 success rate: 0.91 Reward: 78.0
# num_trajectories: 2200 success rate: 0.9109090909090909 Reward: 75.0
# num_trajectories: 2300 success rate: 0.9091304347826087 Reward: 77.0
# num_trajectories: 2400 success rate: 0.9079166666666667 Reward: 82.0
# num_trajectories: 2500 success rate: 0.9088 Reward: 75.0
# num_trajectories: 2600 success rate: 0.9096153846153846 Reward: 79.0
# num_trajectories: 2700 success rate: 0.9103703703703704 Reward: 82.0
# num_trajectories: 2800 success rate: 0.9107142857142857 Reward: 131.0
# num_trajectories: 2900 success rate: 0.9113793103448276 Reward: 76.0
# num_trajectories: 3000 success rate: 0.9103333333333333 Reward: 76.0
# num_trajectories: 3100 success rate: 0.9109677419354839 Reward: 80.0
# num_trajectories: 3200 success rate: 0.910625 Reward: 88.0
# num_trajectories: 3300 success rate: 0.9103030303030303 Reward: 77.0
# num_trajectories: 3400 success rate: 0.9094117647058824 Reward: 79.0
# num_trajectories: 3500 success rate: 0.9088571428571428 Reward: 74.0
# num_trajectories: 3600 success rate: 0.9075 Reward: 73.0
# num_trajectories: 3700 success rate: 0.9067567567567567 Reward: 86.0
# num_trajectories: 3800 success rate: 0.9076315789473685 Reward: 90.0
# num_trajectories: 3900 success rate: 0.9079487179487179 Reward: 130.0
# num_trajectories: 4000 success rate: 0.90675 Reward: 88.0
# num_trajectories: 4100 success rate: 0.9053658536585366 Reward: 80.0
# num_trajectories: 4200 success rate: 0.905 Reward: 78.0
# num_trajectories: 4300 success rate: 0.9051162790697674 Reward: 78.0
# num_trajectories: 4400 success rate: 0.9043181818181818 Reward: 86.0
# num_trajectories: 4500 success rate: 0.9044444444444445 Reward: 86.0
# num_trajectories: 4600 success rate: 0.9045652173913044 Reward: 80.0
# num_trajectories: 4700 success rate: 0.904468085106383 Reward: 78.0
# num_trajectories: 4800 success rate: 0.9033333333333333 Reward: 78.0
# num_trajectories: 4900 success rate: 0.9036734693877551 Reward: 78.0
# num_trajectories: 5000 success rate: 0.9038 Reward: -35.0
# num_trajectories: 5100 success rate: 0.9041176470588236 Reward: 82.0
# num_trajectories: 5200 success rate: 0.9044230769230769 Reward: 86.0
# num_trajectories: 5300 success rate: 0.9039622641509434 Reward: 84.0
# num_trajectories: 5400 success rate: 0.9031481481481481 Reward: 132.0
# num_trajectories: 5500 success rate: 0.9032727272727272 Reward: 133.0
# num_trajectories: 5600 success rate: 0.9033928571428571 Reward: 74.0
# num_trajectories: 5700 success rate: 0.9031578947368422 Reward: 75.0
# num_trajectories: 5800 success rate: 0.903448275862069 Reward: 73.0
# num_trajectories: 5900 success rate: 0.9032203389830509 Reward: 72.0
# num_trajectories: 6000 success rate: 0.9043333333333333 Reward: 78.0
# num_trajectories: 6100 success rate: 0.9049180327868852 Reward: 126.0
# num_trajectories: 6200 success rate: 0.9053225806451612 Reward: 76.0
# num_trajectories: 6300 success rate: 0.9046031746031746 Reward: -35.0
# num_trajectories: 6400 success rate: 0.90453125 Reward: 77.0
# num_trajectories: 6500 success rate: 0.9046153846153846 Reward: 86.0
# num_trajectories: 6600 success rate: 0.9042424242424243 Reward: -35.0
# num_trajectories: 6700 success rate: 0.9040298507462686 Reward: 75.0
# num_trajectories: 6800 success rate: 0.904264705882353 Reward: 86.0
# num_trajectories: 6900 success rate: 0.9043478260869565 Reward: 78.0
# num_trajectories: 7000 success rate: 0.9044285714285715 Reward: 86.0
# num_trajectories: 7100 success rate: 0.9040845070422535 Reward: 16.0
# num_trajectories: 7200 success rate: 0.9036111111111111 Reward: 75.0
# num_trajectories: 7300 success rate: 0.9034246575342466 Reward: 80.0
# num_trajectories: 7400 success rate: 0.9035135135135135 Reward: -35.0
# num_trajectories: 7500 success rate: 0.9034666666666666 Reward: 80.0
# num_trajectories: 7600 success rate: 0.9032894736842105 Reward: 78.0
# num_trajectories: 7700 success rate: 0.9027272727272727 Reward: 79.0
# num_trajectories: 7800 success rate: 0.9029487179487179 Reward: 71.0
# num_trajectories: 7900 success rate: 0.9029113924050632 Reward: 133.0
# num_trajectories: 8000 success rate: 0.902125 Reward: 131.0
# num_trajectories: 8100 success rate: 0.9019753086419753 Reward: 81.0
# num_trajectories: 8200 success rate: 0.9020731707317073 Reward: -35.0
# num_trajectories: 8300 success rate: 0.9019277108433735 Reward: 75.0
# num_trajectories: 8400 success rate: 0.9023809523809524 Reward: 83.0
# num_trajectories: 8500 success rate: 0.9029411764705882 Reward: 84.0
# num_trajectories: 8600 success rate: 0.9029069767441861 Reward: 73.0
# num_trajectories: 8700 success rate: 0.9033333333333333 Reward: 76.0
# num_trajectories: 8800 success rate: 0.9035227272727273 Reward: 84.0
# num_trajectories: 8900 success rate: 0.9031460674157303 Reward: 75.0
# num_trajectories: 9000 success rate: 0.9031111111111111 Reward: 86.0
# num_trajectories: 9100 success rate: 0.9034065934065935 Reward: 137.0
# num_trajectories: 9200 success rate: 0.9041304347826087 Reward: 78.0
# num_trajectories: 9300 success rate: 0.9039784946236559 Reward: 77.0
# num_trajectories: 9400 success rate: 0.9043617021276595 Reward: 77.0
# num_trajectories: 9500 success rate: 0.9042105263157895 Reward: 86.0
# num_trajectories: 9600 success rate: 0.9039583333333333 Reward: 82.0
# num_trajectories: 9700 success rate: 0.9038144329896908 Reward: 131.0
# num_trajectories: 9800 success rate: 0.9041836734693878 Reward: 73.0
# num_trajectories: 9900 success rate: 0.9041414141414141 Reward: 76.0
# num_trajectories: 10000 success rate: 0.9042 Reward: 84.0
# success rate: 0.9042
# Output()
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4550      |
# |    fps             | 11        |
# |    time_elapsed    | 42        |
# |    total_timesteps | 450470    |
# | train/             |           |
# |    actor_loss      | -3.07e+14 |
# |    critic_loss     | 3.48e+13  |
# |    ent_coef        | 1.86e+10  |
# |    ent_coef_loss   | -300      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 530269    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4555      |
# |    fps             | 10        |
# |    time_elapsed    | 87        |
# |    total_timesteps | 450965    |
# | train/             |           |
# |    actor_loss      | -3.22e+14 |
# |    critic_loss     | 3.53e+13  |
# |    ent_coef        | 3.19e+10  |
# |    ent_coef_loss   | -237      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 530764    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4560      |
# |    fps             | 10        |
# |    time_elapsed    | 135       |
# |    total_timesteps | 451460    |
# | train/             |           |
# |    actor_loss      | -3.25e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 4.76e+10  |
# |    ent_coef_loss   | -184      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 531259    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4565      |
# |    fps             | 10        |
# |    time_elapsed    | 182       |
# |    total_timesteps | 451955    |
# | train/             |           |
# |    actor_loss      | -3.31e+14 |
# |    critic_loss     | 3.44e+13  |
# |    ent_coef        | 6.64e+10  |
# |    ent_coef_loss   | -157      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 531754    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4570      |
# |    fps             | 10        |
# |    time_elapsed    | 229       |
# |    total_timesteps | 452450    |
# | train/             |           |
# |    actor_loss      | -3.34e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 8.78e+10  |
# |    ent_coef_loss   | -119      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 532249    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4575      |
# |    fps             | 10        |
# |    time_elapsed    | 275       |
# |    total_timesteps | 452945    |
# | train/             |           |
# |    actor_loss      | -3.39e+14 |
# |    critic_loss     | 3.52e+13  |
# |    ent_coef        | 1.12e+11  |
# |    ent_coef_loss   | -65.7     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 532744    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4580      |
# |    fps             | 10        |
# |    time_elapsed    | 322       |
# |    total_timesteps | 453440    |
# | train/             |           |
# |    actor_loss      | -3.33e+14 |
# |    critic_loss     | 3.38e+13  |
# |    ent_coef        | 1.35e+11  |
# |    ent_coef_loss   | -44.9     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 533239    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4585      |
# |    fps             | 10        |
# |    time_elapsed    | 368       |
# |    total_timesteps | 453935    |
# | train/             |           |
# |    actor_loss      | -3.37e+14 |
# |    critic_loss     | 3.35e+13  |
# |    ent_coef        | 1.57e+11  |
# |    ent_coef_loss   | -20.8     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 533734    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -98.4    |
# | time/              |          |
# |    episodes        | 4590     |
# |    fps             | 10       |
# |    time_elapsed    | 415      |
# |    total_timesteps | 454430   |
# | train/             |          |
# |    actor_loss      | -3.5e+14 |
# |    critic_loss     | 3.45e+13 |
# |    ent_coef        | 1.73e+11 |
# |    ent_coef_loss   | -25.5    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 534229   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4595      |
# |    fps             | 10        |
# |    time_elapsed    | 460       |
# |    total_timesteps | 454925    |
# | train/             |           |
# |    actor_loss      | -3.52e+14 |
# |    critic_loss     | 3.41e+13  |
# |    ent_coef        | 1.85e+11  |
# |    ent_coef_loss   | 2.03      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 534724    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4600      |
# |    fps             | 10        |
# |    time_elapsed    | 507       |
# |    total_timesteps | 455420    |
# | train/             |           |
# |    actor_loss      | -3.54e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 1.91e+11  |
# |    ent_coef_loss   | 3.29      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 535219    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4605      |
# |    fps             | 10        |
# |    time_elapsed    | 555       |
# |    total_timesteps | 455915    |
# | train/             |           |
# |    actor_loss      | -3.61e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 1.92e+11  |
# |    ent_coef_loss   | -0.576    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 535714    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4610      |
# |    fps             | 10        |
# |    time_elapsed    | 602       |
# |    total_timesteps | 456410    |
# | train/             |           |
# |    actor_loss      | -3.71e+14 |
# |    critic_loss     | 3.48e+13  |
# |    ent_coef        | 1.96e+11  |
# |    ent_coef_loss   | -7.24     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 536209    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99.2     |
# |    ep_rew_mean     | -98.4    |
# | time/              |          |
# |    episodes        | 4615     |
# |    fps             | 10       |
# |    time_elapsed    | 651      |
# |    total_timesteps | 456905   |
# | train/             |          |
# |    actor_loss      | -3.6e+14 |
# |    critic_loss     | 3.36e+13 |
# |    ent_coef        | 1.95e+11 |
# |    ent_coef_loss   | -4.06    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 536704   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4620      |
# |    fps             | 10        |
# |    time_elapsed    | 698       |
# |    total_timesteps | 457400    |
# | train/             |           |
# |    actor_loss      | -3.69e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 1.93e+11  |
# |    ent_coef_loss   | -0.822    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 537199    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4625      |
# |    fps             | 10        |
# |    time_elapsed    | 744       |
# |    total_timesteps | 457895    |
# | train/             |           |
# |    actor_loss      | -3.83e+14 |
# |    critic_loss     | 3.52e+13  |
# |    ent_coef        | 1.93e+11  |
# |    ent_coef_loss   | -2.82     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 537694    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4630      |
# |    fps             | 10        |
# |    time_elapsed    | 791       |
# |    total_timesteps | 458390    |
# | train/             |           |
# |    actor_loss      | -3.83e+14 |
# |    critic_loss     | 3.54e+13  |
# |    ent_coef        | 1.95e+11  |
# |    ent_coef_loss   | -18       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 538189    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4635      |
# |    fps             | 10        |
# |    time_elapsed    | 838       |
# |    total_timesteps | 458885    |
# | train/             |           |
# |    actor_loss      | -3.87e+14 |
# |    critic_loss     | 3.51e+13  |
# |    ent_coef        | 1.94e+11  |
# |    ent_coef_loss   | -17.7     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 538684    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4640      |
# |    fps             | 10        |
# |    time_elapsed    | 887       |
# |    total_timesteps | 459380    |
# | train/             |           |
# |    actor_loss      | -3.92e+14 |
# |    critic_loss     | 3.52e+13  |
# |    ent_coef        | 1.94e+11  |
# |    ent_coef_loss   | -1.12     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 539179    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99.2      |
# |    ep_rew_mean     | -98.4     |
# | time/              |           |
# |    episodes        | 4645      |
# |    fps             | 10        |
# |    time_elapsed    | 935       |
# |    total_timesteps | 459875    |
# | train/             |           |
# |    actor_loss      | -3.91e+14 |
# |    critic_loss     | 3.46e+13  |
# |    ent_coef        | 2e+11     |
# |    ent_coef_loss   | 4.7       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 539674    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4650      |
# |    fps             | 10        |
# |    time_elapsed    | 983       |
# |    total_timesteps | 460370    |
# | train/             |           |
# |    actor_loss      | -3.99e+14 |
# |    critic_loss     | 3.48e+13  |
# |    ent_coef        | 2.05e+11  |
# |    ent_coef_loss   | 3.47      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 540169    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4655      |
# |    fps             | 10        |
# |    time_elapsed    | 1034      |
# |    total_timesteps | 460865    |
# | train/             |           |
# |    actor_loss      | -3.99e+14 |
# |    critic_loss     | 3.46e+13  |
# |    ent_coef        | 1.98e+11  |
# |    ent_coef_loss   | -2.86     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 540664    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4660      |
# |    fps             | 10        |
# |    time_elapsed    | 1080      |
# |    total_timesteps | 461360    |
# | train/             |           |
# |    actor_loss      | -4.19e+14 |
# |    critic_loss     | 3.62e+13  |
# |    ent_coef        | 2.02e+11  |
# |    ent_coef_loss   | -3.32     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 541159    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4665      |
# |    fps             | 10        |
# |    time_elapsed    | 1125      |
# |    total_timesteps | 461855    |
# | train/             |           |
# |    actor_loss      | -4.09e+14 |
# |    critic_loss     | 3.56e+13  |
# |    ent_coef        | 2e+11     |
# |    ent_coef_loss   | -8.88     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 541654    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4670      |
# |    fps             | 10        |
# |    time_elapsed    | 1172      |
# |    total_timesteps | 462350    |
# | train/             |           |
# |    actor_loss      | -4.18e+14 |
# |    critic_loss     | 3.56e+13  |
# |    ent_coef        | 2.04e+11  |
# |    ent_coef_loss   | 1.07      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 542149    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4675      |
# |    fps             | 10        |
# |    time_elapsed    | 1217      |
# |    total_timesteps | 462845    |
# | train/             |           |
# |    actor_loss      | -4.11e+14 |
# |    critic_loss     | 3.51e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | -1.57     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 542644    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4680      |
# |    fps             | 10        |
# |    time_elapsed    | 1267      |
# |    total_timesteps | 463340    |
# | train/             |           |
# |    actor_loss      | -4.23e+14 |
# |    critic_loss     | 3.54e+13  |
# |    ent_coef        | 2.02e+11  |
# |    ent_coef_loss   | 1.34      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 543139    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4685      |
# |    fps             | 10        |
# |    time_elapsed    | 1314      |
# |    total_timesteps | 463835    |
# | train/             |           |
# |    actor_loss      | -4.15e+14 |
# |    critic_loss     | 3.45e+13  |
# |    ent_coef        | 2.03e+11  |
# |    ent_coef_loss   | -1.11     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 543634    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4690      |
# |    fps             | 10        |
# |    time_elapsed    | 1363      |
# |    total_timesteps | 464330    |
# | train/             |           |
# |    actor_loss      | -4.21e+14 |
# |    critic_loss     | 3.47e+13  |
# |    ent_coef        | 1.99e+11  |
# |    ent_coef_loss   | 9.85      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 544129    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4695      |
# |    fps             | 10        |
# |    time_elapsed    | 1414      |
# |    total_timesteps | 464825    |
# | train/             |           |
# |    actor_loss      | -4.36e+14 |
# |    critic_loss     | 3.59e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | -9.36     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 544624    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4700      |
# |    fps             | 10        |
# |    time_elapsed    | 1462      |
# |    total_timesteps | 465320    |
# | train/             |           |
# |    actor_loss      | -4.33e+14 |
# |    critic_loss     | 3.52e+13  |
# |    ent_coef        | 1.98e+11  |
# |    ent_coef_loss   | 3.85      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 545119    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4705      |
# |    fps             | 10        |
# |    time_elapsed    | 1509      |
# |    total_timesteps | 465815    |
# | train/             |           |
# |    actor_loss      | -4.38e+14 |
# |    critic_loss     | 3.55e+13  |
# |    ent_coef        | 1.96e+11  |
# |    ent_coef_loss   | -7.04     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 545614    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4710      |
# |    fps             | 10        |
# |    time_elapsed    | 1556      |
# |    total_timesteps | 466310    |
# | train/             |           |
# |    actor_loss      | -4.38e+14 |
# |    critic_loss     | 3.56e+13  |
# |    ent_coef        | 1.97e+11  |
# |    ent_coef_loss   | 8.62      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 546109    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4715      |
# |    fps             | 10        |
# |    time_elapsed    | 1602      |
# |    total_timesteps | 466805    |
# | train/             |           |
# |    actor_loss      | -4.39e+14 |
# |    critic_loss     | 3.56e+13  |
# |    ent_coef        | 1.97e+11  |
# |    ent_coef_loss   | 6.53      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 546604    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4720      |
# |    fps             | 10        |
# |    time_elapsed    | 1651      |
# |    total_timesteps | 467300    |
# | train/             |           |
# |    actor_loss      | -4.44e+14 |
# |    critic_loss     | 3.6e+13   |
# |    ent_coef        | 1.95e+11  |
# |    ent_coef_loss   | -2.63     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 547099    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4725      |
# |    fps             | 10        |
# |    time_elapsed    | 1699      |
# |    total_timesteps | 467795    |
# | train/             |           |
# |    actor_loss      | -4.42e+14 |
# |    critic_loss     | 3.53e+13  |
# |    ent_coef        | 1.98e+11  |
# |    ent_coef_loss   | 13.2      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 547594    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4730      |
# |    fps             | 10        |
# |    time_elapsed    | 1746      |
# |    total_timesteps | 468290    |
# | train/             |           |
# |    actor_loss      | -4.52e+14 |
# |    critic_loss     | 3.58e+13  |
# |    ent_coef        | 1.99e+11  |
# |    ent_coef_loss   | -9.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 548089    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 4735     |
# |    fps             | 10       |
# |    time_elapsed    | 1794     |
# |    total_timesteps | 468785   |
# | train/             |          |
# |    actor_loss      | -4.6e+14 |
# |    critic_loss     | 3.58e+13 |
# |    ent_coef        | 2e+11    |
# |    ent_coef_loss   | -2.18    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 548584   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4740      |
# |    fps             | 10        |
# |    time_elapsed    | 1839      |
# |    total_timesteps | 469280    |
# | train/             |           |
# |    actor_loss      | -4.51e+14 |
# |    critic_loss     | 3.55e+13  |
# |    ent_coef        | 2.02e+11  |
# |    ent_coef_loss   | 16.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 549079    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4745      |
# |    fps             | 10        |
# |    time_elapsed    | 1885      |
# |    total_timesteps | 469775    |
# | train/             |           |
# |    actor_loss      | -4.64e+14 |
# |    critic_loss     | 3.63e+13  |
# |    ent_coef        | 1.99e+11  |
# |    ent_coef_loss   | -7.43     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 549574    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4750      |
# |    fps             | 10        |
# |    time_elapsed    | 1931      |
# |    total_timesteps | 470270    |
# | train/             |           |
# |    actor_loss      | -4.68e+14 |
# |    critic_loss     | 3.62e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | -2.34     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 550069    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4755      |
# |    fps             | 10        |
# |    time_elapsed    | 1976      |
# |    total_timesteps | 470765    |
# | train/             |           |
# |    actor_loss      | -4.71e+14 |
# |    critic_loss     | 3.68e+13  |
# |    ent_coef        | 1.97e+11  |
# |    ent_coef_loss   | -8.77     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 550564    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4760      |
# |    fps             | 10        |
# |    time_elapsed    | 2023      |
# |    total_timesteps | 471260    |
# | train/             |           |
# |    actor_loss      | -4.67e+14 |
# |    critic_loss     | 3.63e+13  |
# |    ent_coef        | 1.99e+11  |
# |    ent_coef_loss   | 2.01      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 551059    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4765      |
# |    fps             | 10        |
# |    time_elapsed    | 2070      |
# |    total_timesteps | 471755    |
# | train/             |           |
# |    actor_loss      | -4.65e+14 |
# |    critic_loss     | 3.64e+13  |
# |    ent_coef        | 2e+11     |
# |    ent_coef_loss   | -0.889    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 551554    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4770      |
# |    fps             | 10        |
# |    time_elapsed    | 2117      |
# |    total_timesteps | 472250    |
# | train/             |           |
# |    actor_loss      | -4.88e+14 |
# |    critic_loss     | 3.81e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | -2.35     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 552049    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4775      |
# |    fps             | 10        |
# |    time_elapsed    | 2164      |
# |    total_timesteps | 472745    |
# | train/             |           |
# |    actor_loss      | -4.78e+14 |
# |    critic_loss     | 3.7e+13   |
# |    ent_coef        | 2e+11     |
# |    ent_coef_loss   | -1.7      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 552544    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4780      |
# |    fps             | 10        |
# |    time_elapsed    | 2211      |
# |    total_timesteps | 473240    |
# | train/             |           |
# |    actor_loss      | -4.76e+14 |
# |    critic_loss     | 3.63e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | 4.66      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 553039    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 4785      |
# |    fps             | 10        |
# |    time_elapsed    | 2259      |
# |    total_timesteps | 473735    |
# | train/             |           |
# |    actor_loss      | -4.79e+14 |
# |    critic_loss     | 3.7e+13   |
# |    ent_coef        | 1.99e+11  |
# |    ent_coef_loss   | 1.36      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 553534    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 4790     |
# |    fps             | 10       |
# |    time_elapsed    | 2307     |
# |    total_timesteps | 474230   |
# | train/             |          |
# |    actor_loss      | -4.7e+14 |
# |    critic_loss     | 3.61e+13 |
# |    ent_coef        | 2e+11    |
# |    ent_coef_loss   | 7.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 554029   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4795      |
# |    fps             | 10        |
# |    time_elapsed    | 2354      |
# |    total_timesteps | 474725    |
# | train/             |           |
# |    actor_loss      | -4.97e+14 |
# |    critic_loss     | 3.73e+13  |
# |    ent_coef        | 2.01e+11  |
# |    ent_coef_loss   | 10.9      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 554524    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4800      |
# |    fps             | 10        |
# |    time_elapsed    | 2400      |
# |    total_timesteps | 475220    |
# | train/             |           |
# |    actor_loss      | -4.93e+14 |
# |    critic_loss     | 3.76e+13  |
# |    ent_coef        | 2.04e+11  |
# |    ent_coef_loss   | -10.6     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 555019    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4805      |
# |    fps             | 10        |
# |    time_elapsed    | 2448      |
# |    total_timesteps | 475715    |
# | train/             |           |
# |    actor_loss      | -4.89e+14 |
# |    critic_loss     | 3.68e+13  |
# |    ent_coef        | 2.05e+11  |
# |    ent_coef_loss   | -16       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 555514    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4810      |
# |    fps             | 10        |
# |    time_elapsed    | 2494      |
# |    total_timesteps | 476210    |
# | train/             |           |
# |    actor_loss      | -4.91e+14 |
# |    critic_loss     | 3.67e+13  |
# |    ent_coef        | 2e+11     |
# |    ent_coef_loss   | -3.76     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 556009    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4815      |
# |    fps             | 10        |
# |    time_elapsed    | 2539      |
# |    total_timesteps | 476705    |
# | train/             |           |
# |    actor_loss      | -4.88e+14 |
# |    critic_loss     | 3.76e+13  |
# |    ent_coef        | 2.04e+11  |
# |    ent_coef_loss   | 5.42      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 556504    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4820      |
# |    fps             | 10        |
# |    time_elapsed    | 2588      |
# |    total_timesteps | 477200    |
# | train/             |           |
# |    actor_loss      | -5.04e+14 |
# |    critic_loss     | 3.76e+13  |
# |    ent_coef        | 2.05e+11  |
# |    ent_coef_loss   | -2.51     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 556999    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4825      |
# |    fps             | 10        |
# |    time_elapsed    | 2637      |
# |    total_timesteps | 477695    |
# | train/             |           |
# |    actor_loss      | -5.07e+14 |
# |    critic_loss     | 3.8e+13   |
# |    ent_coef        | 2.08e+11  |
# |    ent_coef_loss   | 2.81      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 557494    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4830      |
# |    fps             | 10        |
# |    time_elapsed    | 2687      |
# |    total_timesteps | 478190    |
# | train/             |           |
# |    actor_loss      | -5.03e+14 |
# |    critic_loss     | 3.78e+13  |
# |    ent_coef        | 2.04e+11  |
# |    ent_coef_loss   | -0.807    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 557989    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.3    |
# | time/              |          |
# |    episodes        | 4835     |
# |    fps             | 10       |
# |    time_elapsed    | 2733     |
# |    total_timesteps | 478685   |
# | train/             |          |
# |    actor_loss      | -5e+14   |
# |    critic_loss     | 3.8e+13  |
# |    ent_coef        | 2.04e+11 |
# |    ent_coef_loss   | -2.36    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 558484   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4840      |
# |    fps             | 10        |
# |    time_elapsed    | 2779      |
# |    total_timesteps | 479180    |
# | train/             |           |
# |    actor_loss      | -5.21e+14 |
# |    critic_loss     | 3.93e+13  |
# |    ent_coef        | 2.07e+11  |
# |    ent_coef_loss   | -0.141    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 558979    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4845      |
# |    fps             | 10        |
# |    time_elapsed    | 2825      |
# |    total_timesteps | 479675    |
# | train/             |           |
# |    actor_loss      | -5.17e+14 |
# |    critic_loss     | 4.01e+13  |
# |    ent_coef        | 2.07e+11  |
# |    ent_coef_loss   | -3.35     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 559474    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4850      |
# |    fps             | 10        |
# |    time_elapsed    | 2870      |
# |    total_timesteps | 480170    |
# | train/             |           |
# |    actor_loss      | -5.26e+14 |
# |    critic_loss     | 3.95e+13  |
# |    ent_coef        | 2.06e+11  |
# |    ent_coef_loss   | -9.47     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 559969    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4855      |
# |    fps             | 10        |
# |    time_elapsed    | 2916      |
# |    total_timesteps | 480665    |
# | train/             |           |
# |    actor_loss      | -5.11e+14 |
# |    critic_loss     | 3.85e+13  |
# |    ent_coef        | 2.06e+11  |
# |    ent_coef_loss   | 11.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 560464    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4860      |
# |    fps             | 10        |
# |    time_elapsed    | 2963      |
# |    total_timesteps | 481160    |
# | train/             |           |
# |    actor_loss      | -5.17e+14 |
# |    critic_loss     | 3.88e+13  |
# |    ent_coef        | 2.04e+11  |
# |    ent_coef_loss   | -5.12     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 560959    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4865      |
# |    fps             | 10        |
# |    time_elapsed    | 3008      |
# |    total_timesteps | 481655    |
# | train/             |           |
# |    actor_loss      | -5.33e+14 |
# |    critic_loss     | 3.97e+13  |
# |    ent_coef        | 2.1e+11   |
# |    ent_coef_loss   | -4.33     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 561454    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4870      |
# |    fps             | 10        |
# |    time_elapsed    | 3055      |
# |    total_timesteps | 482150    |
# | train/             |           |
# |    actor_loss      | -5.24e+14 |
# |    critic_loss     | 3.98e+13  |
# |    ent_coef        | 2.08e+11  |
# |    ent_coef_loss   | -4.79     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 561949    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4875      |
# |    fps             | 10        |
# |    time_elapsed    | 3100      |
# |    total_timesteps | 482645    |
# | train/             |           |
# |    actor_loss      | -5.33e+14 |
# |    critic_loss     | 4e+13     |
# |    ent_coef        | 2.09e+11  |
# |    ent_coef_loss   | -0.687    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 562444    |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4880      |
# |    fps             | 10        |
# |    time_elapsed    | 3148      |
# |    total_timesteps | 483140    |
# | train/             |           |
# |    actor_loss      | -5.32e+14 |
# |    critic_loss     | 4.01e+13  |
# |    ent_coef        | 2.1e+11   |
# |    ent_coef_loss   | -1.52     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 562939    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -97.3    |
# | time/              |          |
# |    episodes        | 4885     |
# |    fps             | 10       |
# |    time_elapsed    | 3196     |
# |    total_timesteps | 483635   |
# | train/             |          |
# |    actor_loss      | -5.4e+14 |
# |    critic_loss     | 4.1e+13  |
# |    ent_coef        | 2.08e+11 |
# |    ent_coef_loss   | -3.48    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 563434   |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -97.3     |
# | time/              |           |
# |    episodes        | 4890      |
# |    fps             | 10        |
# |    time_elapsed    | 3242      |
# |    total_timesteps | 484130    |
# | train/             |           |
# |    actor_loss      | -5.37e+14 |
# |    critic_loss     | 4e+13     |
# |    ent_coef        | 2.13e+11  |
# |    ent_coef_loss   | 0.0023    |
# |    learning_rate   | 0.001     |
# |    n_updates       | 563929    |
# ----------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -99      |
# | time/              |          |
# |    episodes        | 4895     |
# |    fps             | 10       |
# |    time_elapsed    | 3289     |
# |    total_timesteps | 484625   |
# ...
# |    critic_loss     | 5.62e+14 |
# |    ent_coef        | 4.44e+11 |
# |    ent_coef_loss   | 6.44     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 1016854  |
# ---------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9470      |
# |    fps             | 10        |
# |    time_elapsed    | 47470     |
# |    total_timesteps | 937550    |
# | train/             |           |
# |    actor_loss      | -4.48e+15 |
# |    critic_loss     | 5.56e+14  |
# |    ent_coef        | 4.29e+11  |
# |    ent_coef_loss   | 1.93      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1017349   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9475      |
# |    fps             | 10        |
# |    time_elapsed    | 47518     |
# |    total_timesteps | 938045    |
# | train/             |           |
# |    actor_loss      | -4.34e+15 |
# |    critic_loss     | 5.54e+14  |
# |    ent_coef        | 4.37e+11  |
# |    ent_coef_loss   | 8.93      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1017844   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9480      |
# |    fps             | 10        |
# |    time_elapsed    | 47569     |
# |    total_timesteps | 938540    |
# | train/             |           |
# |    actor_loss      | -4.56e+15 |
# |    critic_loss     | 5.65e+14  |
# |    ent_coef        | 4.41e+11  |
# |    ent_coef_loss   | -3.06     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1018339   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9485      |
# |    fps             | 10        |
# |    time_elapsed    | 47616     |
# |    total_timesteps | 939035    |
# | train/             |           |
# |    actor_loss      | -4.39e+15 |
# |    critic_loss     | 5.6e+14   |
# |    ent_coef        | 4.35e+11  |
# |    ent_coef_loss   | 19.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1018834   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9490      |
# |    fps             | 10        |
# |    time_elapsed    | 47664     |
# |    total_timesteps | 939530    |
# | train/             |           |
# |    actor_loss      | -4.62e+15 |
# |    critic_loss     | 5.86e+14  |
# |    ent_coef        | 4.34e+11  |
# |    ent_coef_loss   | -1.42     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1019329   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9495      |
# |    fps             | 10        |
# |    time_elapsed    | 47710     |
# |    total_timesteps | 940025    |
# | train/             |           |
# |    actor_loss      | -4.58e+15 |
# |    critic_loss     | 5.86e+14  |
# |    ent_coef        | 4.29e+11  |
# |    ent_coef_loss   | -6.22     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1019824   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9500      |
# |    fps             | 10        |
# |    time_elapsed    | 47760     |
# |    total_timesteps | 940520    |
# | train/             |           |
# |    actor_loss      | -4.54e+15 |
# |    critic_loss     | 5.81e+14  |
# |    ent_coef        | 4.25e+11  |
# |    ent_coef_loss   | -3.92     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1020319   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9505      |
# |    fps             | 10        |
# |    time_elapsed    | 47804     |
# |    total_timesteps | 941015    |
# | train/             |           |
# |    actor_loss      | -4.62e+15 |
# |    critic_loss     | 5.78e+14  |
# |    ent_coef        | 4.24e+11  |
# |    ent_coef_loss   | -8.76     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1020814   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9510      |
# |    fps             | 10        |
# |    time_elapsed    | 47845     |
# |    total_timesteps | 941510    |
# | train/             |           |
# |    actor_loss      | -4.64e+15 |
# |    critic_loss     | 5.78e+14  |
# |    ent_coef        | 4.19e+11  |
# |    ent_coef_loss   | -6.65     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1021309   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9515      |
# |    fps             | 10        |
# |    time_elapsed    | 47888     |
# |    total_timesteps | 942005    |
# | train/             |           |
# |    actor_loss      | -4.46e+15 |
# |    critic_loss     | 5.55e+14  |
# |    ent_coef        | 4.19e+11  |
# |    ent_coef_loss   | 1.66      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1021804   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9520      |
# |    fps             | 10        |
# |    time_elapsed    | 47930     |
# |    total_timesteps | 942500    |
# | train/             |           |
# |    actor_loss      | -4.54e+15 |
# |    critic_loss     | 5.71e+14  |
# |    ent_coef        | 4.22e+11  |
# |    ent_coef_loss   | -3.49     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1022299   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9525      |
# |    fps             | 10        |
# |    time_elapsed    | 47972     |
# |    total_timesteps | 942995    |
# | train/             |           |
# |    actor_loss      | -4.59e+15 |
# |    critic_loss     | 5.73e+14  |
# |    ent_coef        | 4.23e+11  |
# |    ent_coef_loss   | 0.365     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1022794   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9530      |
# |    fps             | 10        |
# |    time_elapsed    | 48013     |
# |    total_timesteps | 943490    |
# | train/             |           |
# |    actor_loss      | -4.78e+15 |
# |    critic_loss     | 5.95e+14  |
# |    ent_coef        | 4.18e+11  |
# |    ent_coef_loss   | -6.53     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1023289   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9535      |
# |    fps             | 10        |
# |    time_elapsed    | 48052     |
# |    total_timesteps | 943985    |
# | train/             |           |
# |    actor_loss      | -4.65e+15 |
# |    critic_loss     | 5.99e+14  |
# |    ent_coef        | 4.15e+11  |
# |    ent_coef_loss   | -5.11     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1023784   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9540      |
# |    fps             | 10        |
# |    time_elapsed    | 48095     |
# |    total_timesteps | 944480    |
# | train/             |           |
# |    actor_loss      | -4.57e+15 |
# |    critic_loss     | 5.76e+14  |
# |    ent_coef        | 4.1e+11   |
# |    ent_coef_loss   | 7.32      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1024279   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9545      |
# |    fps             | 10        |
# |    time_elapsed    | 48137     |
# |    total_timesteps | 944975    |
# | train/             |           |
# |    actor_loss      | -4.65e+15 |
# |    critic_loss     | 5.84e+14  |
# |    ent_coef        | 4.08e+11  |
# |    ent_coef_loss   | -9.11     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1024774   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9550      |
# |    fps             | 10        |
# |    time_elapsed    | 48178     |
# |    total_timesteps | 945470    |
# | train/             |           |
# |    actor_loss      | -4.56e+15 |
# |    critic_loss     | 5.88e+14  |
# |    ent_coef        | 4.2e+11   |
# |    ent_coef_loss   | 0.422     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1025269   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9555      |
# |    fps             | 10        |
# |    time_elapsed    | 48219     |
# |    total_timesteps | 945965    |
# | train/             |           |
# |    actor_loss      | -4.52e+15 |
# |    critic_loss     | 5.77e+14  |
# |    ent_coef        | 4e+11     |
# |    ent_coef_loss   | 3.29      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1025764   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9560      |
# |    fps             | 10        |
# |    time_elapsed    | 48258     |
# |    total_timesteps | 946460    |
# | train/             |           |
# |    actor_loss      | -4.51e+15 |
# |    critic_loss     | 5.76e+14  |
# |    ent_coef        | 4.01e+11  |
# |    ent_coef_loss   | 8.83      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1026259   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9565      |
# |    fps             | 10        |
# |    time_elapsed    | 48300     |
# |    total_timesteps | 946955    |
# | train/             |           |
# |    actor_loss      | -4.51e+15 |
# |    critic_loss     | 5.72e+14  |
# |    ent_coef        | 4.09e+11  |
# |    ent_coef_loss   | 12.4      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1026754   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9570      |
# |    fps             | 10        |
# |    time_elapsed    | 48339     |
# |    total_timesteps | 947450    |
# | train/             |           |
# |    actor_loss      | -4.29e+15 |
# |    critic_loss     | 5.56e+14  |
# |    ent_coef        | 4.01e+11  |
# |    ent_coef_loss   | 32.3      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1027249   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9575      |
# |    fps             | 10        |
# |    time_elapsed    | 48384     |
# |    total_timesteps | 947945    |
# | train/             |           |
# |    actor_loss      | -4.68e+15 |
# |    critic_loss     | 5.86e+14  |
# |    ent_coef        | 4.12e+11  |
# |    ent_coef_loss   | 2.16      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1027744   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9580      |
# |    fps             | 10        |
# |    time_elapsed    | 48425     |
# |    total_timesteps | 948440    |
# | train/             |           |
# |    actor_loss      | -4.58e+15 |
# |    critic_loss     | 5.81e+14  |
# |    ent_coef        | 4.02e+11  |
# |    ent_coef_loss   | 14.1      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1028239   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9585      |
# |    fps             | 10        |
# |    time_elapsed    | 48464     |
# |    total_timesteps | 948935    |
# | train/             |           |
# |    actor_loss      | -4.64e+15 |
# |    critic_loss     | 5.99e+14  |
# |    ent_coef        | 4.03e+11  |
# |    ent_coef_loss   | -10.3     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1028734   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9590      |
# |    fps             | 10        |
# |    time_elapsed    | 48508     |
# |    total_timesteps | 949430    |
# | train/             |           |
# |    actor_loss      | -4.67e+15 |
# |    critic_loss     | 5.88e+14  |
# |    ent_coef        | 4.07e+11  |
# |    ent_coef_loss   | 9.35      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1029229   |
# ----------------------------------
# ----------------------------------
# | rollout/           |           |
# |    ep_len_mean     | 99        |
# |    ep_rew_mean     | -99       |
# | time/              |           |
# |    episodes        | 9595      |
# |    fps             | 10        |
# |    time_elapsed    | 48552     |
# |    total_timesteps | 949925    |
# | train/             |           |
# |    actor_loss      | -4.89e+15 |
# |    critic_loss     | 6.09e+14  |
# |    ent_coef        | 6.5e+11   |
# |    ent_coef_loss   | -78.6     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 1029724   |
# ----------------------------------
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# finish learning

# %%
import os
os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
os.environ["CUDA_VISIBLE_DEVICES"]="2"

import time
import numpy as np
from roboverse.policies import policies
from stable_baselines3.common.utils import set_random_seed


def make_env(env_id: str, rank: int, seed: int = 0):
    """
    Utility function for multiprocessed env.

    :param env_id: the environment ID
    :param num_env: the number of environments you wish to have in subprocesses
    :param seed: the inital seed for RNG
    :param rank: index of the subprocess
    """
    def _init():
        env = roboverse.make(env_id,
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
        #env = TimeFeatureWrapper(env)
        #env.reset(seed=seed + rank)
        env.reset()
        return env
    set_random_seed(seed)
    return _init


def collect_data(env, model, policy, target, num_trajectories=100, num_timesteps=30):
    policy_class = policies[policy]
    policy = policy_class(env)
    num_success = 0
    num_saved = 0
    accept_trajectory_key = target
    noise = 0.1
    EPSILON = 0.1

    while num_saved < num_trajectories:
        num_saved += 1
        num_steps = 1e6
        rewards = []
        env.reset()
        policy.reset()
        time.sleep(0.1)
        success = False
        for j in range(num_timesteps):
            action, agent_info = policy.get_action()

            # In case we need to pad actions by 1 for easier realNVP modelling 
            env_action_dim = env.action_space.shape[0]
            #if env_action_dim - action.shape[0] == 1:
            #    action = np.append(action, 0)
            action += np.random.normal(scale=noise, size=(env_action_dim,))
            action = np.clip(action, -1 + EPSILON, 1 - EPSILON)
            observation = env.get_observation()
            observation["image"] = np.transpose(observation["image"], (2, 0, 1))
            next_observation, reward, done, info = env.step(action)
            next_observation["image"] = np.transpose(next_observation["image"], (2, 0, 1))
            rewards.append(reward)
            success = sum(rewards) > 70
            model.replay_buffer.add(observation, next_observation, action, reward, np.array([done]), [{}])

            if success and num_steps > 1e3: #info[accept_trajectory_key]
                num_steps = j

            if success and j > 23: #info[accept_trajectory_key]
                break
            if done or agent_info['done']:
                break

        if success: #info[accept_trajectory_key]
            PRINT = False
            if PRINT:
                print("num_timesteps: ", num_steps, rewards)
                #print(observation["image"].shape)
                #print(next_observation["image"].shape)
            num_success += 1
        if num_saved%100 == 0:
            print(f"num_trajectories: {num_saved} success rate: {num_success/num_saved} Reward: {sum(rewards)}")

    print("success rate: {}".format(num_success / (num_saved)))


import gymnasium as gym
import numpy as np
import roboverse

from stable_baselines3 import TD3
from stable_baselines3.common.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise
from stable_baselines3 import DDPG, HerReplayBuffer
from sb3_contrib import TQC
from sb3_contrib.common.wrappers import TimeFeatureWrapper
from stable_baselines3.common.vec_env import VecNormalize
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common.callbacks import EvalCallback, CheckpointCallback


env = roboverse.make("Widow250PickPlace-v2",
                         gui=False,
                         observation_mode="pixels",
                         transpose_image=False)
#env = TimeFeatureWrapper(env)
#env = DummyVecEnv([make_env("Widow250PickPlace-v1", i) for i in range(4)])
seed = 3
obs = env.reset()

# Save a checkpoint every 1000 steps
checkpoint_callback = CheckpointCallback(
  save_freq=1000,
  save_path=f"./data/seed_{seed}/",
  name_prefix="tqc_model",
  save_replay_buffer=False,
  save_vecnormalize=False,
)

LOAD = True
if LOAD:
    model = TQC.load(f"data/seed_{seed}/tqc_model_329000_steps", env=env)
    model.set_env(env)
else:
    model = TQC(env=env, batch_size=2048, buffer_size=1_000_000, gamma=0.95, learning_rate=0.001, policy='MultiInputPolicy',
                 policy_kwargs=dict(net_arch=[512, 512, 512], n_critics=2),
                 replay_buffer_class=HerReplayBuffer,
                 replay_buffer_kwargs=dict(goal_selection_strategy='future', n_sampled_goal=4),
                 tau=0.05, learning_starts=200, verbose=1)

COLLECT=False
if COLLECT:
    print("collect data")
    collect_data(env, model, "pickplace", "place_success_target", 20000, 35)
    model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
else:
    print("load_replay_buffer")
    model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

# print("start pre-training from buffer only")
# model.learn(total_timesteps=0, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
# model.train(gradient_steps=20000)

print("start learning")
model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")

print("load_replay_buffer")
model.load_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")
# collect_data(env, model, "pickplace", "place_success_target", 10000, 30)
# model.save_replay_buffer(f"data/seed_{seed}/tqc_expert_pick_place")

model.learn(total_timesteps=500_000, callback=checkpoint_callback, log_interval=5, tb_log_name="exp", reset_num_timesteps = False, progress_bar=True)
model.save(f"data/seed_{seed}/tqc_pick_place")
model.save_replay_buffer(f"data/seed_{seed}/tqc_trained_pick_place")
print("finish learning")
# Out:
# pybullet build time: May 20 2022 19:44:17
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/envs/registration.py:555: UserWarning: WARN: The environment Widow250PickPlace-v2 is out of date. You should consider upgrading to version `v3`.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/spaces/box.py:127: UserWarning: WARN: Box bound precision lowered by casting to float32
#   logger.warn(f"Box bound precision lowered by casting to {self.dtype}")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:174: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed a `seed` instead of using `Env.seed` for resetting the environment random number generator.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:187: UserWarning: WARN: Future gym versions will require that `Env.reset` can be passed `options` to allow the environment initialisation to be passed additional information.
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:195: UserWarning: WARN: The result returned by `env.reset()` was not a tuple of the form `(obs, info)`, where `obs` is a observation and `info` is a dictionary containing additional information. Actual type: `<class 'dict'>`
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/common/vec_env/patch_gym.py:49: UserWarning: You provided an OpenAI Gym environment. We strongly recommend transitioning to Gymnasium environments. Stable-Baselines3 is automatically wrapping your environments in a compatibility layer, which could potentially cause issues.
#   warnings.warn(
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# Wrapping the env in a VecTransposeImage.
# load_replay_buffer
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/stable_baselines3/her/her_replay_buffer.py:394: UserWarning: The last trajectory in the replay buffer will be truncated.
# If you are in the same episode as when the replay buffer was saved,
# you should use `truncate_last_trajectory=False` to avoid that issue.
#   warnings.warn(
# start learning
# Output()
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:219:
# DeprecationWarning: WARN: Core environment is written in old step API which returns one bool instead of two. It is
# recommended to rewrite the environment with new step API.
#   logger.deprecation(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:225:
# DeprecationWarning: `np.bool8` is a deprecated alias for `np.bool_`.  (Deprecated NumPy 1.24)
#   if not isinstance(done, (bool, np.bool8)):
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: float64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:165: UserWarning:
# WARN: The obs returned by the `step()` method is not within the observation space.
#   logger.warn(f"{pre} is not within the observation space.")
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gym/utils/passive_env_checker.py:141: UserWarning:
# WARN: The obs returned by the `step()` method was expecting numpy array dtype to be float32, actual type: int64
#   logger.warn(
# /raid/notebook/enhupgu/cog/cogv/lib/python3.8/site-packages/gymnasium/core.py:311: UserWarning: WARN:
# env.compute_reward to get variables from other wrappers is deprecated and will be removed in v1.0, to get this
# variable you can do `env.unwrapped.compute_reward` for environment variables or
# `env.get_wrapper_attr('compute_reward')` that will search the reminding wrappers.
#   logger.warn(
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.3    |
# | time/              |          |
# |    episodes        | 3325     |
# |    fps             | 12       |
# |    time_elapsed    | 16       |
# |    total_timesteps | 329198   |
# | train/             |          |
# |    actor_loss      | -29.3    |
# |    critic_loss     | 1.56     |
# |    ent_coef        | 0.0065   |
# |    ent_coef_loss   | 14.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 348996   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 3330     |
# |    fps             | 13       |
# |    time_elapsed    | 52       |
# |    total_timesteps | 329693   |
# | train/             |          |
# |    actor_loss      | -51.4    |
# |    critic_loss     | 12.8     |
# |    ent_coef        | 0.0155   |
# |    ent_coef_loss   | 63.6     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 349491   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 3335     |
# |    fps             | 13       |
# |    time_elapsed    | 91       |
# |    total_timesteps | 330188   |
# | train/             |          |
# |    actor_loss      | -33.9    |
# |    critic_loss     | 3.23     |
# |    ent_coef        | 0.0296   |
# |    ent_coef_loss   | -0.379   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 349986   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 3340     |
# |    fps             | 12       |
# |    time_elapsed    | 129      |
# |    total_timesteps | 330683   |
# | train/             |          |
# |    actor_loss      | -36.6    |
# |    critic_loss     | 2.52     |
# |    ent_coef        | 0.0283   |
# |    ent_coef_loss   | -1.82    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 350481   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -82.8    |
# | time/              |          |
# |    episodes        | 3345     |
# |    fps             | 12       |
# |    time_elapsed    | 168      |
# |    total_timesteps | 331178   |
# | train/             |          |
# |    actor_loss      | -40.3    |
# |    critic_loss     | 2.64     |
# |    ent_coef        | 0.0271   |
# |    ent_coef_loss   | -1.35    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 350976   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.3    |
# | time/              |          |
# |    episodes        | 3350     |
# |    fps             | 12       |
# |    time_elapsed    | 208      |
# |    total_timesteps | 331673   |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 2.06     |
# |    ent_coef        | 0.0257   |
# |    ent_coef_loss   | -3.14    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 351471   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.1    |
# | time/              |          |
# |    episodes        | 3355     |
# |    fps             | 12       |
# |    time_elapsed    | 244      |
# |    total_timesteps | 332168   |
# | train/             |          |
# |    actor_loss      | -37.1    |
# |    critic_loss     | 2.37     |
# |    ent_coef        | 0.0245   |
# |    ent_coef_loss   | 1.05     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 351966   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -93.5    |
# | time/              |          |
# |    episodes        | 3360     |
# |    fps             | 13       |
# |    time_elapsed    | 281      |
# |    total_timesteps | 332663   |
# | train/             |          |
# |    actor_loss      | -35      |
# |    critic_loss     | 2.92     |
# |    ent_coef        | 0.0236   |
# |    ent_coef_loss   | -2.85    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352461   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -91.9    |
# | time/              |          |
# |    episodes        | 3365     |
# |    fps             | 13       |
# |    time_elapsed    | 319      |
# |    total_timesteps | 333158   |
# | train/             |          |
# |    actor_loss      | -30      |
# |    critic_loss     | 1.2      |
# |    ent_coef        | 0.0153   |
# |    ent_coef_loss   | -9.25    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 352956   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -92.9    |
# | time/              |          |
# |    episodes        | 3370     |
# |    fps             | 13       |
# |    time_elapsed    | 357      |
# |    total_timesteps | 333653   |
# | train/             |          |
# |    actor_loss      | -31.5    |
# |    critic_loss     | 1.88     |
# |    ent_coef        | 0.0118   |
# |    ent_coef_loss   | -3.11    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 353451   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -92.4    |
# | time/              |          |
# |    episodes        | 3375     |
# |    fps             | 12       |
# |    time_elapsed    | 396      |
# |    total_timesteps | 334148   |
# | train/             |          |
# |    actor_loss      | -31      |
# |    critic_loss     | 2.59     |
# |    ent_coef        | 0.0119   |
# |    ent_coef_loss   | 3.34     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 353946   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -92.4    |
# | time/              |          |
# |    episodes        | 3380     |
# |    fps             | 12       |
# |    time_elapsed    | 440      |
# |    total_timesteps | 334643   |
# | train/             |          |
# |    actor_loss      | -31.6    |
# |    critic_loss     | 1.36     |
# |    ent_coef        | 0.0149   |
# |    ent_coef_loss   | -0.784   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 354441   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 3385     |
# |    fps             | 12       |
# |    time_elapsed    | 484      |
# |    total_timesteps | 335138   |
# | train/             |          |
# |    actor_loss      | -34.4    |
# |    critic_loss     | 1.34     |
# |    ent_coef        | 0.0144   |
# |    ent_coef_loss   | 0.294    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 354936   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 3390     |
# |    fps             | 12       |
# |    time_elapsed    | 527      |
# |    total_timesteps | 335633   |
# | train/             |          |
# |    actor_loss      | -38.5    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | 1.91     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 355431   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 3395     |
# |    fps             | 12       |
# |    time_elapsed    | 570      |
# |    total_timesteps | 336128   |
# | train/             |          |
# |    actor_loss      | -38.1    |
# |    critic_loss     | 2.25     |
# |    ent_coef        | 0.0203   |
# |    ent_coef_loss   | -0.343   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 355926   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -94      |
# | time/              |          |
# |    episodes        | 3400     |
# |    fps             | 12       |
# |    time_elapsed    | 620      |
# |    total_timesteps | 336623   |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 1.52     |
# |    ent_coef        | 0.0223   |
# |    ent_coef_loss   | 0.38     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 356421   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -91.6    |
# | time/              |          |
# |    episodes        | 3405     |
# |    fps             | 12       |
# |    time_elapsed    | 669      |
# |    total_timesteps | 337118   |
# | train/             |          |
# |    actor_loss      | -36.5    |
# |    critic_loss     | 1.47     |
# |    ent_coef        | 0.0227   |
# |    ent_coef_loss   | -1.08    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 356916   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -91.6    |
# | time/              |          |
# |    episodes        | 3410     |
# |    fps             | 11       |
# |    time_elapsed    | 718      |
# |    total_timesteps | 337613   |
# | train/             |          |
# |    actor_loss      | -34.9    |
# |    critic_loss     | 1.34     |
# |    ent_coef        | 0.0202   |
# |    ent_coef_loss   | -1.7     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 357411   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -90.6    |
# | time/              |          |
# |    episodes        | 3415     |
# |    fps             | 11       |
# |    time_elapsed    | 762      |
# |    total_timesteps | 338108   |
# | train/             |          |
# |    actor_loss      | -36.2    |
# |    critic_loss     | 1.17     |
# |    ent_coef        | 0.0192   |
# |    ent_coef_loss   | 1.26     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 357906   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -89.6    |
# | time/              |          |
# |    episodes        | 3420     |
# |    fps             | 11       |
# |    time_elapsed    | 803      |
# |    total_timesteps | 338603   |
# | train/             |          |
# |    actor_loss      | -43.5    |
# |    critic_loss     | 1.7      |
# |    ent_coef        | 0.0291   |
# |    ent_coef_loss   | 0.284    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 358401   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -87      |
# | time/              |          |
# |    episodes        | 3425     |
# |    fps             | 11       |
# |    time_elapsed    | 843      |
# |    total_timesteps | 339098   |
# | train/             |          |
# |    actor_loss      | -48.5    |
# |    critic_loss     | 1.47     |
# |    ent_coef        | 0.0319   |
# |    ent_coef_loss   | -0.999   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 358896   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.7    |
# | time/              |          |
# |    episodes        | 3430     |
# |    fps             | 11       |
# |    time_elapsed    | 883      |
# |    total_timesteps | 339593   |
# | train/             |          |
# |    actor_loss      | -41.6    |
# |    critic_loss     | 1.37     |
# |    ent_coef        | 0.0223   |
# |    ent_coef_loss   | 1.13     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 359391   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -85.7    |
# | time/              |          |
# |    episodes        | 3435     |
# |    fps             | 12       |
# |    time_elapsed    | 921      |
# |    total_timesteps | 340088   |
# | train/             |          |
# |    actor_loss      | -38      |
# |    critic_loss     | 1.14     |
# |    ent_coef        | 0.0239   |
# |    ent_coef_loss   | 1.29     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 359886   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -83.8    |
# | time/              |          |
# |    episodes        | 3440     |
# |    fps             | 12       |
# |    time_elapsed    | 964      |
# |    total_timesteps | 340583   |
# | train/             |          |
# |    actor_loss      | -40.1    |
# |    critic_loss     | 1.23     |
# |    ent_coef        | 0.0206   |
# |    ent_coef_loss   | 1.17     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 360381   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.8    |
# | time/              |          |
# |    episodes        | 3445     |
# |    fps             | 12       |
# |    time_elapsed    | 1004     |
# |    total_timesteps | 341078   |
# | train/             |          |
# |    actor_loss      | -37.8    |
# |    critic_loss     | 1.25     |
# |    ent_coef        | 0.0194   |
# |    ent_coef_loss   | -0.278   |
# |    learning_rate   | 0.001    |
# |    n_updates       | 360876   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.8    |
# | time/              |          |
# |    episodes        | 3450     |
# |    fps             | 12       |
# |    time_elapsed    | 1046     |
# |    total_timesteps | 341573   |
# | train/             |          |
# |    actor_loss      | -37.9    |
# |    critic_loss     | 2.07     |
# |    ent_coef        | 0.0226   |
# |    ent_coef_loss   | 0.572    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 361371   |
# ---------------------------------
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 99       |
# |    ep_rew_mean     | -81.8    |
# | time/              |          |
# |    episodes        | 3455     |
# |    fps             | 11       |
# |    time_elapsed    | 1096     |
# |    total_timesteps | 342068   |
# | train/             |          |
# |    actor_loss      | -36.1    |
# |    critic_loss     | 1.36     |
# |    ent_coef        | 0.0193   |
# |    ent_coef_loss   | -1.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 361866   |
# ---------------------------------
